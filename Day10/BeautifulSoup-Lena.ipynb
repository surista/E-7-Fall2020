# %% [markdown]
# # Beautiful Soup
# ## An introduction to Webscraping
# ### By Lena Hajjar, with additions by Jeff Parker
#
# <p> Many of you have expressed interest in processing information found on websites</p>
# <p> There are many options, but the library that is mentioned most often is Beautiful Soup</p>

# %% [markdown]
# #### Some Basics
# Beautiful Soup has an excellent website, with full documentation.  See https://www.crummy.com/software/BeautifulSoup/bs4/doc/
#
# <b> NOTE: </b> Webscraping may be against the terms and conditions of some websites (Yelp, FB, etc). Sometimes it's because they offer the services for a fee (Twitter, Facebook, etc) - so if you really want the information and really don't want to break the terms & conditions (or get your IP address banned from the website), you can try getting the information through the recommended sources. The rules are really made to prevent people from doing mass scrapings for profit - I doubt they would bother tracking down the graduate student scraping one or two pages for educational purposes.
#
# <b> robots.txt </b> The convention is that the publisher will list the rules in a file called robots.txt at the root of the website.

# %%
from bs4 import BeautifulSoup
import requests

# first, we want to read the rules of the road
webpage = requests.get("https://www.movieforums.com/robots.txt")
webtext = webpage.text
print(webtext)
# Out:
# User-agent: *
# Disallow: /scripts/
# Disallow: /cgi-bin/
# Disallow: /community/admin/
# Disallow: /community/images/
# Disallow: /community/mod/
# Disallow: /community/avatar.php
# Disallow: /community/editpost.php
# Disallow: /community/member2.php
# Disallow: /community/moderator.php
# Disallow: /community/newreply.php
# Disallow: /community/newthread.php
# Disallow: /community/online.php
# Disallow: /community/postings.php
# Disallow: /community/private.php
# Disallow: /community/register.php
# Disallow: /community/report.php
# Disallow: /community/threadrate.php
# Disallow: /community/usercp.php

# %% [markdown]
# ## Is our use legitimate?
# What does that mean for us?  Is this use legitimate?  We can use the robotparser library to check.
#
# We demonstrate below, checking if we can scrape the Extension School site.

# %%
import urllib.robotparser
rp = urllib.robotparser.RobotFileParser()
rp.set_url("https://www.extension.harvard.edu/robots.txt")
rp.read()
print(rp.can_fetch("*", "https://www.extension.harvard.edu/"))
# Out:
# True

# %% [markdown]
# #### Let's start at the beginning:
# Let's say we want to look at a thread in movieforums.com about the movie Die Hard.  Here is a thread we will process: https://www.movieforums.com/community/showthread.php?t=49209

# %%
from bs4 import BeautifulSoup
import requests

# first, we should request the webpage
webpage = requests.get("https://www.movieforums.com/community/showthread.php?t=49209")
webtext = webpage.text
# We can print it, but it isn't very useful
print(webtext)
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" dir="ltr" lang="en">
# <head>
# <title> Is Die Hard (1988) overrated? - Movie Forums</title>
#
#
#
# <meta http-equiv="Content-Type" content="text/html; charset=charset=utf-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge" >
# <!-- Whatever you do, do NOT put other stuff above the IE=edge tag -->
#
# <link rel="apple-touch-icon-precomposed" sizes="196x196" href="/apple-touch-icon-precomposed.png?v=2" />
# <link rel="apple-touch-icon" sizes="57x57"   href="/apple-touch-icon-57x57.png?v=2">
# <link rel="apple-touch-icon" sizes="60x60"   href="/apple-touch-icon-60x60.png?v=2">
# <link rel="apple-touch-icon" sizes="72x72"   href="/apple-touch-icon-72x72.png?v=2">
# <link rel="apple-touch-icon" sizes="76x76"   href="/apple-touch-icon-76x76.png?v=2">
# <link rel="apple-touch-icon" sizes="114x114" href="/apple-touch-icon-114x114.png?v=2">
# <link rel="apple-touch-icon" sizes="120x120" href="/apple-touch-icon-120x120.png?v=2">
# <link rel="apple-touch-icon" sizes="144x144" href="/apple-touch-icon-144x144.png?v=2">
# <link rel="apple-touch-icon" sizes="152x152" href="/apple-touch-icon-152x152.png?v=2">
#
# <link rel="shortcut icon" href="/favicon.ico" type="image/x-icon" />
#
# <meta name="mobile-web-app-capable" content="no" />
# <!-- Stops Android from making shortcuts into web apps without browser toolbars -->
#
# <!-- Windows 8 -->
# <meta name="application-name" content="Movie Forums"/>
# <meta name="msapplication-TileColor" content="#161E16"/>
# <meta name="msapplication-square70x70logo" content="/images/windows8/tiny.png"/>
# <meta name="msapplication-square150x150logo" content="/images/windows8/square.png"/>
# <meta name="msapplication-wide310x150logo" content="/images/windows8/wide.png"/>
# <meta name="msapplication-square310x310logo" content="/images/windows8/large.png"/>
# <meta name="msapplication-notification" content="frequency=30;polling-uri=http://notifications.buildmypinnedsite.com/?feed=/community/external.php?type=RSS2&amp;id=1;polling-uri2=http://notifications.buildmypinnedsite.com/?feed=/community/external.php?type=RSS2&amp;id=2;polling-uri3=http://notifications.buildmypinnedsite.com/?feed=/community/external.php?type=RSS2&amp;id=3;polling-uri4=http://notifications.buildmypinnedsite.com/?feed=/community/external.php?type=RSS2&amp;id=4;polling-uri5=http://notifications.buildmypinnedsite.com/?feed=/community/external.php?type=RSS2&amp;id=5; cycle=1"/>
#
# <meta name="generator" content="vBulletin 3.8.0" />
#
# <meta name="keywords" content=" Is Die Hard (1988) overrated?, movie forums,movie forum,movie reviews,movies,movie board,movie discussion,chat,movie awards" />
# <meta name="description" content=" Is Die Hard (1988) overrated? General Movie Discussion" />
#
#
#
# <!-- CSS Stylesheet -->
# <style type="text/css" id="vbulletin_css">
# /**
# * vBulletin 3.8.0 CSS
# * Style: 'Radioactive'; Style ID: 17
# */
# body
# {
# 	font: 16px Arial, Helvetica, sans-serif;
# 	margin: 0px 0px 0px 0px;
# 	scrollbar-3dlight-color: #000;
# 	scrollbar-arrow-color: #FFFFFF;
# 	scrollbar-base-color: #000;
# 	scrollbar-darkshadow-color: #404040;
# 	scrollbar-face-color: #262626;
# 	scrollbar-highlight-color: #595959;
# 	scrollbar-shadow-color: #000;
# }
# td, th, p, li
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .tborder
# {
# 	color: #000000;
# 	border: 0px solid #000000;
# }
# .tcat
# {
# 	color: #CCC;
# 	font-size: 16px;
# 	font-family: 'Futura', sans-serif;
# }
# .tcat a:link, .tcat_alink
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .tcat a:visited, .tcat_avisited
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .tcat a:hover, .tcat a:active, .tcat_ahover
# {
# 	color: #FFFFAE;
# 	text-decoration: underline;
# }
# .thead
# {
# 	color: #FFFFFF;
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .thead a:link, .thead_alink
# {
# 	color: #FFFFFF;
# }
# .thead a:visited, .thead_avisited
# {
# 	color: #FFFFFF;
# }
# .thead a:hover, .thead a:active, .thead_ahover
# {
# 	color: #FFFFAE;
# }
# .tfoot
# {
# 	background: #373737;
# 	color: #FFFFFF;
# }
# .tfoot a:link, .tfoot_alink
# {
# 	color: #FFFFFF;
# }
# .tfoot a:visited, .tfoot_avisited
# {
# 	color: #FFFFFF;
# }
# .tfoot a:hover, .tfoot a:active, .tfoot_ahover
# {
# 	color: #FFFFAE;
# }
# .alt1, .alt1Active
# {
# 	color: #CCC;
# 	background: url(/images/blackpixel_40.png);
# }
# .alt2, .alt2Active
# {
# 	color: #CCC;
# }
# .inlinemod
# {
# 	background: #FFFFCC;
# 	color: #000000;
# }
# .wysiwyg
# {
# 	background: #E4E4E4;
# 	color: #000000;
# 	font-family: Arial, Helvetica, sans-serif;
# 	background-repeat: no-repeat;
# 	background-color: #E4E4E4;
# }
# textarea, .bginput
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .bginput option, .bginput optgroup
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .button
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .smallfont
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .time
# {
# 	color: #666666;
# }
# .navbar
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .highlight
# {
# 	color: #FF0000;
# 	font-weight: bold;
# }
# .fjsel
# {
# 	background: #333333;
# 	color: #D4D4D4;
# }
# .fjdpth0
# {
# 	background: #D4D4D4;
# 	color: #000000;
# }
# .panel
# {
# 	color: #999;
# 	padding: 10px;
#
# }
# legend
# {
# 	color: #000000;
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .vbmenu_control
# {
# 	background: #000;
# 	color: #E1E1E1;
# 	font-family: Arial, sans-serif;
# 	padding: 3px 6px 3px 6px;
# 	white-space: nowrap;
# 	border: 1px solid #777;
# 	border-radius: 7px 7px 0 0;
# }
# .vbmenu_control a:link, .vbmenu_control_alink
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .vbmenu_control a:visited, .vbmenu_control_avisited
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .vbmenu_control a:hover, .vbmenu_control a:active, .vbmenu_control_ahover
# {
# 	color: #FFFFAE;
# 	text-decoration: underline;
# }
# .vbmenu_popup
# {
# 	background: #FFFFFF;
# 	color: #000000;
# 	border: solid 1px #000000;
# 	text-align: left;
# }
# .vbmenu_option
# {
# 	background: #CCCCCC;
# 	color: #000000;
# 	font-family: Arial, Helvetica, sans-serif;
# 	white-space: nowrap;
# 	cursor: hand;
# }
# .vbmenu_option a:link, .vbmenu_option_alink
# {
# 	color: #005C00;
# 	text-decoration: none;
# }
# .vbmenu_option a:visited, .vbmenu_option_avisited
# {
# 	color: #005C00;
# 	text-decoration: none;
# }
# .vbmenu_option a:hover, .vbmenu_option a:active, .vbmenu_option_ahover
# {
# 	color: #CA5100;
# 	text-decoration: none;
# }
# .vbmenu_hilite
# {
# 	background: #585858 url(/community/images/menubg.gif) repeat-x top left;
# 	color: #FFFFFF;
# 	font-family: Arial, Helvetica, sans-serif;
# 	white-space: nowrap;
# 	cursor: hand;
# }
# .vbmenu_hilite a:link, .vbmenu_hilite_alink
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .vbmenu_hilite a:visited, .vbmenu_hilite_avisited
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .vbmenu_hilite a:hover, .vbmenu_hilite a:active, .vbmenu_hilite_ahover
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .vbmenu_popup .thead {
#   text-align: center;
#   color: #383838;
#   text-decoration: underline;
# }
# /* ***** active table cells (IE only) ***** */
# /* .alt1Active, .alt2Active { behavior: url(http://www.movieforums.com/community/clientscript/activecell.htc); } */
# </style>
# <link rel="stylesheet" type="text/css" href="https://www.movieforums.com/community/clientscript/vbulletin_important.css?v=380" />
#
#
# <!-- / CSS Stylesheet -->
#
# <script type="text/javascript" src="/community/clientscript/yui/yahoo-dom-event/yahoo-dom-event.js?v=380"></script>
# <script type="text/javascript" src="/community/clientscript/yui/connection/connection-min.js?v=380"></script>
#
# <script type="text/javascript">
# <!--
# var SESSIONURL = "s=cdc988b455c2e529861d3d4f51f35e13&";
# var SECURITYTOKEN = "guest";
# var IMGDIR_MISC = "images/misc";
# var vb_disable_ajax = parseInt("0", 10);
# // -->
# </script>
# <script type="text/javascript" src="/community/clientscript/vbulletin_global.js?v=380"></script>
#
#
#
#
# <link rel="alternate" type="application/rss+xml" title="Movie Forums RSS Feed" href="external.php?type=RSS2" />
#
# <link rel="alternate" type="application/rss+xml" title="Movie Forums - General Movie Discussion - RSS Feed" href="external.php?type=RSS2&amp;forumids=2" />
#
#
#
# <script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.3/jquery.min.js" type="text/javascript"></script>
#
# <script src="/js/fastclick.js" type="application/javascript"></script>
#
# <script type="text/javascript" src="/js/tipsy/jquery.tipsy.js"></script>
# <link rel="stylesheet" type="text/css" href="/js/tipsy/tipsy.css?v=17" media="screen" />
#
# <link rel="stylesheet" type="text/css" href="/css/style.css?v=297" />
#
# <script type="text/javascript" src="/js/global.js?v=110"></script>
#
# <!--[if lte IE 9]>
# <link rel="stylesheet" type="text/css" href="/css/style-ie.css?v=26" />
# <script src="/js/html5shiv.js"></script>
# <![endif]-->
#
# <!--[if lt IE 8]>
# <link rel="stylesheet" type="text/css" href="/css/style-ie7.css?v=22"/>
# <![endif]-->
#
# <script src="/js/jquery.waitforimages.js" type="text/javascript"></script>
# <script src="/js/jquery.prettyembed.js?v=10" type="text/javascript"></script>
#
#
#
# <link rel="stylesheet" type="text/css" href="/css/style-thread.css?v=111" />
# <link href="/js/bootstrap.icons.css" rel="stylesheet" />
# <link href="/js/jquery.toolbars.css?v=8" rel="stylesheet" />
# <script src="/js/toolbar-master/jquery.toolbar.js?v=55"></script>
#
# <script src="/community/clientscript/vbulletin_post_loader.js?v=380" type="text/javascript"></script>
# <script src="/community/spoilers.js" type="text/javascript"></script>
# <script src="/js/jquery.autosize.js" type="text/javascript"></script>
#
# <script async type="text/javascript" src="https://thisiswaldo.com/ad_delivery?site_id=992"></script>
#
# <script type="text/javascript" src="/js/fancybox/jquery.fancybox.pack.js"></script>
# <link rel="stylesheet" type="text/css" href="/js/fancybox/jquery.fancybox.min.css?v=2" media="screen"/>
#
#
# </head>
#
# <body>
#
#
#
#
#
# <div class="hidden">
# <img src="/images/logo_hover.png" class="hidden" />
# <img src="/images/blackpixel_80.png" class="hidden" />
# </div>
#
# <script type="text/javascript">
# var doc = document.documentElement;
# doc.setAttribute('data-useragent', navigator.userAgent);
#
# $(document).ready(function() {
#   $("#headernotice").click(function() {
#     window.location = 'http://www.movieforums.com/community/showthread.php?t=49083';
#   });
#
# });
# </script>
#
#
# <link rel="icon" href="/animated_favicon_32px.gif" type="image/gif" >
#
#
#
#
# <div id="wrapper" class="relative">
#   <header>
#     <div id="movieforums"><a href="https://www.movieforums.com" title="Movie Forums">Movie Forums</a></div>
#     <a href="https://www.movieforums.com" title="Movie Forums" id="logowrapper"><div id="logo">&nbsp;</div></a>
#   </header>
#
#   <div align="center" id="headerbar">
#     <nav role="navigation" class="relative" align="center">
#       <a href="/movies" id="movies" title="Movies">Movies</a>
#       <a href="/essays" id="essays" title="Essays">Essays</a>
#       <a href="/reviews" id="reviews" title="Movie Reviews">Reviews</a>
#       <a href="/community" id="forums" title="Movie Forums">Forums</a>
#       <a href="/lists" id="lists" title="Lists">Lists</a>
#       <a href="/boxoffice" id="bo" title="Box Office">Box Office</a>
#       <a href="/community/quiz.php" id="quizzes" title="Movie Quizzes">Quizzes</a>
#
#       <div class="subnav" align="left">
#
#       <div id="headersearch" title="Show Search">
#         <?xml version="1.0" ?><svg xmlns="http://www.w3.org/2000/svg" version="1.1" style="left: 10px; top: 10px; position: absolute; z-index: 99999;" height="22" width="22" viewbox="0 0 1024 973" xmlns="http://www.w3.org/2000/svg"><path fill="#B9B591" d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z"/></svg>
#       </div>
#
#       <div id="searchbar">
#         <form action="/community/search.php?do=process" method="post">
#           <input type="hidden" name="do" value="process" />
#           <input type="hidden" name="quicksearch" value="1" />
#           <input type="hidden" name="childforums" value="1" />
#           <input type="hidden" name="exactname" value="1" />
#           <input type="hidden" name="s" value="cdc988b455c2e529861d3d4f51f35e13" />
#           <input type="hidden" name="securitytoken" value="guest" />
#           <input type="hidden" name="titleonly" value="1" />
#           <input type="text" name="query" id="searchfield" />
#           <input type="submit" id="searchsubmit" value="SEARCH" />
#         </form>
#
#         <a href="#" id="closesearch" style="top: 3px;" title="Close Search"><?xml version="1.0" ?><svg height="22" width="22" viewBox="0 0 32 32" xmlns="http://www.w3.org/2000/svg"><path fill="#FFFFFF" d="M4 8 L8 4 L16 12 L24 4 L28 8 L20 16 L28 24 L24 28 L16 20 L8 28 L4 24 L12 16 z"/></svg></a>
#       </div>
#
#
#
#         <div id="header_avatar"></div>
#
#         <a href="/community/search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=getdaily" class="subnav_link">Today's Posts</a>
#
#         <a href="/community/shoutbox.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;" class="subnav_link">The Shoutbox</a>
#
#
#         <a href="/community/register.php??s=cdc988b455c2e529861d3d4f51f35e13" class="subnav_link" rel="nofollow">Register</a>
#
#
#
#         <a href="/community/login_plain.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;" class="subnav_link" id="loginlink">Log In</a>
#
#         <div id="login_open" class="hidden">
#           <div id="login_wrapper">
#             <div id="login_content">
#               <div id="login">
#                 <form action="/community/login.php?do=login" method="post" onsubmit="md5hash(vb_login_password, vb_login_md5password, vb_login_md5password_utf, 0)">
#                 <script type="text/javascript" src="/community/clientscript/vbulletin_md5.js?v=380"></script>
#
#                   <div align="right" style="margin-bottom: 8px;">
#                     <div class="right"><label for="cb_cookieuser_navbar" id="cookielabel"><span>Save?</span></label><input type="checkbox" name="cookieuser" value="1" tabindex="103" id="cb_cookieuser_navbar" checked="checked" accesskey="c" style="margin-top: 9px;" /></div>
#                     <span class="loginfield_label">Username:</span><input type="text" name="vb_login_username" accesskey="u" tabindex="101" id="navbar_username" />
#                   </div>
#
#                   <div align="right">
#                     <div class="right"><input type="submit" name="submit" tabindex="104" class="submitbutton loginbutton" value="Login" /></div>
#                     <span class="loginfield_label">Password:</span><input type="password" tabindex="102" name="vb_login_password" id="navbar_password" />
#                   </div>
#
#                   <input type="hidden" name="s" value="cdc988b455c2e529861d3d4f51f35e13" />
#                   <input type="hidden" name="securitytoken" value="guest" />
#                   <input type="hidden" name="do" value="login" />
#                   <input type="hidden" name="vb_login_md5password" />
#                   <input type="hidden" name="vb_login_md5password_utf" />
#                 </form>
#
#                 <br class="clear" />
#
#                 <div align="center" id="registerdiv">
#                   <a href="/community/register.php?cdc988b455c2e529861d3d4f51f35e13" class="notification">Register Today!</a>
#                 </div>
#               </div>
#             </div>
#           </div>
#         </div>
#
#       </div>
#     </nav>
#   </div>
#
#   <div id="container">
#     <div id="content">
#
#
#
#
# <input type="hidden" name="hidden_postid" id="hidden_postid" value="" />
#
# <a name="poststop" id="poststop"></a>
#
# <h1>Is Die Hard (1988) overrated?</h1>
#
# <div class="inforum light_textshadow" itemscope itemtype="http://data-vocabulary.org/Breadcrumb">
#   &rarr; in <a href="general-movie-discussion.html" class="light" itemprop="url"><span itemprop="title">General Movie Discussion</span></a>
#
#
# </div>
#
# <div class="right inforum light_textshadow">
#   <a href="#goto_threadtools" class="light" id="threadtools">Tools</a>
#   &nbsp;
#
#   &nbsp;
#
#
# </div>
#
# <hr class="clear" style="background: #585858; margin-bottom: 19px;" />
#
# <div>
#   <div class="right">
#     <div class="pagenav pagenav_thread">
#   <span class="pagecount">Page 1 of 5</span>
#
#   <div class="pagenav_inside">
#     <span class="curpage" title="Showing results 1 to 20 of 83">1</span><a class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=2" title="Show results 21 to 40 of 83">2</a><a rel="next" class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=2" title="Next Page - Results 21 to 40 of 83">&raquo;</a><a class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=5" title="Last Page - Results 81 to 83 of 83">Last <strong>&raquo;</strong></a>
#   </div>
#
#
# </div>
#
#
#   </div>
#
#
#     <div id="button"><a href="newreply.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newreply&amp;noquote=1&amp;p=1695060" rel="nofollow" title="Post Reply"><img src="/images/reel_avatar_38x38.png" /> Post Reply</a></div>
#
# </div>
#
# <br class="clear" />
#
#
#
# <!-- toolbar -->
#
#
#
# <br />
#
#
#
#
# <!-- end content table -->
#
# <!-- / end content table -->
#
#
#
#
#
# <div id="posts"><!-- post #1695060 -->
#
#
# 	<div id="edit1695060" style="padding:0px 0px 6px 0px">
# 	<!-- this is not the last post shown on the page -->
#
#
#
#
# <a name="post1695060"></a>
#
#
#
#
#
#
# <div class="post" id="post1695060" >
#
#
#   <br /><br />
#
#   <div class="userinfo left clear" style="padding-top: 0;">
#     <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
#     <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481" title="View ironpony's Profile" class="username" style="padding-right: 10px;"><span>i</span>ronpony</a>
#
#
#     </div>
#
#     <div class="thumb noavatar"
#
#       <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481"><img src="/images/reel_avatar_89x89.png" width="89" height="89" alt="ironpony's Avatar" style="margin-bottom: 1px;border: 0; box-shadow: none; width: 89px; height: 89px;" class="lightshadow" data-postid="1695060" /></a>
#
#
#       <div class="userlinks" style="width: -2px; height: -2px;">
#         <a href="">
#           <div class="padded" style="">
#
#             <div class="posticons_hover" style=""><a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481" title="View ironpony's Profile" style=""><?xml version="1.0" standalone="no" ?><svg height="16" width="16" viewBox="0 0 512 512" preserveAspectRatio="xMidYMid meet" version="1.1" xmlns="http://www.w3.org/2000/svg" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" style="left: 5px; enable-background: new 0 0 512 512;"><path fill="#FFFFFF" d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z"/></svg> Profile</a></div>
#
#             <div class="posticons_hover" style=""><a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=96481" title="Show ironpony's Posts" style=""><?xml version="1.0" standalone="no" ?><svg height="14" width="14"  viewbox="0 0 1024 973" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" version="1.1" style="left: 7px;"><path fill="#FFFFFF" d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z"/></svg> Posts</a></div>
#
#             <div class="posticons_hover"><a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=96481" title="Send ironpony a Message" style=""><?xml version="1.0" standalone="no" ?><svg width="32" height="38" viewBox="140 170 500 500" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" version="1.1" xmlns:xlink="http://www.w3.org/1999/xlink" enable-background="new 140 170 500 500"  style="left: 6px;"><g><path fill="#FFFFFF" d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z"/></g></svg>Msg</a></div>
#           </div>
#         </a>
#       </div>
#
#     </div>
#
#     <div class="usertitle clear">Registered User</div>
#   </div>
#
#   <div class="postcontent relative" id="td_post_1695060">
#
#     <div class="banner right" title="This post has been upvoted 1 time" id="reptotal_1695060">
#
#
#
#       <span>
#
#       +1
#
#
#
#
#
#       </span>
#
#
#     </div>
#
#     <div class="postdate">
#       <a href="showthread.php?p=1695060#post1695060" title="4-29-17 at 6:53 PM" rel="nofollow">04-29-17</a>
#     </div>
#
#     <div class="posttext">
#
#
#
#       <div id="post_message_1695060">
#       After seeing it a few times over the years, I still don't get all the hype. I mean the action scenes are good, but I find the story to be an average action movie plot, to be quite honest.<br />
# <br />
# There isn't a huge deal of character change, the heroes and villains are very black and white, and some parts of the plot I find unconvincing. I mean I know it's an action movie, but this is rated so high by many people, that I can't help to pick on illogics in the plot more so, because of how highly praised it is.<br />
# <br />
# <br />
# SPOILERS<br />
# <br />
# <br />
# Basically when Kristoff is looking for McClane, McClane sneaks up on Kristoff and points his gun at Christoff's head. <br />
# <br />
# He tells Kristoff to drop his gun, and Kristoff says &quot;You won't hurt me, there are rules for policemen&quot;. McClane then says that's what my Captain keeps telling me. He then pistol whips Kristoff, and then tries to wrestle Kristoff's Machine gun, out of his hands.<br />
# <br />
# But why! Why would a cop try to fight someone, who has a machine gun, when the cop can just shoot him? It's not like McClane has any handcuffs on him to neutralize Kristoff, so what is he going to do, if Kristoff surrenders?<br />
# <br />
# Kristoff refused to drop the gun, and any realistic person would know that a cop would just shoot you in this situation and not attempt to wrestle a machine gun out of your hand.<br />
# <br />
# Later on, McClane is trying to get the cop's attention from out the window and another goon comes to try stop him. McClane again tells the guy to put the gun down, but why? It's not like he can keep him held prisoner in situation like that.<br />
# <br />
# He does this with Hans later as well instead of just shooting Hans.<br />
# <br />
# I also feel that some of the dialogue is really dumb in this movie, like when the Deputy Chief cop says that the body that fell from the window that was full of bullet holes, must have been a depressed stockbroker. Really???<br />
# <br />
# And I also feel that the Thornberg character, was not necessary to the plot and didn't really add anything really. I first saw Die Hard on edited television way back, and back then, all of Thornberg's scenes were cut, accept for the video footage, on the news that Holly saw, which tipped Hans' off. Having seen the uncut version of the movie, I feel that Thornberg being turned into an actual subplot character, doesn't really add anything.<br />
# <br />
# We don't need to know the personal squabbles of the news guy, who's only role in the plot was to unintentionally tip the villain off. It made perfect sense on TV to cut all his scenes out accept the video footage one, that tipped Hans off.<br />
# <br />
# And a lot of people out there say that Hans Gruber is the greatest movie villain ever, if not the greatest, but I dunno... I mean he doesn't really go through any huge personal character changes, and he is really just a bankrobber, with no hugely personal stakes in his goal.<br />
# <br />
# McClane is good character, but I feel he is doesn't really do anything to be go through much of a change, and he is not pushed to his moral limits either in the end. But maybe this is not a bad thing, and maybe he doesn't have to.<br />
# <br />
# So I feel the movie, in spite of having really good action scenes, is just not as well written as it could be, and is more of an average, perhaps decent action movie in terms of story and script.<br />
# <br />
# What do you think?
#       </div>
#
#
#
#
#
#
#
#
#
#
#     </div>
#     <br />
#
#   </div>
# </div>
#
#
#
#
#
#
#
#
#
#
# 	</div>
#
#
# <!-- / post #1695060 -->
#
#
#
#
# <div style="margin: 25px 0 50px 155px; display: none;">
#
# </div>
#
#
#
#
#
#
#
#
# <div class="post" id="post_ad">
#   <br /><br />
#
#   <div class="userinfo left clear" style="padding-top: 0;">
#     <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
#       <a class="username noclick" style="padding-right: 10px;"><span>A</span>dvertisement</a> <a href="#" class="favs" id="favlink_ad" data-userid="ad" title="Favorite Movies"><?xml version="1.0" ?><svg height="14px" version="1.1" viewBox="0 0 16 16" width="14px" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink"><title/><defs/><g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125" /></g></g></svg></a>
#     </div>
#
#     <div class="thumb noavatar">
#       <a class="noclick"><img src="/images/reel_avatar_89x89.png" width="89" height="89" style="margin-bottom: 1px; border: 0; box-shadow: none;" /></a>
#     </div>
#
#     <div class="usertitle clear">"Money won is twice as sweet as money earned."</div>
#   </div>
#
#   <div class="postcontent relative" id="td_post_ad">
#
#     <div class="posttext">
#       <div id="post_message_ad">
#         <div id="waldo-tag-993"></div>
#       </div>
#     </div>
#
#     <br />
#
#   </div>
# </div>
#
# <div id="favs_ad" class="hidden">
#   <div>
#     <a href="#" class="closetip notextshadow" title="Close">X</a>
#     <h4 style="display: inline-block;">Favorite Movies</h4>
#   </div>
#
#   <ol>
#     <li><a href="favoritesearch.php?movieid=11873" title="Find others users who listed &quot;The Color of Money&quot;">The Color of Money</a></li>
#
#     <li><a href="favoritesearch.php?movieid=55448" title="Find others users who listed &quot;Money for Nothing&quot;">Money for Nothing</a></li>
#
#     <li><a href="favoritesearch.php?movieid=10466" title="Find others users who listed &quot;The Money Pit&quot;">The Money Pit</a></li>
#
#     <li><a href="favoritesearch.php?movieid=3090" title="Find others users who listed &quot;The Treasure Of The Sierra Madre&quot;">The Treasure Of The Sierra Madre</a></li>
#
#     <li><a href="favoritesearch.php?movieid=6463" title="Find others users who listed &quot;Other Peoples Money&quot;">Other Peoples Money</a></li>
#
#     <li><a href="favoritesearch.php?movieid=11064" title="Find others users who listed &quot;Brewsters Millions&quot;">Brewsters Millions</a></li>
#
#     <li><a href="favoritesearch.php?movieid=524" title="Find others users who listed &quot;Casino&quot;">Casino</a></li>
#
#     <li><a href="favoritesearch.php?movieid=10673" title="Find others users who listed &quot;Wall Street&quot;">Wall Street</a></li>
#
#     <li><a href="favoritesearch.php?movieid=1621" title="Find others users who listed &quot;Trading Places&quot;">Trading Places</a></li>
#
#     <li><a href="favoritesearch.php?movieid=9504" title="Find others users who listed &quot;Glengary Glen Ross&quot;">Glengary Glen Ross</a></li>
#   </ol>
# </div>
#
# <!-- post #1695061 -->
#
#
# 	<div id="edit1695061" style="padding:0px 0px 6px 0px">
# 	<!-- this is not the last post shown on the page -->
#
#
#
#
# <a name="post1695061"></a>
#
#
#
#
#
#
# <div class="post" id="post1695061" >
#
#
#   <br /><br />
#
#   <div class="userinfo left clear" style="padding-top: 0;">
#     <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
#     <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=75073" title="View Blix the Goblin's Profile" class="username" style="font-size: 1.3em; padding-right: 10px;"><span>B</span>lix the Goblin</a> <a href="#" class="favs" id="favlink_1695061" data-userid="75073" title="Favorite Movies">
#
#     <?xml version="1.0" standalone="no" ?>
#     <svg height="14" width="14" viewBox="0 0 16 16" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" version="1.1" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <switch>
#         <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125" /></g></g>
#
#         <foreignObject>
#           <img src="/images/fallbacks/fallback-favs.png" />
#         </foreignObject>
#       </switch>
#     </svg></a>
#
#     <a href="#" class="userlists" id="listlink_1695061" data-userid="75073" title="User Lists">
#
#     <?xml version="1.0" standalone="no" ?>
#     <svg id="list-svg" height="16" width="16" viewbox="0 0 1024 768" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" version="1.1">
#       <switch>
#         <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"/>
#
#         <foreignObject>
#           <img src="/images/fallbacks/fallback-lists.png" />
#         </foreignObject>
#       </switch>
#     </svg></a>
#     </div>
#
#     <div class="thumb" style="width: 105px; height: 90px;"
#
#       <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=75073"><img src="customavatars/avatar75073_2.gif" alt="Blix the Goblin's Avatar" style="margin-bottom: 1px; width: 105px; height: 90px;" class="lightshadow" data-postid="1695061" /></a>
#
#
#       <div class="userlinks" style="width: 103px; height: 88px;">
#         <a href="">
#           <div class="padded" style="">
#
#             <div class="posticons_hover" style=""><a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=75073" title="View Blix the Goblin's Profile" style=""><?xml version="1.0" standalone="no" ?><svg height="16" width="16" viewBox="0 0 512 512" preserveAspectRatio="xMidYMid meet" version="1.1" xmlns="http://www.w3.org/2000/svg" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" style="left: 5px; enable-background: new 0 0 512 512;"><path fill="#FFFFFF" d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z"/></svg> Profile</a></div>
#
#             <div class="posticons_hover" style=""><a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=75073" title="Show Blix the Goblin's Posts" style=""><?xml version="1.0" standalone="no" ?><svg height="14" width="14"  viewbox="0 0 1024 973" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" version="1.1" style="left: 7px;"><path fill="#FFFFFF" d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z"/></svg> Posts</a></div>
#
#             <div class="posticons_hover"><a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=75073" title="Send Blix the Goblin a Message" style=""><?xml version="1.0" standalone="no" ?><svg width="32" height="38" viewBox="140 170 500 500" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" version="1.1" xmlns:xlink="http://www.w3.org/1999/xlink" enable-background="new 140 170 500 500"  style="left: 6px;"><g><path fill="#FFFFFF" d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z"/></g></svg>Message</a></div>
#           </div>
#         </a>
#       </div>
#
#     </div>
#
#     <div class="usertitle clear">The most loathsome of all goblins</div>
#   </div>
#
#   <div class="postcontent relative" id="td_post_1695061">
#
#     <div class="banner right" title="This post has been upvoted 1 time" id="reptotal_1695061">
#
#
#
#       <span>
#
#       +1
#
#
#
#
#
#       </span>
#
#
#     </div>
#
#     <div class="postdate">
#       <a href="showthread.php?p=1695061#post1695061" title="4-29-17 at 6:55 PM" rel="nofollow">04-29-17</a>
#     </div>
#
#     <div class="posttext">
#
#
#
#       <div id="post_message_1695061">
#       I think it's great, but I prefer Die Hard with a Vengeance
#       </div>
#
#
#
#
#
#
#
#
#
#
#     </div>
#     <br />
#
#   </div>
# </div>
#
#
# <div id="favs_75073" class="hidden">
#   <div>
#     <a href="#" class="closetip notextshadow" title="Close">X</a>
#     <h4 style="display: inline-block;">Favorite Movies</h4>
#   </div>
#
#
#   <ol>
#       <li><a href="favoritesearch.php?movieid=11976" title="Find others users who listed &quot;Legend&quot;">Legend</a></li>
#     <li><a href="favoritesearch.php?movieid=15794" title="Find others users who listed &quot;White Heat&quot;">White Heat</a></li>
#     <li><a href="favoritesearch.php?movieid=900" title="Find others users who listed &quot;Bringing Up Baby&quot;">Bringing Up Baby</a></li>
#     <li><a href="favoritesearch.php?movieid=78" title="Find others users who listed &quot;Blade Runner&quot;">Blade Runner</a></li>
#     <li><a href="favoritesearch.php?movieid=5483" title="Find others users who listed &quot;Lisa and the Devil&quot;">Lisa and the Devil</a></li>
#     <li><a href="favoritesearch.php?movieid=691" title="Find others users who listed &quot;The Spy Who Loved Me&quot;">The Spy Who Loved Me</a></li>
#     <li><a href="favoritesearch.php?movieid=10907" title="Find others users who listed &quot;The Adventures of Robin Hood&quot;">The Adventures of Robin Hood</a></li>
#     <li><a href="favoritesearch.php?movieid=10428" title="Find others users who listed &quot;Hackers&quot;">Hackers</a></li>
#     <li><a href="favoritesearch.php?movieid=9434" title="Find others users who listed &quot;Grosse Pointe Blank&quot;">Grosse Pointe Blank</a></li>
#     <li><a href="favoritesearch.php?movieid=284" title="Find others users who listed &quot;The Apartment&quot;">The Apartment</a></li>
#
#   </ol>
#
# </div>
#
#
#
# <div id="lists_75073" class="hidden">
#   <div>
#     <a href="#" class="closetip notextshadow" title="Close">X</a>
#     <h4 style="display: inline-block;">User Lists</h4>
#   </div>
#
#     <div class="clear" style="width: 220px; padding: 4px 8px;">
#     <span class="right" style="font-size: 0.9em;">1%</span>
#
#     <a href="/lists/afis_100_years_100_movies/75073.html" title="View the movies on this list that Blix the Goblin has seen" style="font-size: 0.9em;">100 Years...100 Movies</a>
#   </div>
#   <div class="clear" style="width: 220px; padding: 4px 8px;">
#     <span class="right" style="font-size: 0.9em;">1%</span>
#
#     <a href="/lists/afis_100_years_100_laughs/75073.html" title="View the movies on this list that Blix the Goblin has seen" style="font-size: 0.9em;">100 Years...100 Laughs</a>
#   </div>
#   <div class="clear" style="width: 220px; padding: 4px 8px;">
#     <span class="right" style="font-size: 0.9em;">0%</span>
#
#     <a href="/lists/afis_100_years_100_thrills/75073.html" title="View the movies on this list that Blix the Goblin has seen" style="font-size: 0.9em;">100 Years...100 Thrills</a>
#   </div>
#   <div class="clear" style="width: 220px; padding: 4px 8px;">
#     <span class="right" style="font-size: 0.9em;">1%</span>
#
#     <a href="/lists/afis_100_years_100_passions/75073.html" title="View the movies on this list that Blix the Goblin has seen" style="font-size: 0.9em;">100 Years...100 Passions</a>
#   </div>
#   <div class="clear" style="width: 220px; padding: 4px 8px;">
#     <span class="right" style="font-size: 0.9em;">0%</span>
#
#     <a href="/lists/afis_100_years_100_cheers/75073.html" title="View the movies on this list that Blix the Goblin has seen" style="font-size: 0.9em;">100 Years...100 Cheers</a>
#   </div>
#   <div class="clear" style="width: 220px; padding: 4px 8px;">
#     <span class="right" style="font-size: 0.9em;">0%</span>
#
#     <a href="/lists/afis_100_years_of_musicals/75073.html" title="View the movies on this list that Blix the Goblin has seen" style="font-size: 0.9em;">100 Years of Musicals</a>
#   </div>
#
#
#
#   <hr />
#   <div style="text-align: center;"><a href="/lists/viewall/75073.html" style="font-size: 0.9em;">View All Lists</a></div>
#
# </div>
#
#
#
#
#
#
#
# 	</div>
#
#
# <!-- / post #1695061 --><!-- post #1695062 -->
#
#
# 	<div id="edit1695062" style="padding:0px 0px 6px 0px">
# 	<!-- this is not the last post shown on the page -->
#
#
#
#
# <a name="post1695062"></a>
#
#
#
#
#
#
# <div class="post" id="post1695062" >
#
#
#   <br /><br />
#
#   <div class="userinfo left clear" style="padding-top: 0;">
#     <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
#     <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" title="View Dani8's Profile" class="username" style="padding-right: 10px;"><span>D</span>ani8</a> <a href="#" class="favs" id="favlink_1695062" data-userid="95651" title="Favorite Movies">
#
#     <?xml version="1.0" standalone="no" ?>
#     <svg height="14" width="14" viewBox="0 0 16 16" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" version="1.1" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <switch>
#         <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125" /></g></g>
#
#         <foreignObject>
#           <img src="/images/fallbacks/fallback-favs.png" />
#         </foreignObject>
#       </switch>
#     </svg></a>
#
#
#     </div>
#
#     <div class="thumb" style="width: 77px; height: 90px;"
#
#       <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651"><img src="customavatars/avatar95651_1.gif" alt="Dani8's Avatar" style="margin-bottom: 1px; width: 77px; height: 90px;" class="lightshadow" data-postid="1695062" /></a>
#
#
#       <div class="userlinks" style="width: 75px; height: 88px;">
#         <a href="">
#           <div class="padded" style="left: 4px;">
#
#             <div class="posticons_hover" style=""><a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" title="View Dani8's Profile" style=""><?xml version="1.0" standalone="no" ?><svg height="16" width="16" viewBox="0 0 512 512" preserveAspectRatio="xMidYMid meet" version="1.1" xmlns="http://www.w3.org/2000/svg" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" style="left: 5px; enable-background: new 0 0 512 512;"><path fill="#FFFFFF" d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z"/></svg> Profile</a></div>
#
#             <div class="posticons_hover" style=""><a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=95651" title="Show Dani8's Posts" style=""><?xml version="1.0" standalone="no" ?><svg height="14" width="14"  viewbox="0 0 1024 973" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" version="1.1" style="left: 7px;"><path fill="#FFFFFF" d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z"/></svg> Posts</a></div>
#
#             <div class="posticons_hover"><a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=95651" title="Send Dani8 a Message" style=""><?xml version="1.0" standalone="no" ?><svg width="32" height="38" viewBox="140 170 500 500" preserveAspectRatio="xMidYMid meet" xmlns="http://www.w3.org/2000/svg" version="1.1" xmlns:xlink="http://www.w3.org/1999/xlink" enable-background="new 140 170 500 500"  style="left: 6px;"><g><path fill="#FFFFFF" d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z"/></g></svg>Msg</a></div>
#           </div>
#         </a>
#       </div>
#
#     </div>
#
#     <div class="usertitle clear">You can't win an argument just by being right!</div>
#   </div>
#
#   <div class="postcontent relative" id="td_post_1695062">
#
#     <div class="banner right" title="This post has been upvoted 1 time" id="reptotal_1695062">
#
#
#
#       <span>
#
#       +1
#
#
#
#
#
#       </span>
#
#
#     </div>
#
#     <div class="postdate">
#       <a href="showthread.php?p=1695062#post1695062" title="4-29-17 at 6:56 PM" rel="nofollow">04-29-17</a>
#     </div>
#
#     <div class="posttext">
#
#
#
#       <div id="post_message_1695062">
#       I dont really think there's any such thing as an overrated movie. Just because I may not enjoy a film so much does not mean critics and viewers dont get pumped for it. Die Hard I thought was great fun. Gone Girl is one I mentioned earlier where I dont get the hype, but I'm not going to label it overrated.
#       </div>
#
#
#
#
#
#
#
#
#
#
#     </div>
#     <br />
#
#   </div>
# </div>
#
#
# <div id="favs_95651" class="hidden">
#   <div>
#     <a href="#" class="closetip notextshadow" title="Close">X</a>
#     <h4 style="display: inline-block;">Favorite Movies</h4>
#   </div>
#
#
#   <ol>
#       <li><a href="favoritesearch.php?movieid=60270" title="Find others users who listed &quot;Wish You Were Here&quot;">Wish You Were Here</a></li>
#     <li><a href="favoritesearch.php?movieid=48340" title="Find others users who listed &quot;Sanctum&quot;">Sanctum</a></li>
#     <li><a href="favoritesearch.php?movieid=66113" title="Find others users who listed &quot;In Her Skin&quot;">In Her Skin</a></li>
#     <li><a href="favoritesearch.php?movieid=66125" title="Find others users who listed &quot;Red Dog&quot;">Red Dog</a></li>
#     <li><a href="favoritesearch.php?movieid=287903" title="Find others users who listed &quot;Krampus&quot;">Krampus</a></li>
#     <li><a href="favoritesearch.php?movieid=333386" title="Find others users who listed &quot;The Duel&quot;">The Duel</a></li>
#     <li><a href="favoritesearch.php?movieid=331583" title="Find others users who listed &quot;The Whole Truth&quot;">The Whole Truth</a></li>
#     <li><a href="favoritesearch.php?movieid=9774" title="Find others users who listed &quot;Kokoda&quot;">Kokoda</a></li>
#     <li><a href="favoritesearch.php?movieid=390043" title="Find others users who listed &quot;The Hitman's Bodyguard&quot;">The Hitman's Bodyguard</a></li>
#
#   </ol>
#
# </div>
#
#
#
#
#
#
#
#
#
# 	</div>
#
#
# <!-- / post #1695062 --><!-- post #1695063 -->
#
#
# 	<div id="edit1695063" style="padding:0px 0px 6px 0px">
# 	<!-- this is not the last post shown on the page -->
#
#
#
#
# <a name="post1695063"></a>
#
#
#
#
#
#
# <div class="post" id="post1695063" >
#
#
#   <br /><br />
#
#   <div class="userinfo left clear" style="padding-top: 0;">
#     <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
#     <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=83561" title="View rambond's Profile" class="username" style="padding-right: 10px;"><span>r</span>ambond</a>
#
#
#     </div>
#
#     <div class="thumb" style="width: 90px; height: 90px;"
#
#       <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=83561"><img src="customavatars/avatar83561_1.gif" alt="rambond's Avatar" style="margin-bottom: 1px; width: 90px; height: 90px;" class="lightshadow" data-postid="1695063" /></a>
#
#
#       <div class="userlinks" style="width: 88px; height: 88px;">
#         <a href="">
#           <div class="padded" style="">
#
# ...
#
#
# <div class="right"><div class="pagenav pagenav_thread">
#   <span class="pagecount">Page 1 of 5</span>
#
#   <div class="pagenav_inside">
#     <span class="curpage" title="Showing results 1 to 20 of 83">1</span><a class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=2" title="Show results 21 to 40 of 83">2</a><a rel="next" class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=2" title="Next Page - Results 21 to 40 of 83">&raquo;</a><a class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=5" title="Last Page - Results 81 to 83 of 83">Last <strong>&raquo;</strong></a>
#   </div>
#
#
# </div></div>
# <br class="clear" />
#
# <!-- controls below postbits -->
# <table cellpadding="0" cellspacing="0" border="0" width="100%" style="margin-top:-3px">
# <tr valign="top">
#
#     <td align="right">
#
#     </td>
#
# </tr>
# </table>
# <!-- / controls below postbits -->
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# <!-- controls for non-popup browsers -->
#
# <div align="left" class="container" id="threadtools_menu" style="width: 250px; display: none; background: url(/images/blackpixel_80.png);">
#   <form action="postings.php?t=49209&amp;pollid=" method="post" name="threadadminform">
#   <h4>Tools<a name="goto_threadtools"></a></h4>
#
#   <hr class="dark" />
#
#
#   <div class="threadtool_item"><i class="icon-white icon-print"></i> <a href="printthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209" rel="nofollow" class="light">Show Printable Version</a></div>
#   <div class="threadtool_item"><i class="icon-white icon-envelope"></i> <a href="sendmessage.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=sendtofriend&amp;t=49209" rel="nofollow" class="light">Email this Page</a></div>
#
#
#
#
#
#   <hr class="dark" />
#
#   <input type="hidden" name="s" value="cdc988b455c2e529861d3d4f51f35e13" />
#   <input type="hidden" name="securitytoken" value="guest" />
#   <input type="hidden" name="t" value="49209" />
#   <input type="hidden" name="pollid" value="" />
#   <input type="submit" class="submitbutton" value="Perform Action" />
#
#   </form>
# </div>
# <!-- / thread tools menu -->
#
#
#
# </tr>
# </table>
# <br />
#
# <!-- forum rules and admin links -->
# <table cellpadding="0" cellspacing="0" border="0" width="100%" align="center">
# <tr valign="bottom">
#   <td width="100%" valign="top">
#
#   </td>
#   <td class="smallfont" align="right">
#     <table cellpadding="0" cellspacing="0" border="0">
#
#     <tr>
#       <td><br /><br />
#       <div style="text-align:left; white-space:nowrap">
# 	<form action="forumdisplay.php" method="get">
# 	<input type="hidden" name="s" value="cdc988b455c2e529861d3d4f51f35e13" />
# 	<input type="hidden" name="daysprune" value="" />
# 	<select name="f" class="darkselect" id="jumpmenu" onchange="this.form.submit();">
# 		<optgroup label="Site Areas">
# 			<option value="cp" >User Control Panel</option>
# 			<option value="pm" >Private Messages</option>
# 			<option value="subs" >Subscriptions</option>
# 			<option value="wol" >Who's Online</option>
# 			<option value="search" >Search Forums</option>
# 			<option value="home" >Forums Home</option>
# 		</optgroup>
#
# 		<optgroup label="Forums">
#
#   </optgroup>
#   <optgroup label=" At the Movies">
#
#   <option value="2" class="fjsel" selected="selected">&nbsp; &nbsp;  General Movie Discussion</option>
#
#   <option value="3" class="fjdpth1" >&nbsp; &nbsp;  Movie Reviews</option>
#
#   <option value="4" class="fjdpth1" >&nbsp; &nbsp;  Upcoming Movies &amp; Sequels</option>
#
#   <option value="23" class="fjdpth1" >&nbsp; &nbsp;  Movie Questions</option>
#
#   </optgroup>
#   <optgroup label=" The Business">
#
#   <option value="13" class="fjdpth1" >&nbsp; &nbsp;  Actors, Awards, &amp; Directors</option>
#
#   <option value="9" class="fjdpth1" >&nbsp; &nbsp;  Home Theater Questions &amp; Information</option>
#
#   <option value="14" class="fjdpth1" >&nbsp; &nbsp;  Business &amp; Box Office Discussion</option>
#
#   </optgroup>
#   <optgroup label=" Miscellaneous Forums">
#
#   <option value="15" class="fjdpth1" >&nbsp; &nbsp;  Games and Tabs</option>
#
#   <option value="18" class="fjdpth2" >&nbsp; &nbsp; &nbsp; &nbsp;  Ongoing Tournaments &amp; Brackets</option>
#
#   <option value="8" class="fjdpth1" >&nbsp; &nbsp;  Intermission: Miscellaneous Chat</option>
#
#   <option value="19" class="fjdpth2" >&nbsp; &nbsp; &nbsp; &nbsp;  The Television &amp; Music Forum</option>
#
#   <option value="7" class="fjdpth1" >&nbsp; &nbsp;  Movie Forums Site Stuff</option>
#
#   <option value="17" class="fjdpth2" >&nbsp; &nbsp; &nbsp; &nbsp;  Birthdays and Introductions</option>
#
# 		</optgroup>
#
# 	</select><input type="submit" class="submitbutton" value="Go"  />
# 	</form>
# </div>
#       </td>
#     </tr>
#     </table>
#   </td>
# </tr>
# </table>
# <!-- /forum rules and admin links -->
#
#
#
#   <!-- Do not remove  or your scheduled tasks will cease to function -->
#
#   <!-- Do not remove  or your scheduled tasks will cease to function -->
#
#
#
#
#
#   <script type="text/javascript">
#   <!--
#     // Main vBulletin Javascript Initialization
#     vBulletin_init();
#   //-->
#   </script>
#
#   </div>
# </div>
#
#         <tr>
#           <td height="100%" valign="top" colspan="9" style="padding: 20px; padding-top: 30px;">
#
#
# <footer align="center">
#   <div id="footercontainer">
#     <div align="left" class="half_footer right">
#       <div id="twitter">
#         <a href="https://www.twitter.com/movieforums" id="twitterlink">@movieforums</a>
#         <h2>Twitter</h2>
#       </div>
#
#       <hr />
#       <div id="tweets"></div>
#       <br />
#     </div>
#
#     <div align="left" class="half_footer linkcontainer left">
#       <a href="/" title="Movie Forums" class="footernav noleftpadding">Movie Forums</a>
#       <a href="/essays" title="Essays" class="footernav">Essays</a>
#       <a href="/reviews" title="Movie Reviews" class="footernav noleftpadding">Reviews</a>
#       <a href="/lists" title="Lists" class="footernav">Lists</a>
#       <a href="/boxoffice" title="Box Office" class="footernav noleftpadding">Box Office</a>
#       <a href="/community/quiz.php" title="Movie Quizzes" class="footernav">Quizzes</a>
#       <a href="/community/rules.php" title="Rules" class="footernav noleftpadding" />Rules</a>
#       <a href="/community/search.php" title="Search" class="footernav" />Search</a>
#     </div>
#
#   </div>
#
#   <hr class="clear"/>
#   <a href="https://www.themoviedb.org"><img src="/images/tmdb.png" id="tmdb" /></a>
#
#   <div id="copyright" align="left">
#     <!-- Do not remove this copyright notice -->
#     <div class="clear">Powered by: vBulletin, Copyright, &copy;2000 - 2017, Jelsoft Enterprises Ltd.</div>
#     <!-- Do not remove this copyright notice -->
#   </div>
# </footer>
#
# <script type="text/javascript">
# $.ajax('/js/twitter/jquery.tweet.js', { timeout: 500 /* milliseconds */, success: function(result) {
#   eval(result);
#
#   $("#tweets").tweet({
#     username: "movieforums",
#     modpath: '/js/twitter/',
#     count: 2,
#     loading_text: '<li class="light light_textshadow"><div class="spinner spinner_med"></div> Loading Tweets</li>',
#     join_text: "auto",
#     avatar_size: null,
#     fetch: 20,
#     filter: function(t){ return ! /^@\w+/.test(t.tweet_raw_text); },
#     template: "<img src=\"/images/reel_avatar_34x34.png\" /> {text}",
#     // {time}
#     auto_join_text_default: "",
#     auto_join_text_ed: "",
#     auto_join_text_ing: "",
#     auto_join_text_reply: "",
#     auto_join_text_url: "",
#   });
# }});
# </script>
#
# <script type="text/javascript">
#
#   var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-2501417-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
#
# </script>
#
# <script type="text/javascript">
# // listen for quick reply posts
# $(document).on("DOMNodeInserted", "#posts", function(event) {
#
#   // if it's a div inside a div (which a post will almost certainly always be)...
#   if (event.target.nodeName == "DIV" && event.relatedNode.nodeName == "DIV") {
#    var post_tools_id = $(event.target).find(".post_tools").data("postid");
#
#    // found a post! Now re-run the toolbar plugin, tipsy, and QR link code. Maybe make this into a module later, but for now it'll do
#    if (post_tools_id) {
#       $("#post_tools_" + post_tools_id).toolbar({
#         content: '#user-options_' + post_tools_id,
#         position: 'bottom',
#         hideOnClick: true
#       });
#
#     $('.video').prettyEmbed({
#       previewSize: 'high',
#       showInfo: true,
#       showControls: true,
#       loop: false,
#       colorScheme: 'dark',
#       showRelated: false,
#       useFitVids: false
#     });
#     }
#
#     $("#favlink_" + post_tools_id + ", #listlink_" + post_tools_id).tipsy({
#       fade: true,
#       gravity: 'n',
#       trigger: "manual",
#       html: true,
#       offset: 5,
#       opacity: '0.9',
#       delayIn: 0,
#       delayOut: 0,
#       title:
#         function() {
#           var data_userid = $(this).attr("data-userid");
#
#           if ($(this).attr("class") == 'favs') {
#             return $("#favs_" + data_userid).html();
#           } else {
#             return $("#lists_" + data_userid).html();
#           }
#         }
#     });
#
#     $("#favlink_" + post_tools_id + ", #listlink_" + post_tools_id).click(function() {
#       $(".tipsy").fadeOut("fast");
#       $(this).tipsy("show");
#       return false;
#     });
#
#     $("#qr_" + post_tools_id).click(function() {
#       $("#qr_quickreply").prop("checked", true);
#       $("#qr_quickreply").attr("disabled", false);
#       $("#qr_postid").val(post_tools_id);
#
#       $('html, body').animate({
#         scrollTop: $($("#qr_quickreply")).offset().top
#       }, 1000);
#       $("#vB_Editor_QR_textarea").focus();
#
#       return false;
#     });
#
#     $("a.fancybox_review").fancybox({
#       helpers:  {
#         title: false,
#         overlay: {
#           locked: false,
#         }
#       },
#       'overlayColor'   : '#9b875b',
#       'overlayOpacity' : 0.7,
#       'width'          : 550,
#       'maxWidth'       : 550,
#       'height'         : 330,
#       'maxHeight'      : 330,
#       'padding'        : 1,
#       'type'           : 'iframe',
#       'autoScale'      : true,
#       afterShow: function() {
#         //$('.fancybox-close').focus();
#         $(".fancybox-iframe").contents().find('.repfocus').focus();
#         //$(this.content).attr("tabindex",1).focus()
#       }
#     });
#
#
#     // End re-run code
#
#   }
#
# });
#
# $(document).ready(function() {
#   $("textarea").autosize({append: "\n"});
#   //$(".post").fitVids();
#
#   $('.video').prettyEmbed({
#     previewSize: 'high',
#     showInfo: true,
#     showControls: true,
#     loop: false,
#     colorScheme: 'dark',
#     showRelated: false,
#     useFitVids: false
#   });
#
#   $(".post_tools").each(function() {
#     var post_tools_id = $(this).data("postid");
#
#     $(this).toolbar({
#       content: '#user-options_' + post_tools_id,
#       position: 'bottom',
#       hideOnClick: true
#     });
#   });
#
#
#
#   $(".quickreply").on("click", function() {
#     $("#qr_quickreply").prop("checked", true);
#     $("#qr_quickreply").attr("disabled", false);
#     $("#qr_postid").val($(this).data("postid"));
#
#     $('html, body').animate({
#       scrollTop: $($("#qr_quickreply")).offset().top
#     }, 1000);
#     $("#vB_Editor_QR_textarea").focus();
#
#     return false;
#   });
#
#   $(".posticon").tipsy({
#     gravity: 's',
#     html: true,
#     offset: 5,
#     opacity: '0.9',
#     delayIn: 0,
#     delayOut: 0,
#   });
#
#   $(".favs, .userlists, .avatar_small").tipsy({
#     fade: true,
#     gravity: 'n',
#     trigger: "manual",
#     html: true,
#     offset: 5,
#     opacity: '0.9',
#     delayIn: 0,
#     delayOut: 0,
#     title:
#       function() {
#         var data_userid = $(this).attr("data-userid");
#         var data_postid = $(this).attr("data-postid");
#
#         if ($(this).attr("class") == 'favs') {
#           return $("#favs_" + data_userid).html();
#         } else if ($(this).attr("class") == 'userlists') {
#           return $("#lists_" + data_userid).html();
#         } else {
#           return $("#usersmall_" + data_postid).html();
#         }
#       }
#   });
#
#   $(".favs, .userlists").click(function(){
#     $(".tipsy").fadeOut("fast");
#     $(this).tipsy("show");
#     return false;
#   });
#
#   $(".avatar_small").on('mouseover', function() {
#     $(".tipsy").fadeOut("fast");
#     $(this).tipsy("show");
#   });
#
#   $("a.fancybox").fancybox({
#     helpers:  {
#       title: false,
#       overlay: {
#         locked: false,
#       }
#     },
#     'overlayColor'   : '#9b875b',
#     'overlayOpacity' : 0.7,
#     'width'          : 400,
#     'maxWidth'       : 400,
#     'height'         : 250,
#     'maxHeight'      : 250,
#     'padding'        : 1,
#     'type'           : 'iframe',
#     'autoScale'      : true,
#     afterShow: function() {
#       //$('.fancybox-close').focus();
#       $(".fancybox-iframe").contents().find('.repfocus').focus();
#       //$(this.content).attr("tabindex",1).focus()
#     }
#   });
#
#   $("a.fancybox_rep").fancybox({
#     helpers:  {
#       title: false,
#       overlay: {
#         locked: false,
#       }
#     },
#     'overlayColor'   : '#9b875b',
#     'overlayOpacity' : 0.7,
#     'width'          : 300,
#     'maxWidth'       : 300,
#     'height'         : 410,
#     'maxHeight'      : 410,
#     'padding'        : 1,
#     'type'           : 'iframe',
#     'autoScale'      : true,
#     afterShow: function() {
#     }
#   });
#
#   $("a.fancybox_review").fancybox({
#     helpers:  {
#       title: false,
#       overlay: {
#         locked: false,
#       }
#     },
#     'overlayColor'   : '#9b875b',
#     'overlayOpacity' : 0.7,
#     'width'          : 550,
#     'maxWidth'       : 550,
#     'height'         : 330,
#     'maxHeight'      : 330,
#     'padding'        : 1,
#     'type'           : 'iframe',
#     'autoScale'      : true,
#     afterShow: function() {
#       //$('.fancybox-close').focus();
#       $(".fancybox-iframe").contents().find('#moviename').focus();
#       //$(this.content).attr("tabindex",1).focus()
#     }
#   });
#
# });
#
#   function setpostid(postid) {
#     document.getElementById("hidden_postid").value = postid;
#   }
#
#   function rep_load(postid, rating, userid) {
#     var replink = $("#replink_" + postid);
#     replink.html('<div class="spinner"></div>')
#
#     setpostid(postid);
#
#     $.ajax({
#       type: "GET",
#       url: "ratepost.php",
#       data: "postid=" + postid + "&rate=" + rating + "&userid=" + userid,
#       cache: false,
#       success: function(responsetext) {
#         replink.fadeOut("fast");
#         var thepostid = $("#hidden_postid").val();
#         var banner    = $("#reptotal_" + thepostid);
#
#         if (banner.children("span").length) {
#           var repvalue = banner.children("span");
#         } else {
#           var repvalue = banner.children("a").children("span");
#         }
#
#         if (!banner.is(":visible")) {
#           repvalue.html(responsetext).promise().done(function() {
#             var withoutplus = responsetext.replace("+", "");
#
#             if (withoutplus == 1) {
#               banner.prop("title", "This post has been upvoted 1 time");
#             } else {
#               banner.prop("title", "This post has been upvoted " + withoutplus + " times");
#             }
#
#             if (withoutplus > 9) {
#               banner.css("font-size", "0.8em");
#             }
#
#
#             banner.fadeIn("fast");
#
#           });
#         } else {
#           repvalue.fadeOut("fast", function() {
#             repvalue.html(responsetext);
#             var withoutplus = responsetext.replace("+", "");
#
#             if (withoutplus == 1) {
#               banner.prop("title", "This post has been upvoted 1 time");
#             } else {
#               banner.prop("title", "This post has been upvoted " + withoutplus + " times");
#             }
#
#             if (withoutplus > 9) {
#               banner.css("font-size", "0.8em");
#             }
#
#             repvalue.fadeIn("fast");
#           });
#         }
#       }
#     });
#   }
#
#
# </script>
#
#
#
#
# </body>
# </html>

# %%
print(type(webtext))
# Out:
# <class 'str'>

# %%
#Now we have the ingredients - let's make the soup!
soup = BeautifulSoup(webtext, "html.parser") 
# I just passed the string with all of the html data, and asked to use the html parser

# %%
#you can ask beautiful soup to print everything it parsed

print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html dir="ltr" lang="en" xmlns="http://www.w3.org/1999/xhtml">
#  <head>
#   <title>
#    Is Die Hard (1988) overrated? - Movie Forums
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
#   <!-- Whatever you do, do NOT put other stuff above the IE=edge tag -->
#   <link href="/apple-touch-icon-precomposed.png?v=2" rel="apple-touch-icon-precomposed" sizes="196x196"/>
#   <link href="/apple-touch-icon-57x57.png?v=2" rel="apple-touch-icon" sizes="57x57"/>
#   <link href="/apple-touch-icon-60x60.png?v=2" rel="apple-touch-icon" sizes="60x60"/>
#   <link href="/apple-touch-icon-72x72.png?v=2" rel="apple-touch-icon" sizes="72x72"/>
#   <link href="/apple-touch-icon-76x76.png?v=2" rel="apple-touch-icon" sizes="76x76"/>
#   <link href="/apple-touch-icon-114x114.png?v=2" rel="apple-touch-icon" sizes="114x114"/>
#   <link href="/apple-touch-icon-120x120.png?v=2" rel="apple-touch-icon" sizes="120x120"/>
#   <link href="/apple-touch-icon-144x144.png?v=2" rel="apple-touch-icon" sizes="144x144"/>
#   <link href="/apple-touch-icon-152x152.png?v=2" rel="apple-touch-icon" sizes="152x152"/>
#   <link href="/favicon.ico" rel="shortcut icon" type="image/x-icon">
#    <meta content="no" name="mobile-web-app-capable">
#     <!-- Stops Android from making shortcuts into web apps without browser toolbars -->
#     <!-- Windows 8 -->
#     <meta content="Movie Forums" name="application-name"/>
#     <meta content="#161E16" name="msapplication-TileColor"/>
#     <meta content="/images/windows8/tiny.png" name="msapplication-square70x70logo"/>
#     <meta content="/images/windows8/square.png" name="msapplication-square150x150logo"/>
#     <meta content="/images/windows8/wide.png" name="msapplication-wide310x150logo"/>
#     <meta content="/images/windows8/large.png" name="msapplication-square310x310logo"/>
#     <meta content="frequency=30;polling-uri=http://notifications.buildmypinnedsite.com/?feed=/community/external.php?type=RSS2&amp;id=1;polling-uri2=http://notifications.buildmypinnedsite.com/?feed=/community/external.php?type=RSS2&amp;id=2;polling-uri3=http://notifications.buildmypinnedsite.com/?feed=/community/external.php?type=RSS2&amp;id=3;polling-uri4=http://notifications.buildmypinnedsite.com/?feed=/community/external.php?type=RSS2&amp;id=4;polling-uri5=http://notifications.buildmypinnedsite.com/?feed=/community/external.php?type=RSS2&amp;id=5; cycle=1" name="msapplication-notification"/>
#     <meta content="vBulletin 3.8.0" name="generator"/>
#     <meta content=" Is Die Hard (1988) overrated?, movie forums,movie forum,movie reviews,movies,movie board,movie discussion,chat,movie awards" name="keywords"/>
#     <meta content=" Is Die Hard (1988) overrated? General Movie Discussion" name="description"/>
#     <!-- CSS Stylesheet -->
#     <style id="vbulletin_css" type="text/css">
#      /**
# * vBulletin 3.8.0 CSS
# * Style: 'Radioactive'; Style ID: 17
# */
# body
# {
# 	font: 16px Arial, Helvetica, sans-serif;
# 	margin: 0px 0px 0px 0px;
# 	scrollbar-3dlight-color: #000;
# 	scrollbar-arrow-color: #FFFFFF;
# 	scrollbar-base-color: #000;
# 	scrollbar-darkshadow-color: #404040;
# 	scrollbar-face-color: #262626;
# 	scrollbar-highlight-color: #595959;
# 	scrollbar-shadow-color: #000;
# }
# td, th, p, li
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .tborder
# {
# 	color: #000000;
# 	border: 0px solid #000000;
# }
# .tcat
# {
# 	color: #CCC;
# 	font-size: 16px;
# 	font-family: 'Futura', sans-serif;
# }
# .tcat a:link, .tcat_alink
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .tcat a:visited, .tcat_avisited
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .tcat a:hover, .tcat a:active, .tcat_ahover
# {
# 	color: #FFFFAE;
# 	text-decoration: underline;
# }
# .thead
# {
# 	color: #FFFFFF;
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .thead a:link, .thead_alink
# {
# 	color: #FFFFFF;
# }
# .thead a:visited, .thead_avisited
# {
# 	color: #FFFFFF;
# }
# .thead a:hover, .thead a:active, .thead_ahover
# {
# 	color: #FFFFAE;
# }
# .tfoot
# {
# 	background: #373737;
# 	color: #FFFFFF;
# }
# .tfoot a:link, .tfoot_alink
# {
# 	color: #FFFFFF;
# }
# .tfoot a:visited, .tfoot_avisited
# {
# 	color: #FFFFFF;
# }
# .tfoot a:hover, .tfoot a:active, .tfoot_ahover
# {
# 	color: #FFFFAE;
# }
# .alt1, .alt1Active
# {
# 	color: #CCC;
# 	background: url(/images/blackpixel_40.png);
# }
# .alt2, .alt2Active
# {
# 	color: #CCC;
# }
# .inlinemod
# {
# 	background: #FFFFCC;
# 	color: #000000;
# }
# .wysiwyg
# {
# 	background: #E4E4E4;
# 	color: #000000;
# 	font-family: Arial, Helvetica, sans-serif;
# 	background-repeat: no-repeat;
# 	background-color: #E4E4E4;
# }
# textarea, .bginput
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .bginput option, .bginput optgroup
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .button
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .smallfont
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .time
# {
# 	color: #666666;
# }
# .navbar
# {
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .highlight
# {
# 	color: #FF0000;
# 	font-weight: bold;
# }
# .fjsel
# {
# 	background: #333333;
# 	color: #D4D4D4;
# }
# .fjdpth0
# {
# 	background: #D4D4D4;
# 	color: #000000;
# }
# .panel
# {
# 	color: #999;
# 	padding: 10px;
#
# }
# legend
# {
# 	color: #000000;
# 	font-family: Arial, Helvetica, sans-serif;
# }
# .vbmenu_control
# {
# 	background: #000;
# 	color: #E1E1E1;
# 	font-family: Arial, sans-serif;
# 	padding: 3px 6px 3px 6px;
# 	white-space: nowrap;
# 	border: 1px solid #777;
# 	border-radius: 7px 7px 0 0;
# }
# .vbmenu_control a:link, .vbmenu_control_alink
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .vbmenu_control a:visited, .vbmenu_control_avisited
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .vbmenu_control a:hover, .vbmenu_control a:active, .vbmenu_control_ahover
# {
# 	color: #FFFFAE;
# 	text-decoration: underline;
# }
# .vbmenu_popup
# {
# 	background: #FFFFFF;
# 	color: #000000;
# 	border: solid 1px #000000;
# 	text-align: left;
# }
# .vbmenu_option
# {
# 	background: #CCCCCC;
# 	color: #000000;
# 	font-family: Arial, Helvetica, sans-serif;
# 	white-space: nowrap;
# 	cursor: hand;
# }
# .vbmenu_option a:link, .vbmenu_option_alink
# {
# 	color: #005C00;
# 	text-decoration: none;
# }
# .vbmenu_option a:visited, .vbmenu_option_avisited
# {
# 	color: #005C00;
# 	text-decoration: none;
# }
# .vbmenu_option a:hover, .vbmenu_option a:active, .vbmenu_option_ahover
# {
# 	color: #CA5100;
# 	text-decoration: none;
# }
# .vbmenu_hilite
# {
# 	background: #585858 url(/community/images/menubg.gif) repeat-x top left;
# 	color: #FFFFFF;
# 	font-family: Arial, Helvetica, sans-serif;
# 	white-space: nowrap;
# 	cursor: hand;
# }
# .vbmenu_hilite a:link, .vbmenu_hilite_alink
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .vbmenu_hilite a:visited, .vbmenu_hilite_avisited
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .vbmenu_hilite a:hover, .vbmenu_hilite a:active, .vbmenu_hilite_ahover
# {
# 	color: #FFFFFF;
# 	text-decoration: none;
# }
# .vbmenu_popup .thead {
#   text-align: center;
#   color: #383838;
#   text-decoration: underline;
# }
# /* ***** active table cells (IE only) ***** */
# /* .alt1Active, .alt2Active { behavior: url(http://www.movieforums.com/community/clientscript/activecell.htc); } */
#     </style>
#     <link href="https://www.movieforums.com/community/clientscript/vbulletin_important.css?v=380" rel="stylesheet" type="text/css">
#      <!-- / CSS Stylesheet -->
#      <script src="/community/clientscript/yui/yahoo-dom-event/yahoo-dom-event.js?v=380" type="text/javascript">
#      </script>
#      <script src="/community/clientscript/yui/connection/connection-min.js?v=380" type="text/javascript">
#      </script>
#      <script type="text/javascript">
#       <!--
# var SESSIONURL = "s=cdc988b455c2e529861d3d4f51f35e13&";
# var SECURITYTOKEN = "guest";
# var IMGDIR_MISC = "images/misc";
# var vb_disable_ajax = parseInt("0", 10);
# // -->
#      </script>
#      <script src="/community/clientscript/vbulletin_global.js?v=380" type="text/javascript">
#      </script>
#      <link href="external.php?type=RSS2" rel="alternate" title="Movie Forums RSS Feed" type="application/rss+xml">
#       <link href="external.php?type=RSS2&amp;forumids=2" rel="alternate" title="Movie Forums - General Movie Discussion - RSS Feed" type="application/rss+xml">
#        <script src="//ajax.googleapis.com/ajax/libs/jquery/1.8.3/jquery.min.js" type="text/javascript">
#        </script>
#        <script src="/js/fastclick.js" type="application/javascript">
#        </script>
#        <script src="/js/tipsy/jquery.tipsy.js" type="text/javascript">
#        </script>
#        <link href="/js/tipsy/tipsy.css?v=17" media="screen" rel="stylesheet" type="text/css">
#         <link href="/css/style.css?v=297" rel="stylesheet" type="text/css">
#          <script src="/js/global.js?v=110" type="text/javascript">
#          </script>
#          <!--[if lte IE 9]>
# <link rel="stylesheet" type="text/css" href="/css/style-ie.css?v=26" />
# <script src="/js/html5shiv.js"></script>
# <![endif]-->
#          <!--[if lt IE 8]>
# <link rel="stylesheet" type="text/css" href="/css/style-ie7.css?v=22"/>
# <![endif]-->
#          <script src="/js/jquery.waitforimages.js" type="text/javascript">
#          </script>
#          <script src="/js/jquery.prettyembed.js?v=10" type="text/javascript">
#          </script>
#          <link href="/css/style-thread.css?v=111" rel="stylesheet" type="text/css">
#           <link href="/js/bootstrap.icons.css" rel="stylesheet">
#            <link href="/js/jquery.toolbars.css?v=8" rel="stylesheet"/>
#            <script src="/js/toolbar-master/jquery.toolbar.js?v=55">
#            </script>
#            <script src="/community/clientscript/vbulletin_post_loader.js?v=380" type="text/javascript">
#            </script>
#            <script src="/community/spoilers.js" type="text/javascript">
#            </script>
#            <script src="/js/jquery.autosize.js" type="text/javascript">
#            </script>
#            <script async="" src="https://thisiswaldo.com/ad_delivery?site_id=992" type="text/javascript">
#            </script>
#            <script src="/js/fancybox/jquery.fancybox.pack.js" type="text/javascript">
#            </script>
#            <link href="/js/fancybox/jquery.fancybox.min.css?v=2" media="screen" rel="stylesheet" type="text/css"/>
#           </link>
#          </link>
#         </link>
#        </link>
#       </link>
#      </link>
#     </link>
#    </meta>
#   </link>
#  </head>
#  <body>
#   <div class="hidden">
#    <img class="hidden" src="/images/logo_hover.png"/>
#    <img class="hidden" src="/images/blackpixel_80.png"/>
#   </div>
#   <script type="text/javascript">
#    var doc = document.documentElement;
# doc.setAttribute('data-useragent', navigator.userAgent);
#
# $(document).ready(function() {
#   $("#headernotice").click(function() {
#     window.location = 'http://www.movieforums.com/community/showthread.php?t=49083';
#   });
#
# });
#   </script>
#   <link href="/animated_favicon_32px.gif" rel="icon" type="image/gif"/>
#   <div class="relative" id="wrapper">
#    <header>
#     <div id="movieforums">
#      <a href="https://www.movieforums.com" title="Movie Forums">
#       Movie Forums
#      </a>
#     </div>
#     <a href="https://www.movieforums.com" id="logowrapper" title="Movie Forums">
#      <div id="logo">
#      </div>
#     </a>
#    </header>
#    <div align="center" id="headerbar">
#     <nav align="center" class="relative" role="navigation">
#      <a href="/movies" id="movies" title="Movies">
#       Movies
#      </a>
#      <a href="/essays" id="essays" title="Essays">
#       Essays
#      </a>
#      <a href="/reviews" id="reviews" title="Movie Reviews">
#       Reviews
#      </a>
#      <a href="/community" id="forums" title="Movie Forums">
#       Forums
#      </a>
#      <a href="/lists" id="lists" title="Lists">
#       Lists
#      </a>
#      <a href="/boxoffice" id="bo" title="Box Office">
#       Box Office
#      </a>
#      <a href="/community/quiz.php" id="quizzes" title="Movie Quizzes">
#       Quizzes
#      </a>
#      <div align="left" class="subnav">
#       <div id="headersearch" title="Show Search">
#        <?xml version="1.0" ?>
#        <svg height="22" style="left: 10px; top: 10px; position: absolute; z-index: 99999;" version="1.1" viewbox="0 0 1024 973" width="22" xmlns="http://www.w3.org/2000/svg">
#         <path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#B9B591">
#         </path>
#        </svg>
#       </div>
#       <div id="searchbar">
#        <form action="/community/search.php?do=process" method="post">
#         <input name="do" type="hidden" value="process"/>
#         <input name="quicksearch" type="hidden" value="1"/>
#         <input name="childforums" type="hidden" value="1"/>
#         <input name="exactname" type="hidden" value="1"/>
#         <input name="s" type="hidden" value="cdc988b455c2e529861d3d4f51f35e13"/>
#         <input name="securitytoken" type="hidden" value="guest"/>
#         <input name="titleonly" type="hidden" value="1"/>
#         <input id="searchfield" name="query" type="text"/>
#         <input id="searchsubmit" type="submit" value="SEARCH"/>
#        </form>
#        <a href="#" id="closesearch" style="top: 3px;" title="Close Search">
#         <?xml version="1.0" ?>
#         <svg height="22" viewbox="0 0 32 32" width="22" xmlns="http://www.w3.org/2000/svg">
#          <path d="M4 8 L8 4 L16 12 L24 4 L28 8 L20 16 L28 24 L24 28 L16 20 L8 28 L4 24 L12 16 z" fill="#FFFFFF">
#          </path>
#         </svg>
#        </a>
#       </div>
#       <div id="header_avatar">
#       </div>
#       <a class="subnav_link" href="/community/search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=getdaily">
#        Today's Posts
#       </a>
#       <a class="subnav_link" href="/community/shoutbox.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;">
#        The Shoutbox
#       </a>
#       <a class="subnav_link" href="/community/register.php??s=cdc988b455c2e529861d3d4f51f35e13" rel="nofollow">
#        Register
#       </a>
#       <a class="subnav_link" href="/community/login_plain.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;" id="loginlink">
#        Log In
#       </a>
#       <div class="hidden" id="login_open">
#        <div id="login_wrapper">
#         <div id="login_content">
#          <div id="login">
#           <form action="/community/login.php?do=login" method="post" onsubmit="md5hash(vb_login_password, vb_login_md5password, vb_login_md5password_utf, 0)">
#            <script src="/community/clientscript/vbulletin_md5.js?v=380" type="text/javascript">
#            </script>
#            <div align="right" style="margin-bottom: 8px;">
#             <div class="right">
#              <label for="cb_cookieuser_navbar" id="cookielabel">
#               <span>
#                Save?
#               </span>
#              </label>
#              <input accesskey="c" checked="checked" id="cb_cookieuser_navbar" name="cookieuser" style="margin-top: 9px;" tabindex="103" type="checkbox" value="1"/>
#             </div>
#             <span class="loginfield_label">
#              Username:
#             </span>
#             <input accesskey="u" id="navbar_username" name="vb_login_username" tabindex="101" type="text"/>
#            </div>
#            <div align="right">
#             <div class="right">
#              <input class="submitbutton loginbutton" name="submit" tabindex="104" type="submit" value="Login"/>
#             </div>
#             <span class="loginfield_label">
#              Password:
#             </span>
#             <input id="navbar_password" name="vb_login_password" tabindex="102" type="password"/>
#            </div>
#            <input name="s" type="hidden" value="cdc988b455c2e529861d3d4f51f35e13"/>
#            <input name="securitytoken" type="hidden" value="guest"/>
#            <input name="do" type="hidden" value="login"/>
#            <input name="vb_login_md5password" type="hidden"/>
#            <input name="vb_login_md5password_utf" type="hidden"/>
#           </form>
#           <br class="clear"/>
#           <div align="center" id="registerdiv">
#            <a class="notification" href="/community/register.php?cdc988b455c2e529861d3d4f51f35e13">
#             Register Today!
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </nav>
#    </div>
#    <div id="container">
#     <div id="content">
#      <input id="hidden_postid" name="hidden_postid" type="hidden" value=""/>
#      <a id="poststop" name="poststop">
#      </a>
#      <h1>
#       Is Die Hard (1988) overrated?
#      </h1>
#      <div class="inforum light_textshadow" itemscope="" itemtype="http://data-vocabulary.org/Breadcrumb">
#       → in
#       <a class="light" href="general-movie-discussion.html" itemprop="url">
#        <span itemprop="title">
#         General Movie Discussion
#        </span>
#       </a>
#      </div>
#      <div class="right inforum light_textshadow">
#       <a class="light" href="#goto_threadtools" id="threadtools">
#        Tools
#       </a>
#      </div>
#      <hr class="clear" style="background: #585858; margin-bottom: 19px;"/>
#      <div>
#       <div class="right">
#        <div class="pagenav pagenav_thread">
#         <span class="pagecount">
#          Page 1 of 5
#         </span>
#         <div class="pagenav_inside">
#          <span class="curpage" title="Showing results 1 to 20 of 83">
#           1
#          </span>
#          <a class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=2" title="Show results 21 to 40 of 83">
#           2
#          </a>
#          <a class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=2" rel="next" title="Next Page - Results 21 to 40 of 83">
#           »
#          </a>
#          <a class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=5" title="Last Page - Results 81 to 83 of 83">
#           Last
#           <strong>
#            »
#           </strong>
#          </a>
#         </div>
#        </div>
#       </div>
#       <div id="button">
#        <a href="newreply.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newreply&amp;noquote=1&amp;p=1695060" rel="nofollow" title="Post Reply">
#         <img src="/images/reel_avatar_38x38.png"/>
#         Post Reply
#        </a>
#       </div>
#      </div>
#      <br class="clear"/>
#      <!-- toolbar -->
#      <br/>
#      <!-- end content table -->
#      <!-- / end content table -->
#      <div id="posts">
#       <!-- post #1695060 -->
#       <div id="edit1695060" style="padding:0px 0px 6px 0px">
#        <!-- this is not the last post shown on the page -->
#        <a name="post1695060">
#        </a>
#        <div class="post" id="post1695060">
#         <br/>
#         <br/>
#         <div class="userinfo left clear" style="padding-top: 0;">
#          <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
#           <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481" style="padding-right: 10px;" title="View ironpony's Profile">
#            <span>
#             i
#            </span>
#            ronpony
#           </a>
#          </div>
#          <div <a="" class="thumb noavatar" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481">
#           <img alt="ironpony's Avatar" class="lightshadow" data-postid="1695060" height="89" src="/images/reel_avatar_89x89.png" style="margin-bottom: 1px;border: 0; box-shadow: none; width: 89px; height: 89px;" width="89"/>
#          </div>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#   </div>
#  </body>
# </html>
# <div class="userlinks" style="width: -2px; height: -2px;">
#  <a href="">
#   <div class="padded" style="">
#    <div class="posticons_hover" style="">
#     <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481" style="" title="View ironpony's Profile">
#      <?xml version="1.0" standalone="no" ?>
#      <svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF">
#       </path>
#      </svg>
#      Profile
#     </a>
#    </div>
#    <div class="posticons_hover" style="">
#     <a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=96481" style="" title="Show ironpony's Posts">
#      <?xml version="1.0" standalone="no" ?>
#      <svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg">
#       <path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF">
#       </path>
#      </svg>
#      Posts
#     </a>
#    </div>
#    <div class="posticons_hover">
#     <a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=96481" style="" title="Send ironpony a Message">
#      <?xml version="1.0" standalone="no" ?>
#      <svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <g>
#        <path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF">
#        </path>
#       </g>
#      </svg>
#      Msg
#     </a>
#    </div>
#   </div>
#  </a>
# </div>
# <div class="usertitle clear">
#  Registered User
# </div>
# <div class="postcontent relative" id="td_post_1695060">
#  <div class="banner right" id="reptotal_1695060" title="This post has been upvoted 1 time">
#   <span>
#    +1
#   </span>
#  </div>
#  <div class="postdate">
#   <a href="showthread.php?p=1695060#post1695060" rel="nofollow" title="4-29-17 at 6:53 PM">
#    04-29-17
#   </a>
#  </div>
#  <div class="posttext">
#   <div id="post_message_1695060">
#    After seeing it a few times over the years, I still don't get all the hype. I mean the action scenes are good, but I find the story to be an average action movie plot, to be quite honest.
#    <br/>
#    <br/>
#    There isn't a huge deal of character change, the heroes and villains are very black and white, and some parts of the plot I find unconvincing. I mean I know it's an action movie, but this is rated so high by many people, that I can't help to pick on illogics in the plot more so, because of how highly praised it is.
#    <br/>
#    <br/>
#    <br/>
#    SPOILERS
#    <br/>
#    <br/>
#    <br/>
#    Basically when Kristoff is looking for McClane, McClane sneaks up on Kristoff and points his gun at Christoff's head.
#    <br/>
#    <br/>
#    He tells Kristoff to drop his gun, and Kristoff says "You won't hurt me, there are rules for policemen". McClane then says that's what my Captain keeps telling me. He then pistol whips Kristoff, and then tries to wrestle Kristoff's Machine gun, out of his hands.
#    <br/>
#    <br/>
#    But why! Why would a cop try to fight someone, who has a machine gun, when the cop can just shoot him? It's not like McClane has any handcuffs on him to neutralize Kristoff, so what is he going to do, if Kristoff surrenders?
#    <br/>
#    <br/>
#    Kristoff refused to drop the gun, and any realistic person would know that a cop would just shoot you in this situation and not attempt to wrestle a machine gun out of your hand.
#    <br/>
#    <br/>
#    Later on, McClane is trying to get the cop's attention from out the window and another goon comes to try stop him. McClane again tells the guy to put the gun down, but why? It's not like he can keep him held prisoner in situation like that.
#    <br/>
#    <br/>
#    He does this with Hans later as well instead of just shooting Hans.
#    <br/>
#    <br/>
#    I also feel that some of the dialogue is really dumb in this movie, like when the Deputy Chief cop says that the body that fell from the window that was full of bullet holes, must have been a depressed stockbroker. Really???
#    <br/>
#    <br/>
#    And I also feel that the Thornberg character, was not necessary to the plot and didn't really add anything really. I first saw Die Hard on edited television way back, and back then, all of Thornberg's scenes were cut, accept for the video footage, on the news that Holly saw, which tipped Hans' off. Having seen the uncut version of the movie, I feel that Thornberg being turned into an actual subplot character, doesn't really add anything.
#    <br/>
#    <br/>
#    We don't need to know the personal squabbles of the news guy, who's only role in the plot was to unintentionally tip the villain off. It made perfect sense on TV to cut all his scenes out accept the video footage one, that tipped Hans off.
#    <br/>
#    <br/>
#    And a lot of people out there say that Hans Gruber is the greatest movie villain ever, if not the greatest, but I dunno... I mean he doesn't really go through any huge personal character changes, and he is really just a bankrobber, with no hugely personal stakes in his goal.
#    <br/>
#    <br/>
#    McClane is good character, but I feel he is doesn't really do anything to be go through much of a change, and he is not pushed to his moral limits either in the end. But maybe this is not a bad thing, and maybe he doesn't have to.
#    <br/>
#    <br/>
#    So I feel the movie, in spite of having really good action scenes, is just not as well written as it could be, and is more of an average, perhaps decent action movie in terms of story and script.
#    <br/>
#    <br/>
#    What do you think?
#   </div>
#  </div>
#  <br/>
# </div>
# <!-- / post #1695060 -->
# <div style="margin: 25px 0 50px 155px; display: none;">
# </div>
# <div class="post" id="post_ad">
#  <br/>
#  <br/>
#  <div class="userinfo left clear" style="padding-top: 0;">
#   <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
#    <a class="username noclick" style="padding-right: 10px;">
#     <span>
#      A
#     </span>
#     dvertisement
#    </a>
#    <a class="favs" data-userid="ad" href="#" id="favlink_ad" title="Favorite Movies">
#     <?xml version="1.0" ?>
#     <svg height="14px" version="1.1" viewbox="0 0 16 16" width="14px" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
#      <title>
#      </title>
#      <defs>
#      </defs>
#      <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1">
#       <g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)">
#        <path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125">
#        </path>
#       </g>
#      </g>
#     </svg>
#    </a>
#   </div>
#   <div class="thumb noavatar">
#    <a class="noclick">
#     <img height="89" src="/images/reel_avatar_89x89.png" style="margin-bottom: 1px; border: 0; box-shadow: none;" width="89"/>
#    </a>
#   </div>
#   <div class="usertitle clear">
#    "Money won is twice as sweet as money earned."
#   </div>
#  </div>
#  <div class="postcontent relative" id="td_post_ad">
#   <div class="posttext">
#    <div id="post_message_ad">
#     <div id="waldo-tag-993">
#     </div>
#    </div>
#   </div>
#   <br/>
#  </div>
# </div>
# <div class="hidden" id="favs_ad">
#  <div>
#   <a class="closetip notextshadow" href="#" title="Close">
#    X
#   </a>
#   <h4 style="display: inline-block;">
#    Favorite Movies
#   </h4>
#  </div>
#  <ol>
#   <li>
#    <a href="favoritesearch.php?movieid=11873" title='Find others users who listed "The Color of Money"'>
#     The Color of Money
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=55448" title='Find others users who listed "Money for Nothing"'>
#     Money for Nothing
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=10466" title='Find others users who listed "The Money Pit"'>
#     The Money Pit
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=3090" title='Find others users who listed "The Treasure Of The Sierra Madre"'>
#     The Treasure Of The Sierra Madre
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=6463" title='Find others users who listed "Other Peoples Money"'>
#     Other Peoples Money
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=11064" title='Find others users who listed "Brewsters Millions"'>
#     Brewsters Millions
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=524" title='Find others users who listed "Casino"'>
#     Casino
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=10673" title='Find others users who listed "Wall Street"'>
#     Wall Street
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=1621" title='Find others users who listed "Trading Places"'>
#     Trading Places
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=9504" title='Find others users who listed "Glengary Glen Ross"'>
#     Glengary Glen Ross
#    </a>
#   </li>
#  </ol>
# </div>
# <!-- post #1695061 -->
# <div id="edit1695061" style="padding:0px 0px 6px 0px">
#  <!-- this is not the last post shown on the page -->
#  <a name="post1695061">
#  </a>
#  <div class="post" id="post1695061">
#   <br/>
#   <br/>
#   <div class="userinfo left clear" style="padding-top: 0;">
#    <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
#     <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=75073" style="font-size: 1.3em; padding-right: 10px;" title="View Blix the Goblin's Profile">
#      <span>
#       B
#      </span>
#      lix the Goblin
#     </a>
#     <a class="favs" data-userid="75073" href="#" id="favlink_1695061" title="Favorite Movies">
#      <?xml version="1.0" standalone="no" ?>
#      <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <switch>
#        <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1">
#         <g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)">
#          <path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125">
#          </path>
#         </g>
#        </g>
#        <foreignobject>
#         <img src="/images/fallbacks/fallback-favs.png"/>
#        </foreignobject>
#       </switch>
#      </svg>
#     </a>
#     <a class="userlists" data-userid="75073" href="#" id="listlink_1695061" title="User Lists">
#      <?xml version="1.0" standalone="no" ?>
#      <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
#       <switch>
#        <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z">
#        </path>
#        <foreignobject>
#         <img src="/images/fallbacks/fallback-lists.png"/>
#        </foreignobject>
#       </switch>
#      </svg>
#     </a>
#    </div>
#    <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=75073" style="width: 105px; height: 90px;">
#     <img alt="Blix the Goblin's Avatar" class="lightshadow" data-postid="1695061" src="customavatars/avatar75073_2.gif" style="margin-bottom: 1px; width: 105px; height: 90px;"/>
#    </div>
#   </div>
#  </div>
# </div>
# <div class="userlinks" style="width: 103px; height: 88px;">
#  <a href="">
#   <div class="padded" style="">
#    <div class="posticons_hover" style="">
#     <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=75073" style="" title="View Blix the Goblin's Profile">
#      <?xml version="1.0" standalone="no" ?>
#      <svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF">
#       </path>
#      </svg>
#      Profile
#     </a>
#    </div>
#    <div class="posticons_hover" style="">
#     <a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=75073" style="" title="Show Blix the Goblin's Posts">
#      <?xml version="1.0" standalone="no" ?>
#      <svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg">
#       <path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF">
#       </path>
#      </svg>
#      Posts
#     </a>
#    </div>
#    <div class="posticons_hover">
#     <a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=75073" style="" title="Send Blix the Goblin a Message">
#      <?xml version="1.0" standalone="no" ?>
#      <svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <g>
#        <path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF">
#        </path>
#       </g>
#      </svg>
#      Message
#     </a>
#    </div>
#   </div>
#  </a>
# </div>
# <div class="usertitle clear">
#  The most loathsome of all goblins
# </div>
# <div class="postcontent relative" id="td_post_1695061">
#  <div class="banner right" id="reptotal_1695061" title="This post has been upvoted 1 time">
#   <span>
#    +1
#   </span>
#  </div>
#  <div class="postdate">
#   <a href="showthread.php?p=1695061#post1695061" rel="nofollow" title="4-29-17 at 6:55 PM">
#    04-29-17
#   </a>
#  </div>
#  <div class="posttext">
#   <div id="post_message_1695061">
#    I think it's great, but I prefer Die Hard with a Vengeance
#   </div>
#  </div>
#  <br/>
# </div>
# <div class="hidden" id="favs_75073">
#  <div>
#   <a class="closetip notextshadow" href="#" title="Close">
#    X
#   </a>
#   <h4 style="display: inline-block;">
#    Favorite Movies
#   </h4>
#  </div>
#  <ol>
#   <li>
#    <a href="favoritesearch.php?movieid=11976" title='Find others users who listed "Legend"'>
#     Legend
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=15794" title='Find others users who listed "White Heat"'>
#     White Heat
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=900" title='Find others users who listed "Bringing Up Baby"'>
#     Bringing Up Baby
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=78" title='Find others users who listed "Blade Runner"'>
#     Blade Runner
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=5483" title='Find others users who listed "Lisa and the Devil"'>
#     Lisa and the Devil
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=691" title='Find others users who listed "The Spy Who Loved Me"'>
#     The Spy Who Loved Me
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=10907" title='Find others users who listed "The Adventures of Robin Hood"'>
#     The Adventures of Robin Hood
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=10428" title='Find others users who listed "Hackers"'>
#     Hackers
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=9434" title='Find others users who listed "Grosse Pointe Blank"'>
#     Grosse Pointe Blank
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=284" title='Find others users who listed "The Apartment"'>
#     The Apartment
#    </a>
#   </li>
#  </ol>
# </div>
# <div class="hidden" id="lists_75073">
#  <div>
#   <a class="closetip notextshadow" href="#" title="Close">
#    X
#   </a>
#   <h4 style="display: inline-block;">
#    User Lists
#   </h4>
#  </div>
#  <div class="clear" style="width: 220px; padding: 4px 8px;">
#   <span class="right" style="font-size: 0.9em;">
#    1%
#   </span>
#   <a href="/lists/afis_100_years_100_movies/75073.html" style="font-size: 0.9em;" title="View the movies on this list that Blix the Goblin has seen">
#    100 Years...100 Movies
#   </a>
#  </div>
#  <div class="clear" style="width: 220px; padding: 4px 8px;">
#   <span class="right" style="font-size: 0.9em;">
#    1%
#   </span>
#   <a href="/lists/afis_100_years_100_laughs/75073.html" style="font-size: 0.9em;" title="View the movies on this list that Blix the Goblin has seen">
#    100 Years...100 Laughs
#   </a>
#  </div>
#  <div class="clear" style="width: 220px; padding: 4px 8px;">
#   <span class="right" style="font-size: 0.9em;">
#    0%
#   </span>
#   <a href="/lists/afis_100_years_100_thrills/75073.html" style="font-size: 0.9em;" title="View the movies on this list that Blix the Goblin has seen">
#    100 Years...100 Thrills
#   </a>
#  </div>
#  <div class="clear" style="width: 220px; padding: 4px 8px;">
#   <span class="right" style="font-size: 0.9em;">
#    1%
#   </span>
#   <a href="/lists/afis_100_years_100_passions/75073.html" style="font-size: 0.9em;" title="View the movies on this list that Blix the Goblin has seen">
#    100 Years...100 Passions
#   </a>
#  </div>
#  <div class="clear" style="width: 220px; padding: 4px 8px;">
#   <span class="right" style="font-size: 0.9em;">
#    0%
#   </span>
#   <a href="/lists/afis_100_years_100_cheers/75073.html" style="font-size: 0.9em;" title="View the movies on this list that Blix the Goblin has seen">
#    100 Years...100 Cheers
#   </a>
#  </div>
#  <div class="clear" style="width: 220px; padding: 4px 8px;">
#   <span class="right" style="font-size: 0.9em;">
#    0%
#   </span>
#   <a href="/lists/afis_100_years_of_musicals/75073.html" style="font-size: 0.9em;" title="View the movies on this list that Blix the Goblin has seen">
#    100 Years of Musicals
#   </a>
#  </div>
#  <hr/>
#  <div style="text-align: center;">
#   <a href="/lists/viewall/75073.html" style="font-size: 0.9em;">
#    View All Lists
#   </a>
#  </div>
# </div>
# <!-- / post #1695061 -->
# <!-- post #1695062 -->
# <div id="edit1695062" style="padding:0px 0px 6px 0px">
#  <!-- this is not the last post shown on the page -->
#  <a name="post1695062">
#  </a>
#  <div class="post" id="post1695062">
#   <br/>
#   <br/>
#   <div class="userinfo left clear" style="padding-top: 0;">
#    <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
#     <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="padding-right: 10px;" title="View Dani8's Profile">
#      <span>
#       D
#      </span>
#      ani8
#     </a>
#     <a class="favs" data-userid="95651" href="#" id="favlink_1695062" title="Favorite Movies">
#      <?xml version="1.0" standalone="no" ?>
#      <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <switch>
#        <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1">
#         <g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)">
#          <path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125">
#          </path>
#         </g>
#        </g>
#        <foreignobject>
#         <img src="/images/fallbacks/fallback-favs.png"/>
#        </foreignobject>
#       </switch>
#      </svg>
#     </a>
#    </div>
#    <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="width: 77px; height: 90px;">
#     <img alt="Dani8's Avatar" class="lightshadow" data-postid="1695062" src="customavatars/avatar95651_1.gif" style="margin-bottom: 1px; width: 77px; height: 90px;"/>
#    </div>
#   </div>
#  </div>
# </div>
# <div class="userlinks" style="width: 75px; height: 88px;">
#  <a href="">
#   <div class="padded" style="left: 4px;">
#    <div class="posticons_hover" style="">
#     <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="" title="View Dani8's Profile">
#      <?xml version="1.0" standalone="no" ?>
#      <svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF">
#       </path>
#      </svg>
#      Profile
#     </a>
#    </div>
#    <div class="posticons_hover" style="">
#     <a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=95651" style="" title="Show Dani8's Posts">
#      <?xml version="1.0" standalone="no" ?>
#      <svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg">
#       <path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF">
#       </path>
#      </svg>
#      Posts
#     </a>
#    </div>
#    <div class="posticons_hover">
#     <a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=95651" style="" title="Send Dani8 a Message">
#      <?xml version="1.0" standalone="no" ?>
#      <svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink">
#       <g>
#        <path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF">
#        </path>
#       </g>
#      </svg>
#      Msg
#     </a>
#    </div>
#   </div>
#  </a>
# </div>
# <div class="usertitle clear">
#  You can't win an argument just by being right!
# </div>
# <div class="postcontent relative" id="td_post_1695062">
#  <div class="banner right" id="reptotal_1695062" title="This post has been upvoted 1 time">
#   <span>
#    +1
#   </span>
#  </div>
#  <div class="postdate">
#   <a href="showthread.php?p=1695062#post1695062" rel="nofollow" title="4-29-17 at 6:56 PM">
#    04-29-17
#   </a>
#  </div>
#  <div class="posttext">
#   <div id="post_message_1695062">
#    I dont really think there's any such thing as an overrated movie. Just because I may not enjoy a film so much does not mean critics and viewers dont get pumped for it. Die Hard I thought was great fun. Gone Girl is one I mentioned earlier where I dont get the hype, but I'm not going to label it overrated.
#   </div>
#  </div>
#  <br/>
# </div>
# <div class="hidden" id="favs_95651">
#  <div>
#   <a class="closetip notextshadow" href="#" title="Close">
#    X
#   </a>
#   <h4 style="display: inline-block;">
#    Favorite Movies
#   </h4>
#  </div>
#  <ol>
#   <li>
#    <a href="favoritesearch.php?movieid=60270" title='Find others users who listed "Wish You Were Here"'>
#     Wish You Were Here
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=48340" title='Find others users who listed "Sanctum"'>
#     Sanctum
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=66113" title='Find others users who listed "In Her Skin"'>
#     In Her Skin
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=66125" title='Find others users who listed "Red Dog"'>
#     Red Dog
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=287903" title='Find others users who listed "Krampus"'>
#     Krampus
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=333386" title='Find others users who listed "The Duel"'>
#     The Duel
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=331583" title='Find others users who listed "The Whole Truth"'>
#     The Whole Truth
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=9774" title='Find others users who listed "Kokoda"'>
#     Kokoda
#    </a>
#   </li>
#   <li>
#    <a href="favoritesearch.php?movieid=390043" title="Find others users who listed &quot;The Hitman's Bodyguard&quot;">
#     The Hitman's Bodyguard
#    </a>
#   </li>
#  </ol>
# </div>
# <!-- / post #1695062 -->
# <!-- post #1695063 -->
# <div id="edit1695063" style="padding:0px 0px 6px 0px">
#  <!-- this is not the last post shown on the page -->
#  <a name="post1695063">
#  </a>
#  <div class="post" id="post1695063">
# ...
#     »
#    </a>
#    <a class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=5" title="Last Page - Results 81 to 83 of 83">
#     Last
#     <strong>
#      »
#     </strong>
#    </a>
#   </div>
#  </div>
# </div>
# <br class="clear"/>
# <!-- controls below postbits -->
# <table border="0" cellpadding="0" cellspacing="0" style="margin-top:-3px" width="100%">
#  <tr valign="top">
#   <td align="right">
#   </td>
#  </tr>
# </table>
# <!-- / controls below postbits -->
# <!-- controls for non-popup browsers -->
# <div align="left" class="container" id="threadtools_menu" style="width: 250px; display: none; background: url(/images/blackpixel_80.png);">
#  <form action="postings.php?t=49209&amp;pollid=" method="post" name="threadadminform">
#   <h4>
#    Tools
#    <a name="goto_threadtools">
#    </a>
#   </h4>
#   <hr class="dark"/>
#   <div class="threadtool_item">
#    <i class="icon-white icon-print">
#    </i>
#    <a class="light" href="printthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209" rel="nofollow">
#     Show Printable Version
#    </a>
#   </div>
#   <div class="threadtool_item">
#    <i class="icon-white icon-envelope">
#    </i>
#    <a class="light" href="sendmessage.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=sendtofriend&amp;t=49209" rel="nofollow">
#     Email this Page
#    </a>
#   </div>
#   <hr class="dark"/>
#   <input name="s" type="hidden" value="cdc988b455c2e529861d3d4f51f35e13"/>
#   <input name="securitytoken" type="hidden" value="guest"/>
#   <input name="t" type="hidden" value="49209"/>
#   <input name="pollid" type="hidden" value=""/>
#   <input class="submitbutton" type="submit" value="Perform Action"/>
#  </form>
# </div>
# <!-- / thread tools menu -->
# <br/>
# <!-- forum rules and admin links -->
# <table align="center" border="0" cellpadding="0" cellspacing="0" width="100%">
#  <tr valign="bottom">
#   <td valign="top" width="100%">
#   </td>
#   <td align="right" class="smallfont">
#    <table border="0" cellpadding="0" cellspacing="0">
#     <tr>
#      <td>
#       <br/>
#       <br/>
#       <div style="text-align:left; white-space:nowrap">
#        <form action="forumdisplay.php" method="get">
#         <input name="s" type="hidden" value="cdc988b455c2e529861d3d4f51f35e13"/>
#         <input name="daysprune" type="hidden" value=""/>
#         <select class="darkselect" id="jumpmenu" name="f" onchange="this.form.submit();">
#          <optgroup label="Site Areas">
#           <option value="cp">
#            User Control Panel
#           </option>
#           <option value="pm">
#            Private Messages
#           </option>
#           <option value="subs">
#            Subscriptions
#           </option>
#           <option value="wol">
#            Who's Online
#           </option>
#           <option value="search">
#            Search Forums
#           </option>
#           <option value="home">
#            Forums Home
#           </option>
#          </optgroup>
#          <optgroup label="Forums">
#          </optgroup>
#          <optgroup label=" At the Movies">
#           <option class="fjsel" selected="selected" value="2">
#            General Movie Discussion
#           </option>
#           <option class="fjdpth1" value="3">
#            Movie Reviews
#           </option>
#           <option class="fjdpth1" value="4">
#            Upcoming Movies &amp; Sequels
#           </option>
#           <option class="fjdpth1" value="23">
#            Movie Questions
#           </option>
#          </optgroup>
#          <optgroup label=" The Business">
#           <option class="fjdpth1" value="13">
#            Actors, Awards, &amp; Directors
#           </option>
#           <option class="fjdpth1" value="9">
#            Home Theater Questions &amp; Information
#           </option>
#           <option class="fjdpth1" value="14">
#            Business &amp; Box Office Discussion
#           </option>
#          </optgroup>
#          <optgroup label=" Miscellaneous Forums">
#           <option class="fjdpth1" value="15">
#            Games and Tabs
#           </option>
#           <option class="fjdpth2" value="18">
#            Ongoing Tournaments &amp; Brackets
#           </option>
#           <option class="fjdpth1" value="8">
#            Intermission: Miscellaneous Chat
#           </option>
#           <option class="fjdpth2" value="19">
#            The Television &amp; Music Forum
#           </option>
#           <option class="fjdpth1" value="7">
#            Movie Forums Site Stuff
#           </option>
#           <option class="fjdpth2" value="17">
#            Birthdays and Introductions
#           </option>
#          </optgroup>
#         </select>
#         <input class="submitbutton" type="submit" value="Go"/>
#        </form>
#       </div>
#      </td>
#     </tr>
#    </table>
#   </td>
#  </tr>
# </table>
# <!-- /forum rules and admin links -->
# <!-- Do not remove  or your scheduled tasks will cease to function -->
# <!-- Do not remove  or your scheduled tasks will cease to function -->
# <script type="text/javascript">
#  <!--
#     // Main vBulletin Javascript Initialization
#     vBulletin_init();
#   //-->
# </script>
# <tr>
#  <td colspan="9" height="100%" style="padding: 20px; padding-top: 30px;" valign="top">
#   <footer align="center">
#    <div id="footercontainer">
#     <div align="left" class="half_footer right">
#      <div id="twitter">
#       <a href="https://www.twitter.com/movieforums" id="twitterlink">
#        @movieforums
#       </a>
#       <h2>
#        Twitter
#       </h2>
#      </div>
#      <hr/>
#      <div id="tweets">
#      </div>
#      <br/>
#     </div>
#     <div align="left" class="half_footer linkcontainer left">
#      <a class="footernav noleftpadding" href="/" title="Movie Forums">
#       Movie Forums
#      </a>
#      <a class="footernav" href="/essays" title="Essays">
#       Essays
#      </a>
#      <a class="footernav noleftpadding" href="/reviews" title="Movie Reviews">
#       Reviews
#      </a>
#      <a class="footernav" href="/lists" title="Lists">
#       Lists
#      </a>
#      <a class="footernav noleftpadding" href="/boxoffice" title="Box Office">
#       Box Office
#      </a>
#      <a class="footernav" href="/community/quiz.php" title="Movie Quizzes">
#       Quizzes
#      </a>
#      <a class="footernav noleftpadding" href="/community/rules.php" title="Rules">
#      </a>
#      Rules
#     </div>
#    </div>
#   </footer>
#  </td>
# </tr>
# <a class="footernav" href="/community/search.php" title="Search">
# </a>
# Search
# <hr class="clear"/>
# <a href="https://www.themoviedb.org">
#  <img id="tmdb" src="/images/tmdb.png"/>
# </a>
# <div align="left" id="copyright">
#  <!-- Do not remove this copyright notice -->
#  <div class="clear">
#   Powered by: vBulletin, Copyright, ©2000 - 2017, Jelsoft Enterprises Ltd.
#  </div>
#  <!-- Do not remove this copyright notice -->
# </div>
# <script type="text/javascript">
#  $.ajax('/js/twitter/jquery.tweet.js', { timeout: 500 /* milliseconds */, success: function(result) {
#   eval(result);
#
#   $("#tweets").tweet({
#     username: "movieforums",
#     modpath: '/js/twitter/',
#     count: 2,
#     loading_text: '<li class="light light_textshadow"><div class="spinner spinner_med"></div> Loading Tweets</li>',
#     join_text: "auto",
#     avatar_size: null,
#     fetch: 20,
#     filter: function(t){ return ! /^@\w+/.test(t.tweet_raw_text); },
#     template: "<img src=\"/images/reel_avatar_34x34.png\" /> {text}",
#     // {time}
#     auto_join_text_default: "",
#     auto_join_text_ed: "",
#     auto_join_text_ing: "",
#     auto_join_text_reply: "",
#     auto_join_text_url: "",
#   });
# }});
# </script>
# <script type="text/javascript">
#  var _gaq = _gaq || [];
#   _gaq.push(['_setAccount', 'UA-2501417-1']);
#   _gaq.push(['_trackPageview']);
#
#   (function() {
#     var ga = document.createElement('script'); ga.type = 'text/javascript'; ga.async = true;
#     ga.src = ('https:' == document.location.protocol ? 'https://' : 'http://') + 'stats.g.doubleclick.net/dc.js';
#     var s = document.getElementsByTagName('script')[0]; s.parentNode.insertBefore(ga, s);
#   })();
# </script>
# <script type="text/javascript">
#  // listen for quick reply posts
# $(document).on("DOMNodeInserted", "#posts", function(event) {
#
#   // if it's a div inside a div (which a post will almost certainly always be)...
#   if (event.target.nodeName == "DIV" && event.relatedNode.nodeName == "DIV") {
#    var post_tools_id = $(event.target).find(".post_tools").data("postid");
#
#    // found a post! Now re-run the toolbar plugin, tipsy, and QR link code. Maybe make this into a module later, but for now it'll do
#    if (post_tools_id) {
#       $("#post_tools_" + post_tools_id).toolbar({
#         content: '#user-options_' + post_tools_id,
#         position: 'bottom',
#         hideOnClick: true
#       });
#
#     $('.video').prettyEmbed({
#       previewSize: 'high',
#       showInfo: true,
#       showControls: true,
#       loop: false,
#       colorScheme: 'dark',
#       showRelated: false,
#       useFitVids: false
#     });
#     }
#
#     $("#favlink_" + post_tools_id + ", #listlink_" + post_tools_id).tipsy({
#       fade: true,
#       gravity: 'n',
#       trigger: "manual",
#       html: true,
#       offset: 5,
#       opacity: '0.9',
#       delayIn: 0,
#       delayOut: 0,
#       title:
#         function() {
#           var data_userid = $(this).attr("data-userid");
#
#           if ($(this).attr("class") == 'favs') {
#             return $("#favs_" + data_userid).html();
#           } else {
#             return $("#lists_" + data_userid).html();
#           }
#         }
#     });
#
#     $("#favlink_" + post_tools_id + ", #listlink_" + post_tools_id).click(function() {
#       $(".tipsy").fadeOut("fast");
#       $(this).tipsy("show");
#       return false;
#     });
#
#     $("#qr_" + post_tools_id).click(function() {
#       $("#qr_quickreply").prop("checked", true);
#       $("#qr_quickreply").attr("disabled", false);
#       $("#qr_postid").val(post_tools_id);
#
#       $('html, body').animate({
#         scrollTop: $($("#qr_quickreply")).offset().top
#       }, 1000);
#       $("#vB_Editor_QR_textarea").focus();
#
#       return false;
#     });
#
#     $("a.fancybox_review").fancybox({
#       helpers:  {
#         title: false,
#         overlay: {
#           locked: false,
#         }
#       },
#       'overlayColor'   : '#9b875b',
#       'overlayOpacity' : 0.7,
#       'width'          : 550,
#       'maxWidth'       : 550,
#       'height'         : 330,
#       'maxHeight'      : 330,
#       'padding'        : 1,
#       'type'           : 'iframe',
#       'autoScale'      : true,
#       afterShow: function() {
#         //$('.fancybox-close').focus();
#         $(".fancybox-iframe").contents().find('.repfocus').focus();
#         //$(this.content).attr("tabindex",1).focus()
#       }
#     });
#
#
#     // End re-run code
#
#   }
#
# });
#
# $(document).ready(function() {
#   $("textarea").autosize({append: "\n"});
#   //$(".post").fitVids();
#
#   $('.video').prettyEmbed({
#     previewSize: 'high',
#     showInfo: true,
#     showControls: true,
#     loop: false,
#     colorScheme: 'dark',
#     showRelated: false,
#     useFitVids: false
#   });
#
#   $(".post_tools").each(function() {
#     var post_tools_id = $(this).data("postid");
#
#     $(this).toolbar({
#       content: '#user-options_' + post_tools_id,
#       position: 'bottom',
#       hideOnClick: true
#     });
#   });
#
#
#
#   $(".quickreply").on("click", function() {
#     $("#qr_quickreply").prop("checked", true);
#     $("#qr_quickreply").attr("disabled", false);
#     $("#qr_postid").val($(this).data("postid"));
#
#     $('html, body').animate({
#       scrollTop: $($("#qr_quickreply")).offset().top
#     }, 1000);
#     $("#vB_Editor_QR_textarea").focus();
#
#     return false;
#   });
#
#   $(".posticon").tipsy({
#     gravity: 's',
#     html: true,
#     offset: 5,
#     opacity: '0.9',
#     delayIn: 0,
#     delayOut: 0,
#   });
#
#   $(".favs, .userlists, .avatar_small").tipsy({
#     fade: true,
#     gravity: 'n',
#     trigger: "manual",
#     html: true,
#     offset: 5,
#     opacity: '0.9',
#     delayIn: 0,
#     delayOut: 0,
#     title:
#       function() {
#         var data_userid = $(this).attr("data-userid");
#         var data_postid = $(this).attr("data-postid");
#
#         if ($(this).attr("class") == 'favs') {
#           return $("#favs_" + data_userid).html();
#         } else if ($(this).attr("class") == 'userlists') {
#           return $("#lists_" + data_userid).html();
#         } else {
#           return $("#usersmall_" + data_postid).html();
#         }
#       }
#   });
#
#   $(".favs, .userlists").click(function(){
#     $(".tipsy").fadeOut("fast");
#     $(this).tipsy("show");
#     return false;
#   });
#
#   $(".avatar_small").on('mouseover', function() {
#     $(".tipsy").fadeOut("fast");
#     $(this).tipsy("show");
#   });
#
#   $("a.fancybox").fancybox({
#     helpers:  {
#       title: false,
#       overlay: {
#         locked: false,
#       }
#     },
#     'overlayColor'   : '#9b875b',
#     'overlayOpacity' : 0.7,
#     'width'          : 400,
#     'maxWidth'       : 400,
#     'height'         : 250,
#     'maxHeight'      : 250,
#     'padding'        : 1,
#     'type'           : 'iframe',
#     'autoScale'      : true,
#     afterShow: function() {
#       //$('.fancybox-close').focus();
#       $(".fancybox-iframe").contents().find('.repfocus').focus();
#       //$(this.content).attr("tabindex",1).focus()
#     }
#   });
#
#   $("a.fancybox_rep").fancybox({
#     helpers:  {
#       title: false,
#       overlay: {
#         locked: false,
#       }
#     },
#     'overlayColor'   : '#9b875b',
#     'overlayOpacity' : 0.7,
#     'width'          : 300,
#     'maxWidth'       : 300,
#     'height'         : 410,
#     'maxHeight'      : 410,
#     'padding'        : 1,
#     'type'           : 'iframe',
#     'autoScale'      : true,
#     afterShow: function() {
#     }
#   });
#
#   $("a.fancybox_review").fancybox({
#     helpers:  {
#       title: false,
#       overlay: {
#         locked: false,
#       }
#     },
#     'overlayColor'   : '#9b875b',
#     'overlayOpacity' : 0.7,
#     'width'          : 550,
#     'maxWidth'       : 550,
#     'height'         : 330,
#     'maxHeight'      : 330,
#     'padding'        : 1,
#     'type'           : 'iframe',
#     'autoScale'      : true,
#     afterShow: function() {
#       //$('.fancybox-close').focus();
#       $(".fancybox-iframe").contents().find('#moviename').focus();
#       //$(this.content).attr("tabindex",1).focus()
#     }
#   });
#
# });
#
#   function setpostid(postid) {
#     document.getElementById("hidden_postid").value = postid;
#   }
#
#   function rep_load(postid, rating, userid) {
#     var replink = $("#replink_" + postid);
#     replink.html('<div class="spinner"></div>')
#
#     setpostid(postid);
#
#     $.ajax({
#       type: "GET",
#       url: "ratepost.php",
#       data: "postid=" + postid + "&rate=" + rating + "&userid=" + userid,
#       cache: false,
#       success: function(responsetext) {
#         replink.fadeOut("fast");
#         var thepostid = $("#hidden_postid").val();
#         var banner    = $("#reptotal_" + thepostid);
#
#         if (banner.children("span").length) {
#           var repvalue = banner.children("span");
#         } else {
#           var repvalue = banner.children("a").children("span");
#         }
#
#         if (!banner.is(":visible")) {
#           repvalue.html(responsetext).promise().done(function() {
#             var withoutplus = responsetext.replace("+", "");
#
#             if (withoutplus == 1) {
#               banner.prop("title", "This post has been upvoted 1 time");
#             } else {
#               banner.prop("title", "This post has been upvoted " + withoutplus + " times");
#             }
#
#             if (withoutplus > 9) {
#               banner.css("font-size", "0.8em");
#             }
#
#
#             banner.fadeIn("fast");
#
#           });
#         } else {
#           repvalue.fadeOut("fast", function() {
#             repvalue.html(responsetext);
#             var withoutplus = responsetext.replace("+", "");
#
#             if (withoutplus == 1) {
#               banner.prop("title", "This post has been upvoted 1 time");
#             } else {
#               banner.prop("title", "This post has been upvoted " + withoutplus + " times");
#             }
#
#             if (withoutplus > 9) {
#               banner.css("font-size", "0.8em");
#             }
#
#             repvalue.fadeIn("fast");
#           });
#         }
#       }
#     });
#   }
# </script>

# %%
# What is the organization of a webpage?
from IPython.display import Image
Image('http://www.openbookproject.net/tutorials/getdown/css/images/lesson4/HTMLDOMTree.png')

# %%
# Cool! we have our soup- now let's see what's in it. 
# You can look for a tag itself (like the title tag)
print(soup.title) #notice that the tags are still here
print("===========================")
print(soup.title.string) #cool, now we know how to get the text inbetween the tags!
print("===========================")
print(soup.div)
print("===========================")
print(soup.div['class']) #you can ask for an attribute 
print("===========================")
print(soup.a)
print("===========================")
print(soup.a['href']) #cool, a new link! 

# note that this only returns the first instance of each tag specified!
# Out:
# <title> Is Die Hard (1988) overrated? - Movie Forums</title>
# ===========================
#  Is Die Hard (1988) overrated? - Movie Forums
# ===========================
# <div class="hidden">
# <img class="hidden" src="/images/logo_hover.png"/>
# <img class="hidden" src="/images/blackpixel_80.png"/>
# </div>
# ===========================
# ['hidden']
# ===========================
# <a href="https://www.movieforums.com" title="Movie Forums">Movie Forums</a>
# ===========================
# https://www.movieforums.com

# %%
# what if we wanted ALL links?
links = soup.find_all('a')
print(links) # this looks kind of ugly. What's happening here?
print("===========================")
print(type(links)) #it's a set!
print("===========================")

# say I wanted to find out all the links and text displayed
for i in links:
     print(i['href'], ":", i.string)
# Out:
# [<a href="https://www.movieforums.com" title="Movie Forums">Movie Forums</a>, <a href="https://www.movieforums.com" id="logowrapper" title="Movie Forums"><div id="logo"> </div></a>, <a href="/movies" id="movies" title="Movies">Movies</a>, <a href="/essays" id="essays" title="Essays">Essays</a>, <a href="/reviews" id="reviews" title="Movie Reviews">Reviews</a>, <a href="/community" id="forums" title="Movie Forums">Forums</a>, <a href="/lists" id="lists" title="Lists">Lists</a>, <a href="/boxoffice" id="bo" title="Box Office">Box Office</a>, <a href="/community/quiz.php" id="quizzes" title="Movie Quizzes">Quizzes</a>, <a href="#" id="closesearch" style="top: 3px;" title="Close Search"><?xml version="1.0" ?><svg height="22" viewbox="0 0 32 32" width="22" xmlns="http://www.w3.org/2000/svg"><path d="M4 8 L8 4 L16 12 L24 4 L28 8 L20 16 L28 24 L24 28 L16 20 L8 28 L4 24 L12 16 z" fill="#FFFFFF"></path></svg></a>, <a class="subnav_link" href="/community/search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=getdaily">Today's Posts</a>, <a class="subnav_link" href="/community/shoutbox.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;">The Shoutbox</a>, <a class="subnav_link" href="/community/register.php??s=cdc988b455c2e529861d3d4f51f35e13" rel="nofollow">Register</a>, <a class="subnav_link" href="/community/login_plain.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;" id="loginlink">Log In</a>, <a class="notification" href="/community/register.php?cdc988b455c2e529861d3d4f51f35e13">Register Today!</a>, <a id="poststop" name="poststop"></a>, <a class="light" href="general-movie-discussion.html" itemprop="url"><span itemprop="title">General Movie Discussion</span></a>, <a class="light" href="#goto_threadtools" id="threadtools">Tools</a>, <a class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=2" title="Show results 21 to 40 of 83">2</a>, <a class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=2" rel="next" title="Next Page - Results 21 to 40 of 83">»</a>, <a class="pnav_new" href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;t=49209&amp;page=5" title="Last Page - Results 81 to 83 of 83">Last <strong>»</strong></a>, <a href="newreply.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newreply&amp;noquote=1&amp;p=1695060" rel="nofollow" title="Post Reply"><img src="/images/reel_avatar_38x38.png"/> Post Reply</a>, <a name="post1695060"></a>, <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481" style="padding-right: 10px;" title="View ironpony's Profile"><span>i</span>ronpony</a>, <a href="">
# <div class="padded" style="">
# <div class="posticons_hover" style=""><a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481" style="" title="View ironpony's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a></div>
# <div class="posticons_hover" style=""><a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=96481" style="" title="Show ironpony's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a></div>
# <div class="posticons_hover"><a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=96481" style="" title="Send ironpony a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Msg</a></div>
# </div>
# </a>, <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481" style="" title="View ironpony's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a>, <a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=96481" style="" title="Show ironpony's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a>, <a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=96481" style="" title="Send ironpony a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Msg</a>, <a href="showthread.php?p=1695060#post1695060" rel="nofollow" title="4-29-17 at 6:53 PM">04-29-17</a>, <a class="username noclick" style="padding-right: 10px;"><span>A</span>dvertisement</a>, <a class="favs" data-userid="ad" href="#" id="favlink_ad" title="Favorite Movies"><?xml version="1.0" ?><svg height="14px" version="1.1" viewbox="0 0 16 16" width="14px" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink"><title></title><defs></defs><g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g></svg></a>, <a class="noclick"><img height="89" src="/images/reel_avatar_89x89.png" style="margin-bottom: 1px; border: 0; box-shadow: none;" width="89"/></a>, <a class="closetip notextshadow" href="#" title="Close" ...
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>, <a class="userlists" data-userid="75073" href="#" id="listlink_1695061" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>, <a href="">
# <div class="padded" style="">
# <div class="posticons_hover" style=""><a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=75073" style="" title="View Blix the Goblin's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a></div>
# <div class="posticons_hover" style=""><a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=75073" style="" title="Show Blix the Goblin's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a></div>
# <div class="posticons_hover"><a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=75073" style="" title="Send Blix the Goblin a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Message</a></div>
# </div>
# </a>, <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=75073" style="" title="View Blix the Goblin's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a>, <a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=75073" style="" title="Show Blix the Goblin's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a>, <a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=75073" style="" title="Send Blix the Goblin a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Message</a>, <a href="showthread.php?p=1695061#post1695061" rel="nofollow" title="4-29-17 at 6:55 PM">04-29-17</a>, <a class="closetip notextshadow" href="#" title="Close">X</a>, <a href="favoritesearch.php?movieid=11976" title='Find others users who listed "Legend"'>Legend</a>, <a href="favoritesearch.php?movieid=15794" title='Find others users who listed "White Heat"'>White Heat</a>, <a href="favoritesearch.php?movieid=900" title='Find others users who listed "Bringing Up Baby"'>Bringing Up Baby</a>, <a href="favoritesearch.php?movieid=78" title='Find others users who listed "Blade Runner"'>Blade Runner</a>, <a href="favoritesearch.php?movieid=5483" title='Find others users who listed "Lisa and the Devil"'>Lisa and the Devil</a>, <a href="favoritesearch.php?movieid=691" title='Find others users who listed "The Spy Who Loved Me"'>The Spy Who Loved Me</a>, <a href="favoritesearch.php?movieid=10907" title='Find others users who listed "The Adventures of Robin Hood"'>The Adventures of Robin Hood</a>, <a href="favoritesearch.php?movieid=10428" title='Find others users who listed "Hackers"'>Hackers</a>, <a href="favoritesearch.php?movieid=9434" ...
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>, <a href="">
# <div class="padded" style="left: 4px;">
# <div class="posticons_hover" style=""><a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="" title="View Dani8's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a></div>
# <div class="posticons_hover" style=""><a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=95651" style="" title="Show Dani8's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a></div>
# <div class="posticons_hover"><a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=95651" style="" title="Send Dani8 a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Msg</a></div>
# </div>
# </a>, <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="" title="View Dani8's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a>, <a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=95651" style="" title="Show Dani8's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a>, <a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=95651" style="" title="Send Dani8 a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Msg</a>, <a href="showthread.php?p=1695062#post1695062" rel="nofollow" title="4-29-17 at 6:56 PM">04-29-17</a>, <a class="closetip notextshadow" href="#" title="Close">X</a>, <a href="favoritesearch.php?movieid=60270" title='Find others users who listed "Wish You Were Here"'>Wish You Were Here</a>, <a href="favoritesearch.php?movieid=48340" title='Find others users who listed "Sanctum"'>Sanctum</a>, <a href="favoritesearch.php?movieid=66113" title='Find others users who listed "In Her Skin"'>In Her Skin</a>, <a href="favoritesearch.php?movieid=66125" title='Find others users who listed "Red Dog"'>Red Dog</a>, <a href="favoritesearch.php?movieid=287903" title='Find others users who listed "Krampus"'>Krampus</a>, <a href="favoritesearch.php?movieid=333386" title='Find others users who listed "The Duel"'>The Duel</a>, <a href="favoritesearch.php?movieid=331583" title='Find others users who listed "The Whole Truth"'>The Whole Truth</a>, <a href="favoritesearch.php?movieid=9774" title='Find others users who listed "Kokoda"'>Kokoda</a>, <a href="favoritesearch.php?movieid=390043" title="Find others users who listed &quot;The Hitman's Bodyguard&quot;">The Hitman's Bodyguard</a ...
# <div class="padded" style="">
# <div class="posticons_hover" style=""><a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=83561" style="" title="View rambond's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a></div>
# <div class="posticons_hover" style=""><a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=83561" style="" title="Show rambond's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a></div>
# <div class="posticons_hover"><a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=83561" style="" title="Send rambond a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Message</a></div>
# </div>
# </a>, <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=83561" style="" title="View rambond's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a>, <a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=83561" style="" title="Show rambond's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a>, <a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=83561" style="" title="Send rambond a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Message</a>, <a href="showthread.php?p=1695063#post1695063" rel="nofollow" title="4-29-17 at 6:57 PM">04-29-17</a>, <a name="post1695064"></a>, <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="padding-right: 10px;" title="View Dani8's Profile"><span>D</span>ani8</a>, <a class="favs" data-userid="95651" href="#" id="favlink_1695064" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>, <a href="">
# <div class="padded" style="left: 4px;">
# <div class="posticons_hover" style=""><a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="" title="View Dani8's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a></div>
# <div class="posticons_hover" style=""><a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=95651" style="" title="Show Dani8's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a></div>
# <div class="posticons_hover"><a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=95651" style="" title="Send Dani8 a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Msg</a></div>
# </div>
# </a>, <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="" title="View Dani8's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a>, <a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=95651" style="" title="Show Dani8's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a>, <a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=95651" style="" title="Send Dani8 a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Msg</a>, <a href="showthread.php?p=1695064#post1695064" rel="nofollow" title="4-29-17 at 7:04 PM">04-29-17</a>, <a href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;p=1695063#post1695063" title="View Post">Originally Posted by <strong>rambond</strong></a>, <a class="closetip notextshadow" href="#" title="Close">X</a>, <a href="favoritesearch.php?movieid=60270" title='Find others users who listed "Wish You Were Here"'>Wish You Were Here</a>, <a href="favoritesearch.php?movieid=48340" title='Find others users who listed "Sanctum"'>Sanctum</a>, <a href="favoritesearch.php?movieid=66113" title='Find others users who listed "In Her Skin"'>In Her Skin</a>, <a href="favoritesearch.php?movieid=66125" title='Find others users who listed "Red Dog"'>Red Dog</a>, <a href="favoritesearch.php?movieid=287903" title='Find others users who listed "Krampus"'>Krampus</a>, <a href="favoritesearch.php?movieid=333386" title='Find others users who listed "The Duel"'>The Duel</a>, <a href="favoritesearch.php?movieid=331583" title='Find others users who listed "The Whole Truth"'>The Whole Truth</a>, <a href="favoritesearch.php?movieid=9774" title='Find others users who listed "Kokoda" ...
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>, <a class="userlists" data-userid="85347" href="#" id="listlink_1695107" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>, <a href="">
# <div class="padded" style="">
# <div class="posticons_hover" style=""><a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=85347" style="" title="View MovieMeditation's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a></div>
# <div class="posticons_hover" style=""><a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=85347" style="" title="Show MovieMeditation's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a></div>
# <div class="posticons_hover"><a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=85347" style="" title="Send MovieMeditation a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Message</a></div>
# </div>
# ...
# <div class="posticons_hover" style=""><a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=96380" style="" title="Show Joel's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a></div>
# <div class="posticons_hover"><a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=96380" style="" title="Send Joel a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Message</a></div>
# </div>
# </a>, <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96380" style="" title="View Joel's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a>, <a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=96380" style="" title="Show Joel's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a>, <a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=96380" style="" title="Send Joel a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Message</a>, <a href="showthread.php?p=1695184#post1695184" rel="nofollow" title="4-29-17 at 11:30 PM">04-29-17</a>, <a href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;p=1695145#post1695145" title="View Post">Originally Posted by <strong>Dani8</strong></a>, <a class="closetip notextshadow" href="#" title="Close">X</a>, <a href="favoritesearch.php?movieid=90" title='Find others users who listed "Beverly Hills Cop"'>Beverly Hills Cop</a>, <a href="favoritesearch.php?movieid=2056" title='Find others users who listed "The Station Agent"'>The Station Agent</a>, <a href="favoritesearch.php?movieid=78" title='Find others users who listed "Blade Runner"'>Blade Runner</a>, <a href="favoritesearch.php?movieid=2609" title='Find others users who listed "Planes, Trains and Automobiles"'>Planes, Trains and Automobiles</a>, <a href="favoritesearch.php?movieid=1091" title='Find others users who listed "The Thing"'>The Thing</a>, <a href="favoritesearch.php?movieid=11797" title='Find others users who listed "Fright Night"'>Fright Night</a>, <a href="favoritesearch.php?movieid=24226" title='Find others users who listed "The Verdict"'>The Verdict</a>, <a href="favoritesearch.php? ...
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>, <a class="userlists" data-userid="96380" href="#" id="listlink_1695195" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>, <a href="">
# <div class="padded" style="top: 6px;">
# <div class="posticons_hover" style=""><a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96380" style="" title="View Joel's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a></div>
# <div class="posticons_hover" style=""><a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=96380" style="" title="Show Joel's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a></div>
# <div class="posticons_hover"><a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=96380" style="" title="Send Joel a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Message</a></div>
# </div>
# </a>, <a href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96380" style="" title="View Joel's Profile"><?xml version="1.0" standalone="no" ?><svg height="16" preserveaspectratio="xMidYMid meet" style="left: 5px; enable-background: new 0 0 512 512;" version="1.1" viewbox="0 0 512 512" width="16" xml:space="preserve" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><path d="M448,448c0,0,0-26.4-2.2-40.2c-1.8-10.9-16.9-25.3-81.1-48.9c-63.2-23.2-59.3-11.9-59.3-54.6c0-27.7,14.1-11.6,23.1-64.2  c3.5-20.7,6.3-6.9,13.9-40.1c4-17.4-2.7-18.7-1.9-27c0.8-8.3,1.6-15.7,3.1-32.7C345.4,119.3,325.9,64,256,64  c-69.9,0-89.4,55.3-87.5,76.4c1.5,16.9,2.3,24.4,3.1,32.7c0.8,8.3-5.9,9.6-1.9,27c7.6,33.1,10.4,19.3,13.9,40.1  c9,52.6,23.1,36.5,23.1,64.2c0,42.8,3.9,31.5-59.3,54.6c-64.2,23.5-79.4,38-81.1,48.9C64,421.6,64,448,64,448h192H448z" fill="#FFFFFF"></path></svg> Profile</a>, <a href="search.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=finduser&amp;u=96380" style="" title="Show Joel's Posts"><?xml version="1.0" standalone="no" ?><svg height="14" preserveaspectratio="xMidYMid meet" style="left: 7px;" version="1.1" viewbox="0 0 1024 973" width="14" xmlns="http://www.w3.org/2000/svg"><path d="M960 832L710.875 582.875C746.438 524.812 768 457.156 768 384 768 171.96900000000005 596 0 384 0 171.969 0 0 171.96900000000005 0 384c0 212 171.969 384 384 384 73.156 0 140.812-21.562 198.875-57L832 960c17.5 17.5 46.5 17.375 64 0l64-64C977.5 878.5 977.5 849.5 960 832zM384 640c-141.375 0-256-114.625-256-256s114.625-256 256-256 256 114.625 256 256S525.375 640 384 640z" fill="#FFFFFF"></path></svg> Posts</a>, <a href="private.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;do=newpm&amp;u=96380" style="" title="Send Joel a Message"><?xml version="1.0" standalone="no" ?><svg enable-background="new 140 170 500 500" height="38" preserveaspectratio="xMidYMid meet" style="left: 6px;" version="1.1" viewbox="140 170 500 500" width="32" xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink"><g><path d="M354.188,312.509l-60.577-65.686l60.632-60.735c1.254-1.256,3.399-0.368,3.399,1.406V311.16    C357.642,312.972,355.417,313.842,354.188,312.509z M261.667,278.823c-3.477,3.483-8.197,5.441-13.119,5.441h-0.157    c-5.008,0-9.812-1.987-13.357-5.526l-17.957-17.926l-61.616,62.724c-1.237,1.259-0.345,3.386,1.42,3.386h187.099    c1.735,0,2.639-2.065,1.463-3.34l-61.684-66.888L261.667,278.823z M248.392,270.329h0.004c1.33,0,2.58-0.519,3.52-1.46    l91.716-91.873c1.252-1.255,0.364-3.397-1.409-3.397h-187.97c-1.774,0-2.662,2.146-1.406,3.399l92.031,91.877    C245.816,269.814,247.064,270.329,248.392,270.329z M142.491,191.15v120.836c0,1.782,2.162,2.666,3.411,1.395l61.314-62.416    l-61.327-61.224C144.634,188.489,142.491,189.378,142.491,191.15z" fill="#FFFFFF"></path></g></svg>Message</a>, <a href="showthread.php?p=1695195#post1695195" rel="nofollow" title="4-29-17 at 11:39 PM">04-29-17</a>, <a class="closetip notextshadow" href="#" title="Close">X</a>, <a href="favoritesearch.php?movieid=90" title='Find others users who listed "Beverly Hills Cop"'>Beverly Hills Cop</a>, <a href="favoritesearch.php?movieid=2056" title='Find others users who listed "The Station Agent"'>The Station Agent</a>, <a href="favoritesearch.php?movieid=78" title='Find others users who listed "Blade Runner"'>Blade Runner</a>, <a href="favoritesearch.php?movieid=2609" title='Find others users who listed "Planes, Trains and Automobiles"'>Planes, Trains and Automobiles</a>, <a href="favoritesearch.php?movieid=1091" title='Find others users who listed "The Thing"'>The Thing</a>, <a href="favoritesearch.php?movieid=11797" title='Find others users who listed "Fright Night"'>Fright Night</a>, <a href="favoritesearch.php?movieid=24226" title='Find others users who listed "The Verdict"'>The Verdict</a>, <a href="favoritesearch.php?movieid=12498" title='Find others users who listed "Sling Blade"'>Sling Blade</a>, <a href="favoritesearch.php?movieid=9675" title='Find others users who ...
# ===========================
# <class 'bs4.element.ResultSet'>
# ===========================
# https://www.movieforums.com : Movie Forums
# https://www.movieforums.com :
# /movies : Movies
# /essays : Essays
# /reviews : Reviews
# /community : Forums
# /lists : Lists
# /boxoffice : Box Office
# /community/quiz.php : Quizzes
# # : None
# /community/search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=getdaily : Today's Posts
# /community/shoutbox.php?s=cdc988b455c2e529861d3d4f51f35e13& : The Shoutbox
# /community/register.php??s=cdc988b455c2e529861d3d4f51f35e13 : Register
# /community/login_plain.php?s=cdc988b455c2e529861d3d4f51f35e13& : Log In
# /community/register.php?cdc988b455c2e529861d3d4f51f35e13 : Register Today!
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-10-9eb43aa0a3f6> in <module>()
#       8 # say I wanted to find out all the links and text displayed
#       9 for i in links:
# ---> 10      print(i['href'], ":", i.string)
#
# /anaconda/lib/python3.6/site-packages/bs4/element.py in __getitem__(self, key)
#    1009         """tag[key] returns the value of the 'key' attribute for the tag,
#    1010         and throws an exception if it's not there."""
# -> 1011         return self.attrs[key]
#    1012
#    1013     def __iter__(self):
#
# KeyError: 'href'

# %%
# we got a key error! I should probably deal with that error

for i in links:
    try:
        print(i['href'], ":", i.string)
    except KeyError:
        pass # I don't care mwhat happens to links without 'href's, so I skip them
# Out:
# https://www.movieforums.com : Movie Forums
# https://www.movieforums.com :
# /movies : Movies
# /essays : Essays
# /reviews : Reviews
# /community : Forums
# /lists : Lists
# /boxoffice : Box Office
# /community/quiz.php : Quizzes
# # : None
# /community/search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=getdaily : Today's Posts
# /community/shoutbox.php?s=cdc988b455c2e529861d3d4f51f35e13& : The Shoutbox
# /community/register.php??s=cdc988b455c2e529861d3d4f51f35e13 : Register
# /community/login_plain.php?s=cdc988b455c2e529861d3d4f51f35e13& : Log In
# /community/register.php?cdc988b455c2e529861d3d4f51f35e13 : Register Today!
# general-movie-discussion.html : General Movie Discussion
# #goto_threadtools : Tools
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&t=49209&page=2 : 2
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&t=49209&page=2 : »
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&t=49209&page=5 : None
# newreply.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newreply&noquote=1&p=1695060 : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96481 : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96481 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=96481 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=96481 : None
# showthread.php?p=1695060#post1695060 : 04-29-17
# # : None
# # : X
# favoritesearch.php?movieid=11873 : The Color of Money
# favoritesearch.php?movieid=55448 : Money for Nothing
# favoritesearch.php?movieid=10466 : The Money Pit
# favoritesearch.php?movieid=3090 : The Treasure Of The Sierra Madre
# favoritesearch.php?movieid=6463 : Other Peoples Money
# favoritesearch.php?movieid=11064 : Brewsters Millions
# favoritesearch.php?movieid=524 : Casino
# favoritesearch.php?movieid=10673 : Wall Street
# favoritesearch.php?movieid=1621 : Trading Places
# favoritesearch.php?movieid=9504 : Glengary Glen Ross
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=75073 : None
# # : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=75073 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=75073 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=75073 : None
# showthread.php?p=1695061#post1695061 : 04-29-17
# # : X
# favoritesearch.php?movieid=11976 : Legend
# favoritesearch.php?movieid=15794 : White Heat
# favoritesearch.php?movieid=900 : Bringing Up Baby
# favoritesearch.php?movieid=78 : Blade Runner
# favoritesearch.php?movieid=5483 : Lisa and the Devil
# favoritesearch.php?movieid=691 : The Spy Who Loved Me
# favoritesearch.php?movieid=10907 : The Adventures of Robin Hood
# favoritesearch.php?movieid=10428 : Hackers
# favoritesearch.php?movieid=9434 : Grosse Pointe Blank
# favoritesearch.php?movieid=284 : The Apartment
# # : X
# /lists/afis_100_years_100_movies/75073.html : 100 Years...100 Movies
# /lists/afis_100_years_100_laughs/75073.html : 100 Years...100 Laughs
# /lists/afis_100_years_100_thrills/75073.html : 100 Years...100 Thrills
# /lists/afis_100_years_100_passions/75073.html : 100 Years...100 Passions
# /lists/afis_100_years_100_cheers/75073.html : 100 Years...100 Cheers
# /lists/afis_100_years_of_musicals/75073.html : 100 Years of Musicals
# /lists/viewall/75073.html : View All Lists
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=95651 : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=95651 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=95651 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=95651 : None
# showthread.php?p=1695062#post1695062 : 04-29-17
# # : X
# favoritesearch.php?movieid=60270 : Wish You Were Here
# favoritesearch.php?movieid=48340 : Sanctum
# favoritesearch.php?movieid=66113 : In Her Skin
# favoritesearch.php?movieid=66125 : Red Dog
# favoritesearch.php?movieid=287903 : Krampus
# favoritesearch.php?movieid=333386 : The Duel
# favoritesearch.php?movieid=331583 : The Whole Truth
# favoritesearch.php?movieid=9774 : Kokoda
# favoritesearch.php?movieid=390043 : The Hitman's Bodyguard
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=83561 : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=83561 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=83561 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=83561 : None
# showthread.php?p=1695063#post1695063 : 04-29-17
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=95651 : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=95651 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=95651 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=95651 : None
# showthread.php?p=1695064#post1695064 : 04-29-17
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&p=1695063#post1695063 : None
# # : X
# favoritesearch.php?movieid=60270 : Wish You Were Here
# favoritesearch.php?movieid=48340 : Sanctum
# favoritesearch.php?movieid=66113 : In Her Skin
# favoritesearch.php?movieid=66125 : Red Dog
# favoritesearch.php?movieid=287903 : Krampus
# favoritesearch.php?movieid=333386 : The Duel
# favoritesearch.php?movieid=331583 : The Whole Truth
# favoritesearch.php?movieid=9774 : Kokoda
# favoritesearch.php?movieid=390043 : The Hitman's Bodyguard
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=85347 : None
# # : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=85347 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=85347 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=85347 : None
# showthread.php?p=1695107#post1695107 : 04-29-17
# https://www.movieforums.com/community/showthread.php?p=1771126#post1771126 : None
# https://www.movieforums.com/community/showthread.php?t=37926 : MovieMeditation's Cinema Reviews
# https://www.movieforums.com/community/showthread.php?p=1234644#post1234644 : #1 Film Diary 2015
# https://letterboxd.com/MovieMeditation/ : Letterboxd Profile
# http://oc.mymovies.dk/ABjerg : DVD & Blu-ray Collection
# https://www.movieforums.com/community/showthread.php?t=40665 : MovieMeditation's Top 50 Horror
# # : X
# favoritesearch.php?movieid=6977 : No Country for Old Men
# favoritesearch.php?movieid=289 : Casablanca
# favoritesearch.php?movieid=334 : Magnolia
# favoritesearch.php?movieid=8967 : The Tree of Life
# favoritesearch.php?movieid=393 : Kill Bill: Vol. 2
# favoritesearch.php?movieid=9693 : Children of Men
# favoritesearch.php?movieid=86829 : Inside Llewyn Davis
# favoritesearch.php?movieid=84175 : Beasts of the Southern Wild
# favoritesearch.php?movieid=132344 : Before Midnight
# favoritesearch.php?movieid=155 : The Dark Knight
# # : X
# /lists/movie_forums_comic_book_movies/85347.html : MF: Comic Book Movies
# /lists/movie_forums_top_100_2010/85347.html : MF: Top 100 (2010)
# /lists/movie_forums_animated/85347.html : MF: Top Animated Films
# /lists/movie_forums_millennium_100/85347.html : MF: Millennium 100
# /lists/movie_forums_1990s/85347.html : MF: Top Films of 90s
# /lists/viewall/85347.html : View All Lists
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=68505 : None
# # : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=68505 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=68505 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=68505 : None
# showthread.php?p=1695109#post1695109 : 04-29-17
# # : X
# favoritesearch.php?movieid=769 : Goodfellas
# favoritesearch.php?movieid=103 : Taxi Driver
# favoritesearch.php?movieid=4995 : Boogie Nights
# favoritesearch.php?movieid=185 : A Clockwork Orange
# favoritesearch.php?movieid=814 : An American Werewolf in London
# favoritesearch.php?movieid=14 : American Beauty
# favoritesearch.php?movieid=1696 : The Devil's Rejects
# favoritesearch.php?movieid=525 : The Blues Brothers
# favoritesearch.php?movieid=346 : Seven Samurai
# favoritesearch.php?movieid=9988 : Beerfest
# # : X
# /lists/afis_100_years_100_movies/68505.html : 100 Years...100 Movies
# /lists/afis_100_years_100_laughs/68505.html : 100 Years...100 Laughs
# /lists/afis_100_years_100_thrills/68505.html : 100 Years...100 Thrills
# /lists/afis_100_years_100_passions/68505.html : 100 Years...100 Passions
# /lists/afis_100_years_100_cheers/68505.html : 100 Years...100 Cheers
# /lists/afis_100_years_of_musicals/68505.html : 100 Years of Musicals
# /lists/viewall/68505.html : View All Lists
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=95651 : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=95651 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=95651 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=95651 : None
# showthread.php?p=1695110#post1695110 : 04-29-17
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&p=1695109#post1695109 : None
# # : X
# favoritesearch.php?movieid=60270 : Wish You Were Here
# favoritesearch.php?movieid=48340 : Sanctum
# favoritesearch.php?movieid=66113 : In Her Skin
# favoritesearch.php?movieid=66125 : Red Dog
# favoritesearch.php?movieid=287903 : Krampus
# favoritesearch.php?movieid=333386 : The Duel
# favoritesearch.php?movieid=331583 : The Whole Truth
# favoritesearch.php?movieid=9774 : Kokoda
# favoritesearch.php?movieid=390043 : The Hitman's Bodyguard
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=88640 : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=88640 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=88640 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=88640 : None
# showthread.php?p=1695111#post1695111 : 04-29-17
# https://letterboxd.com/Redwell/ : Letterboxd
# https://squawkr.io/ : Squakwr
# http://reverseshot.org/ : ReverseShot
# http://slantmagazine.com/ : SlantMagazine
# # : X
# favoritesearch.php?movieid=68722 : The Master
# favoritesearch.php?movieid=16642 : Days of Heaven
# favoritesearch.php?movieid=30497 : The Texas Chain Saw Massacre
# favoritesearch.php?movieid=95043 : The Devil
# favoritesearch.php?movieid=21484 : Possession
# favoritesearch.php?movieid=82027 : Crows
# favoritesearch.php?movieid=16672 : Woman in the Dunes
# favoritesearch.php?movieid=8416 : The Conformist
# favoritesearch.php?movieid=11481 : Repulsion
# favoritesearch.php?movieid=27236 : Two-Lane Blacktop
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96053 : None
# # : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96053 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=96053 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=96053 : None
# showthread.php?p=1695114#post1695114 : 04-29-17
#  : View Spoilers
# # : X
# favoritesearch.php?movieid=948 : Halloween
# favoritesearch.php?movieid=429 : The Good, the Bad and the Ugly
# favoritesearch.php?movieid=814 : An American Werewolf in London
# favoritesearch.php?movieid=562 : Die Hard
# favoritesearch.php?movieid=2493 : The Princess Bride
# favoritesearch.php?movieid=710 : GoldenEye
# favoritesearch.php?movieid=30497 : The Texas Chain Saw Massacre
# favoritesearch.php?movieid=583 : Life of Brian
# favoritesearch.php?movieid=346 : Seven Samurai
# favoritesearch.php?movieid=783 : Gandhi
# # : X
# /lists/afis_100_years_100_movies/96053.html : 100 Years...100 Movies
# /lists/afis_100_years_100_laughs/96053.html : 100 Years...100 Laughs
# /lists/afis_100_years_100_thrills/96053.html : 100 Years...100 Thrills
# /lists/afis_100_years_100_passions/96053.html : 100 Years...100 Passions
# /lists/afis_100_years_100_cheers/96053.html : 100 Years...100 Cheers
# /lists/afis_100_years_of_musicals/96053.html : 100 Years of Musicals
# /lists/viewall/96053.html : View All Lists
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96481 : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96481 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=96481 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=96481 : None
# showthread.php?p=1695137#post1695137 : 04-29-17
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96053 : None
# # : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96053 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=96053 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=96053 : None
# showthread.php?p=1695139#post1695139 : 04-29-17
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&p=1695137#post1695137 : None
# # : X
# favoritesearch.php?movieid=948 : Halloween
# favoritesearch.php?movieid=429 : The Good, the Bad and the Ugly
# favoritesearch.php?movieid=814 : An American Werewolf in London
# favoritesearch.php?movieid=562 : Die Hard
# favoritesearch.php?movieid=2493 : The Princess Bride
# favoritesearch.php?movieid=710 : GoldenEye
# favoritesearch.php?movieid=30497 : The Texas Chain Saw Massacre
# favoritesearch.php?movieid=583 : Life of Brian
# favoritesearch.php?movieid=346 : Seven Samurai
# favoritesearch.php?movieid=783 : Gandhi
# # : X
# /lists/afis_100_years_100_movies/96053.html : 100 Years...100 Movies
# /lists/afis_100_years_100_laughs/96053.html : 100 Years...100 Laughs
# /lists/afis_100_years_100_thrills/96053.html : 100 Years...100 Thrills
# /lists/afis_100_years_100_passions/96053.html : 100 Years...100 Passions
# /lists/afis_100_years_100_cheers/96053.html : 100 Years...100 Cheers
# /lists/afis_100_years_of_musicals/96053.html : 100 Years of Musicals
# /lists/viewall/96053.html : View All Lists
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=85193 : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=85193 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=85193 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=85193 : None
# showthread.php?p=1695141#post1695141 : 04-29-17
# https://www.movieforums.com/community/showthread.php?t=48685 : here!
# https://www.movieforums.com/community/showthread.php?anchor=1&p=1276583#post1276583 : here
# # : X
# /lists/movie_forums_top_100_2010/85193.html : MF: Top 100 (2010)
# /lists/movie_forums_millennium_100/85193.html : MF: Millennium 100
# /lists/afis_100_years_100_movies/85193.html : 100 Years...100 Movies
# /lists/sight_and_sounds_directors_poll/85193.html : Sight & Sound: Directors Poll
# /lists/movie_forums_comic_book_movies/85193.html : MF: Comic Book Movies
# /lists/afis_100_years_100_thrills/85193.html : 100 Years...100 Thrills
# /lists/viewall/85193.html : View All Lists
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=85776 : None
# # : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=85776 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=85776 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=85776 : None
# showthread.php?p=1695142#post1695142 : 04-29-17
# # : X
# favoritesearch.php?movieid=609 : Poltergeist
# favoritesearch.php?movieid=154 : Star Trek II: The Wrath of Khan
# favoritesearch.php?movieid=85 : Raiders of the Lost Ark
# favoritesearch.php?movieid=3525 : Working Girl
# favoritesearch.php?movieid=274 : The Silence of the Lambs
# favoritesearch.php?movieid=5548 : RoboCop
# favoritesearch.php?movieid=861 : Total Recall
# favoritesearch.php?movieid=578 : Jaws
# favoritesearch.php?movieid=149 : Akira
# favoritesearch.php?movieid=6341 : Blue Thunder
# # : X
# /lists/afis_100_years_100_thrills/85776.html : 100 Years...100 Thrills
# /lists/movie_forums_top_100_2010/85776.html : MF: Top 100 (2010)
# /lists/afis_100_years_100_cheers/85776.html : 100 Years...100 Cheers
# /lists/movie_forums_1980s/85776.html : MF: Top Films of 80s
# /lists/afis_100_years_100_movies/85776.html : 100 Years...100 Movies
# /lists/viewall/85776.html : View All Lists
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=95651 : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=95651 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=95651 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=95651 : None
# showthread.php?p=1695145#post1695145 : 04-29-17
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&p=1695137#post1695137 : None
# # : X
# favoritesearch.php?movieid=60270 : Wish You Were Here
# favoritesearch.php?movieid=48340 : Sanctum
# favoritesearch.php?movieid=66113 : In Her Skin
# favoritesearch.php?movieid=66125 : Red Dog
# favoritesearch.php?movieid=287903 : Krampus
# favoritesearch.php?movieid=333386 : The Duel
# favoritesearch.php?movieid=331583 : The Whole Truth
# favoritesearch.php?movieid=9774 : Kokoda
# favoritesearch.php?movieid=390043 : The Hitman's Bodyguard
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96919 : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96919 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=96919 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=96919 : None
# showthread.php?p=1695146#post1695146 : 04-29-17
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=95985 : None
# # : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=95985 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=95985 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=95985 : None
# showthread.php?p=1695150#post1695150 : 04-29-17
# # : X
# favoritesearch.php?movieid=1955 : The Elephant Man
# favoritesearch.php?movieid=62 : 2001: A Space Odyssey
# favoritesearch.php?movieid=597 : Titanic
# # : X
# /lists/afis_100_years_100_movies/95985.html : 100 Years...100 Movies
# /lists/afis_100_years_100_laughs/95985.html : 100 Years...100 Laughs
# /lists/afis_100_years_100_thrills/95985.html : 100 Years...100 Thrills
# /lists/afis_100_years_100_passions/95985.html : 100 Years...100 Passions
# /lists/afis_100_years_100_cheers/95985.html : 100 Years...100 Cheers
# /lists/afis_100_years_of_musicals/95985.html : 100 Years of Musicals
# /lists/viewall/95985.html : View All Lists
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=75073 : None
# # : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=75073 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=75073 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=75073 : None
# showthread.php?p=1695162#post1695162 : 04-29-17
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&p=1695150#post1695150 : None
# # : X
# favoritesearch.php?movieid=11976 : Legend
# favoritesearch.php?movieid=15794 : White Heat
# favoritesearch.php?movieid=900 : Bringing Up Baby
# favoritesearch.php?movieid=78 : Blade Runner
# favoritesearch.php?movieid=5483 : Lisa and the Devil
# favoritesearch.php?movieid=691 : The Spy Who Loved Me
# favoritesearch.php?movieid=10907 : The Adventures of Robin Hood
# favoritesearch.php?movieid=10428 : Hackers
# favoritesearch.php?movieid=9434 : Grosse Pointe Blank
# favoritesearch.php?movieid=284 : The Apartment
# # : X
# /lists/afis_100_years_100_movies/75073.html : 100 Years...100 Movies
# /lists/afis_100_years_100_laughs/75073.html : 100 Years...100 Laughs
# /lists/afis_100_years_100_thrills/75073.html : 100 Years...100 Thrills
# /lists/afis_100_years_100_passions/75073.html : 100 Years...100 Passions
# /lists/afis_100_years_100_cheers/75073.html : 100 Years...100 Cheers
# /lists/afis_100_years_of_musicals/75073.html : 100 Years of Musicals
# /lists/viewall/75073.html : View All Lists
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96380 : None
# # : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96380 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=96380 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=96380 : None
# showthread.php?p=1695184#post1695184 : 04-29-17
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&p=1695145#post1695145 : None
# # : X
# favoritesearch.php?movieid=90 : Beverly Hills Cop
# favoritesearch.php?movieid=2056 : The Station Agent
# favoritesearch.php?movieid=78 : Blade Runner
# favoritesearch.php?movieid=2609 : Planes, Trains and Automobiles
# favoritesearch.php?movieid=1091 : The Thing
# favoritesearch.php?movieid=11797 : Fright Night
# favoritesearch.php?movieid=24226 : The Verdict
# favoritesearch.php?movieid=12498 : Sling Blade
# favoritesearch.php?movieid=9675 : Sideways
# favoritesearch.php?movieid=9346 : Risky Business
# # : X
# /lists/afis_100_years_100_movies/96380.html : 100 Years...100 Movies
# /lists/afis_100_years_100_laughs/96380.html : 100 Years...100 Laughs
# /lists/afis_100_years_100_thrills/96380.html : 100 Years...100 Thrills
# /lists/afis_100_years_100_passions/96380.html : 100 Years...100 Passions
# /lists/afis_100_years_100_cheers/96380.html : 100 Years...100 Cheers
# /lists/afis_100_years_of_musicals/96380.html : 100 Years of Musicals
# /lists/viewall/96380.html : View All Lists
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96380 : None
# # : None
# # : None
#  : None
# member.php?s=cdc988b455c2e529861d3d4f51f35e13&u=96380 : None
# search.php?s=cdc988b455c2e529861d3d4f51f35e13&do=finduser&u=96380 : None
# private.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newpm&u=96380 : None
# showthread.php?p=1695195#post1695195 : 04-29-17
# # : X
# favoritesearch.php?movieid=90 : Beverly Hills Cop
# favoritesearch.php?movieid=2056 : The Station Agent
# favoritesearch.php?movieid=78 : Blade Runner
# favoritesearch.php?movieid=2609 : Planes, Trains and Automobiles
# favoritesearch.php?movieid=1091 : The Thing
# favoritesearch.php?movieid=11797 : Fright Night
# favoritesearch.php?movieid=24226 : The Verdict
# favoritesearch.php?movieid=12498 : Sling Blade
# favoritesearch.php?movieid=9675 : Sideways
# favoritesearch.php?movieid=9346 : Risky Business
# # : X
# /lists/afis_100_years_100_movies/96380.html : 100 Years...100 Movies
# /lists/afis_100_years_100_laughs/96380.html : 100 Years...100 Laughs
# /lists/afis_100_years_100_thrills/96380.html : 100 Years...100 Thrills
# /lists/afis_100_years_100_passions/96380.html : 100 Years...100 Passions
# /lists/afis_100_years_100_cheers/96380.html : 100 Years...100 Cheers
# /lists/afis_100_years_of_musicals/96380.html : 100 Years of Musicals
# /lists/viewall/96380.html : View All Lists
# newreply.php?s=cdc988b455c2e529861d3d4f51f35e13&do=newreply&noquote=1&p=1695060 : None
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&t=49209&page=2 : 2
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&t=49209&page=2 : »
# showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&t=49209&page=5 : None
# printthread.php?s=cdc988b455c2e529861d3d4f51f35e13&t=49209 : Show Printable Version
# sendmessage.php?s=cdc988b455c2e529861d3d4f51f35e13&do=sendtofriend&t=49209 : Email this Page
# https://www.twitter.com/movieforums : @movieforums
# / : Movie Forums
# /essays : Essays
# /reviews : Reviews
# /lists : Lists
# /boxoffice : Box Office
# /community/quiz.php : Quizzes
# /community/rules.php : None
# /community/search.php : None
# https://www.themoviedb.org : None

# %%
# you could also get all the text on the page (problem solved, right?)
soup.get_text()
# Out:
# '\n\n\n Is Die Hard (1988) overrated? - Movie Forums\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\n\r\n/**\r\n* vBulletin 3.8.0 CSS\r\n* Style: \'Radioactive\'; Style ID: 17\r\n*/\r\nbody\r\n{\r\n\tfont: 16px Arial, Helvetica, sans-serif;\r\n\tmargin: 0px 0px 0px 0px;\r\n\tscrollbar-3dlight-color: #000; \r\n\tscrollbar-arrow-color: #FFFFFF;\r\n\tscrollbar-base-color: #000;\r\n\tscrollbar-darkshadow-color: #404040;\r\n\tscrollbar-face-color: #262626;\r\n\tscrollbar-highlight-color: #595959;\r\n\tscrollbar-shadow-color: #000;\r\n}\r\ntd, th, p, li\r\n{\r\n\tfont-family: Arial, Helvetica, sans-serif;\r\n}\r\n.tborder\r\n{\r\n\tcolor: #000000;\r\n\tborder: 0px solid #000000;\r\n}\r\n.tcat\r\n{\r\n\tcolor: #CCC;\r\n\tfont-size: 16px;\r\n\tfont-family: \'Futura\', sans-serif;\r\n}\r\n.tcat a:link, .tcat_alink\r\n{\r\n\tcolor: #FFFFFF;\r\n\ttext-decoration: none;\r\n}\r\n.tcat a:visited, .tcat_avisited\r\n{\r\n\tcolor: #FFFFFF;\r\n\ttext-decoration: none;\r\n}\r\n.tcat a:hover, .tcat a:active, .tcat_ahover\r\n{\r\n\tcolor: #FFFFAE;\r\n\ttext-decoration: underline;\r\n}\r\n.thead\r\n{\r\n\tcolor: #FFFFFF;\r\n\tfont-family: Arial, Helvetica, sans-serif;\r\n}\r\n.thead a:link, .thead_alink\r\n{\r\n\tcolor: #FFFFFF;\r\n}\r\n.thead a:visited, .thead_avisited\r\n{\r\n\tcolor: #FFFFFF;\r\n}\r\n.thead a:hover, .thead a:active, .thead_ahover\r\n{\r\n\tcolor: #FFFFAE;\r\n}\r\n.tfoot\r\n{\r\n\tbackground: #373737;\r\n\tcolor: #FFFFFF;\r\n}\r\n.tfoot a:link, .tfoot_alink\r\n{\r\n\tcolor: #FFFFFF;\r\n}\r\n.tfoot a:visited, .tfoot_avisited\r\n{\r\n\tcolor: #FFFFFF;\r\n}\r\n.tfoot a:hover, .tfoot a:active, .tfoot_ahover\r\n{\r\n\tcolor: #FFFFAE;\r\n}\r\n.alt1, .alt1Active\r\n{\r\n\tcolor: #CCC;\r\n\tbackground: url(/images/blackpixel_40.png);\r\n}\r\n.alt2, .alt2Active\r\n{\r\n\tcolor: #CCC;\r\n}\r\n.inlinemod\r\n{\r\n\tbackground: #FFFFCC;\r\n\tcolor: #000000;\r\n}\r\n.wysiwyg\r\n{\r\n\tbackground: #E4E4E4;\r\n\tcolor: #000000;\r\n\tfont-family: Arial, Helvetica, sans-serif;\r\n\tbackground-repeat: no-repeat;\r\n\tbackground-color: #E4E4E4;\r\n}\r\ntextarea, .bginput\r\n{\r\n\tfont-family: Arial, Helvetica, sans-serif;\r\n}\r\n.bginput option, .bginput optgroup\r\n{\r\n\tfont-family: Arial, Helvetica, sans-serif;\r\n}\r\n.button\r\n{\r\n\tfont-family: Arial, Helvetica, sans-serif;\r\n}\r\n.smallfont\r\n{\r\n\tfont-family: Arial, Helvetica, sans-serif;\r\n}\r\n.time\r\n{\r\n\tcolor: #666666;\r\n}\r\n.navbar\r\n{\r\n\tfont-family: Arial, Helvetica, sans-serif;\r\n}\r\n.highlight\r\n{\r\n\tcolor: #FF0000;\r\n\tfont-weight: bold;\r\n}\r\n.fjsel\r\n{\r\n\tbackground: #333333;\r\n\tcolor: #D4D4D4;\r\n}\r\n.fjdpth0\r\n{\r\n\tbackground: #D4D4D4;\r\n\tcolor: #000000;\r\n}\r\n.panel\r\n{\r\n\tcolor: #999;\r\n\tpadding: 10px;\r\n\t\r\n}\r\nlegend\r\n{\r\n\tcolor: #000000;\r\n\tfont-family: Arial, Helvetica, sans-serif;\r\n}\r\n.vbmenu_control\r\n{\r\n\tbackground: #000;\r\n\tcolor: #E1E1E1;\r\n\tfont-family: Arial, sans-serif;\r\n\tpadding: 3px 6px 3px 6px;\r\n\twhite-space: nowrap;\r\n\tborder: 1px solid #777;\r\n\tborder-radius: 7px 7px 0 0;\r\n}\r\n.vbmenu_control a:link, .vbmenu_control_alink\r\n{\r\n\tcolor: #FFFFFF;\r\n\ttext-decoration: none;\r\n}\r\n.vbmenu_control a:visited, .vbmenu_control_avisited\r\n{\r\n\tcolor: #FFFFFF;\r\n\ttext-decoration: none;\r\n}\r\n.vbmenu_control a:hover, .vbmenu_control a:active, .vbmenu_control_ahover\r\n{\r\n\tcolor: #FFFFAE;\r\n\ttext-decoration: underline;\r\n}\r\n.vbmenu_popup\r\n{\r\n\tbackground: #FFFFFF;\r\n\tcolor: #000000;\r\n\tborder: solid 1px #000000;\r\n\ttext-align: left;\r\n}\r\n.vbmenu_option\r\n{\r\n\tbackground: #CCCCCC;\r\n\tcolor: #000000;\r\n\tfont-family: Arial, Helvetica, sans-serif;\r\n\twhite-space: nowrap;\r\n\tcursor: hand;\r\n}\r\n.vbmenu_option a:link, .vbmenu_option_alink\r\n{\r\n\tcolor: #005C00;\r\n\ttext-decoration: none;\r\n}\r\n.vbmenu_option a:visited, .vbmenu_option_avisited\r\n{\r\n\tcolor: #005C00;\r\n\ttext-decoration: none;\r\n}\r\n.vbmenu_option a:hover, .vbmenu_opti ...

# %% [markdown]
# Problems with this "solution":
# <ul>
# <li> It's ugly </li>
# <li> Everything is smushed together - you don't know who said what or when. </li>
# <li> You literally have all the text including..
# <ul>
# <li>quotes (that'd be repeated text)</li>
# <li>signatures (meaningless to the question) </li>
# <li>and all the text that is a part of the webpage! </li>
# </ul>
# </ul>
#
# <p> So it looks like what we really want to do is find each post, and then get the information we want from it</p>

# %%
## after doing some detective work, we discovered that posts are found in div tags with class 'post'.

allDiv = soup.find_all('div') # all div's
postDivs = [] # empty list
postDateDivs = []
postTextDivs = []

for div in allDiv:
    try:
        if 'post' in div.get('class'): # if it's a post, add to post list
            postDivs.append(div)
        elif 'postdate' in div.get('class'): # if it's a date, add to date list
            postDateDivs.append(div)
        elif 'posttext' in div.get('class'): # if it's text, add to text list
            postTextDivs.append(div)
    except Exception:
        pass

# %%
postTextDivs.pop(1) # the advertisement is always the second post
postDivs.pop(1) # the advertisement is always the second post

print(len(postDivs))
print(len(postDateDivs))
print(len(postTextDivs))
print(postDivs)
print("+++++++++++++")
print(postDateDivs)
print("+++++++++++++")
print(postTextDivs)
# Out:
# 19
# 20
# 19
# [<div class="post" id="post1695060">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481" style="padding-right: 10px;" title="View ironpony's Profile"><span>i</span>ronpony</a>
# </div>
# <div <a="" class="thumb noavatar" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481"><img alt="ironpony's Avatar" class="lightshadow" data-postid="1695060" height="89" src="/images/reel_avatar_89x89.png" style="margin-bottom: 1px;border: 0; box-shadow: none; width: 89px; height: 89px;" width="89"/></div></div></div>, <div class="post" id="post1695062">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="padding-right: 10px;" title="View Dani8's Profile"><span>D</span>ani8</a> <a class="favs" data-userid="95651" href="#" id="favlink_1695062" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="width: 77px; height: 90px;"><img alt="Dani8's Avatar" class="lightshadow" data-postid="1695062" src="customavatars/avatar95651_1.gif" style="margin-bottom: 1px; width: 77px; height: 90px;"/></div></div></div>, <div class="post" id="post1695063">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=83561" style="padding-right: 10px;" title="View rambond's Profile"><span>r</span>ambond</a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=83561" style="width: 90px; height: 90px;"><img alt="rambond's Avatar" class="lightshadow" data-postid="1695063" src="customavatars/avatar83561_1.gif" style="margin-bottom: 1px; width: 90px; height: 90px;"/></div></div></div>, <div class="post" id="post1695064">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="padding-right: 10px;" title="View Dani8's Profile"><span>D</span>ani8</a> <a class="favs" data-userid="95651" href="#" id="favlink_1695064" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="width: 77px; height: 90px;"><img alt="Dani8's Avatar" class="lightshadow" data-postid="1695064" src="customavatars/avatar95651_1.gif" style="margin-bottom: 1px; width: 77px; height: 90px;"/></div></div></div>, <div class="post" id="post1695107">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=85347" style="font-size: 1.3em; padding-right: 10px;" title="View MovieMeditation's Profile"><span>M</span>ovieMeditation</a> <a class="favs" data-userid="85347" href="#" id="favlink_1695107" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# <a class="userlists" data-userid="85347" href="#" id="listlink_1695107" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=85347" style="width: 90px; height: 90px;"><img alt="MovieMeditation's Avatar" class="lightshadow" data-postid="1695107" src="customavatars/avatar85347_37.gif" style="margin-bottom: 1px; width: 90px; height: 90px;"/></div></div></div>, <div class="post" id="post1695109">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=68505" style="padding-right: 10px;" title="View cricket's Profile"><span>c</span>ricket</a> <a class="favs" data-userid="68505" href="#" id="favlink_1695109" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# <a class="userlists" data-userid="68505" href="#" id="listlink_1695109" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=68505" style="width: 110px; height: 90px;"><img alt="cricket's Avatar" class="lightshadow" data-postid="1695109" src="customavatars/avatar68505_68.gif" style="margin-bottom: 1px; width: 110px; height: 90px;"/></div></div></div>, <div class="post" id="post1695110">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="padding-right: 10px;" title="View Dani8's Profile"><span>D</span>ani8</a> <a class="favs" data-userid="95651" href="#" id="favlink_1695110" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="width: 77px; height: 90px;"><img alt="Dani8's Avatar" class="lightshadow" data-postid="1695110" src="customavatars/avatar95651_1.gif" style="margin-bottom: 1px; width: 77px; height: 90px;"/></div></div></div>, <div class="post" id="post1695111">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=88640" style="padding-right: 10px;" title="View Redwell's Profile"><span>R</span>edwell</a> <a class="favs" data-userid="88640" href="#" id="favlink_1695111" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=88640" style="width: 110px; height: 90px;"><img alt="Redwell's Avatar" class="lightshadow" data-postid="1695111" src="customavatars/avatar88640_6.gif" style="margin-bottom: 1px; width: 110px; height: 90px;"/></div></div></div>, <div class="post" id="post1695114">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96053" style="font-size: 1.3em; padding-right: 10px;" title="View BoxOfficePoison's Profile"><span>B</span>oxOfficePoison</a> <a class="favs" data-userid="96053" href="#" id="favlink_1695114" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# <a class="userlists" data-userid="96053" href="#" id="listlink_1695114" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96053" style="width: 96px; height: 90px;"><img alt="BoxOfficePoison's Avatar" class="lightshadow" data-postid="1695114" src="customavatars/avatar96053_1.gif" style="margin-bottom: 1px; width: 96px; height: 90px;"/></div></div></div>, <div class="post" id="post1695137">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481" style="padding-right: 10px;" title="View ironpony's Profile"><span>i</span>ronpony</a>
# </div>
# <div <a="" class="thumb noavatar" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96481"><img alt="ironpony's Avatar" class="lightshadow" data-postid="1695137" height="89" src="/images/reel_avatar_89x89.png" style="margin-bottom: 1px;border: 0; box-shadow: none; width: 89px; height: 89px;" width="89"/></div></div></div>, <div class="post" id="post1695139">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96053" style="font-size: 1.3em; padding-right: 10px;" title="View BoxOfficePoison's Profile"><span>B</span>oxOfficePoison</a> <a class="favs" data-userid="96053" href="#" id="favlink_1695139" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# <a class="userlists" data-userid="96053" href="#" id="listlink_1695139" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96053" style="width: 96px; height: 90px;"><img alt="BoxOfficePoison's Avatar" class="lightshadow" data-postid="1695139" src="customavatars/avatar96053_1.gif" style="margin-bottom: 1px; width: 96px; height: 90px;"/></div></div></div>, <div class="post" id="post1695141">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=85193" style="padding-right: 10px;" title="View neiba's Profile"><span>n</span>eiba</a>
# <a class="userlists" data-userid="85193" href="#" id="listlink_1695141" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=85193" style="width: 90px; height: 90px;"><img alt="neiba's Avatar" class="lightshadow" data-postid="1695141" src="customavatars/avatar85193_44.gif" style="margin-bottom: 1px; width: 90px; height: 90px;"/></div></div></div>, <div class="post" id="post1695142">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=85776" style="padding-right: 10px;" title="View Steve Freeling's Profile"><span>S</span>teve Freeling</a> <a class="favs" data-userid="85776" href="#" id="favlink_1695142" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# <a class="userlists" data-userid="85776" href="#" id="listlink_1695142" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=85776" style="width: 90px; height: 90px;"><img alt="Steve Freeling's Avatar" class="lightshadow" data-postid="1695142" src="customavatars/avatar85776_16.gif" style="margin-bottom: 1px; width: 90px; height: 90px;"/></div></div></div>, <div class="post" id="post1695145">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="padding-right: 10px;" title="View Dani8's Profile"><span>D</span>ani8</a> <a class="favs" data-userid="95651" href="#" id="favlink_1695145" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95651" style="width: 77px; height: 90px;"><img alt="Dani8's Avatar" class="lightshadow" data-postid="1695145" src="customavatars/avatar95651_1.gif" style="margin-bottom: 1px; width: 77px; height: 90px;"/></div></div></div>, <div class="post" id="post1695146">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96919" style="padding-right: 10px;" title="View GulfportDoc's Profile"><span>G</span>ulfportDoc</a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96919" style="width: 110px; height: 83px;"><img alt="GulfportDoc's Avatar" class="lightshadow" data-postid="1695146" src="customavatars/avatar96919_2.gif" style="margin-bottom: 1px; width: 110px; height: 83px;"/></div></div></div>, <div class="post" id="post1695150">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95985" style="font-size: 1.3em; padding-right: 10px;" title="View mattiasflgrtll6's Profile"><span>m</span>attiasflgrtll6</a> <a class="favs" data-userid="95985" href="#" id="favlink_1695150" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# <a class="userlists" data-userid="95985" href="#" id="listlink_1695150" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=95985" style="width: 110px; height: 83px;"><img alt="mattiasflgrtll6's Avatar" class="lightshadow" data-postid="1695150" src="customavatars/avatar95985_1.gif" style="margin-bottom: 1px; width: 110px; height: 83px;"/></div></div></div>, <div class="post" id="post1695162">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=75073" style="font-size: 1.3em; padding-right: 10px;" title="View Blix the Goblin's Profile"><span>B</span>lix the Goblin</a> <a class="favs" data-userid="75073" href="#" id="favlink_1695162" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# <a class="userlists" data-userid="75073" href="#" id="listlink_1695162" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=75073" style="width: 105px; height: 90px;"><img alt="Blix the Goblin's Avatar" class="lightshadow" data-postid="1695162" src="customavatars/avatar75073_2.gif" style="margin-bottom: 1px; width: 105px; height: 90px;"/></div></div></div>, <div class="post" id="post1695184">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96380" style="padding-right: 10px;" title="View Joel's Profile"><span>J</span>oel</a> <a class="favs" data-userid="96380" href="#" id="favlink_1695184" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# <a class="userlists" data-userid="96380" href="#" id="listlink_1695184" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96380" style="width: 110px; height: 83px;"><img alt="Joel's Avatar" class="lightshadow" data-postid="1695184" src="customavatars/avatar96380_34.gif" style="margin-bottom: 1px; width: 110px; height: 83px;"/></div></div></div>, <div class="post" id="post1695195">
# <br/><br/>
# <div class="userinfo left clear" style="padding-top: 0;">
# <div style="position: absolute; top: -28px; left: 0; white-space: nowrap;">
# <a class="username" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96380" style="padding-right: 10px;" title="View Joel's Profile"><span>J</span>oel</a> <a class="favs" data-userid="96380" href="#" id="favlink_1695195" title="Favorite Movies">
# <?xml version="1.0" standalone="no" ?>
# <svg height="14" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 16 16" width="14" xmlns="http://www.w3.org/2000/svg" xmlns:sketch="http://www.bohemiancoding.com/sketch/ns" xmlns:xlink="http://www.w3.org/1999/xlink">
# <switch>
# <g fill="none" fill-rule="evenodd" id="Icons with numbers" stroke="none" stroke-width="1"><g fill="#FFFFFF" id="Group" transform="translate(-384.000000, -480.000000)"><path d="M392,491.953125 L387.022583,495.99353 L389.032704,489.524391 L384.015259,486.030029 L390.052612,486.030029 L392,480 L393.984253,486.030029 L400.065063,486.030029 L394.967296,489.524392 L397.036133,495.99353 L392,491.953125 Z M392,491.953125"></path></g></g>
# <foreignobject>
# <img src="/images/fallbacks/fallback-favs.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# <a class="userlists" data-userid="96380" href="#" id="listlink_1695195" title="User Lists">
# <?xml version="1.0" standalone="no" ?>
# <svg height="16" id="list-svg" preserveaspectratio="xMidYMid meet" version="1.1" viewbox="0 0 1024 768" width="16" xmlns="http://www.w3.org/2000/svg">
# <switch>
# <path d="M0 576h128v-128h-128v128z m0-256h128v-128h-128v128z m0 512h128v-128h-128v128z m256-256h512v-128h-512v128z m0-256h512v-128h-512v128z m0 512h512v-128h-512v128z"></path>
# <foreignobject>
# <img src="/images/fallbacks/fallback-lists.png"/>
# </foreignobject>
# </switch>
# </svg></a>
# </div>
# <div <a="" class="thumb" href="member.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;u=96380" style="width: 110px; height: 83px;"><img alt="Joel's Avatar" class="lightshadow" data-postid="1695195" src="customavatars/avatar96380_34.gif" style="margin-bottom: 1px; width: 110px; height: 83px;"/></div></div></div>]
# +++++++++++++
# [<div class="postdate">
# <a href="showthread.php?p=1695060#post1695060" rel="nofollow" title="4-29-17 at 6:53 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695061#post1695061" rel="nofollow" title="4-29-17 at 6:55 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695062#post1695062" rel="nofollow" title="4-29-17 at 6:56 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695063#post1695063" rel="nofollow" title="4-29-17 at 6:57 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695064#post1695064" rel="nofollow" title="4-29-17 at 7:04 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695107#post1695107" rel="nofollow" title="4-29-17 at 8:52 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695109#post1695109" rel="nofollow" title="4-29-17 at 8:54 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695110#post1695110" rel="nofollow" title="4-29-17 at 8:56 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695111#post1695111" rel="nofollow" title="4-29-17 at 8:56 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695114#post1695114" rel="nofollow" title="4-29-17 at 9:18 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695137#post1695137" rel="nofollow" title="4-29-17 at 9:41 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695139#post1695139" rel="nofollow" title="4-29-17 at 9:46 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695141#post1695141" rel="nofollow" title="4-29-17 at 9:49 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695142#post1695142" rel="nofollow" title="4-29-17 at 9:49 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695145#post1695145" rel="nofollow" title="4-29-17 at 9:52 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695146#post1695146" rel="nofollow" title="4-29-17 at 9:59 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695150#post1695150" rel="nofollow" title="4-29-17 at 10:15 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695162#post1695162" rel="nofollow" title="4-29-17 at 10:54 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695184#post1695184" rel="nofollow" title="4-29-17 at 11:30 PM">04-29-17</a>
# </div>, <div class="postdate">
# <a href="showthread.php?p=1695195#post1695195" rel="nofollow" title="4-29-17 at 11:39 PM">04-29-17</a>
# </div>]
# +++++++++++++
# [<div class="posttext">
# <div id="post_message_1695060">
#       After seeing it a few times over the years, I still don't get all the hype. I mean the action scenes are good, but I find the story to be an average action movie plot, to be quite honest.<br/>
# <br/>
# There isn't a huge deal of character change, the heroes and villains are very black and white, and some parts of the plot I find unconvincing. I mean I know it's an action movie, but this is rated so high by many people, that I can't help to pick on illogics in the plot more so, because of how highly praised it is.<br/>
# <br/>
# <br/>
# SPOILERS<br/>
# <br/>
# <br/>
# Basically when Kristoff is looking for McClane, McClane sneaks up on Kristoff and points his gun at Christoff's head. <br/>
# <br/>
# He tells Kristoff to drop his gun, and Kristoff says "You won't hurt me, there are rules for policemen". McClane then says that's what my Captain keeps telling me. He then pistol whips Kristoff, and then tries to wrestle Kristoff's Machine gun, out of his hands.<br/>
# <br/>
# But why! Why would a cop try to fight someone, who has a machine gun, when the cop can just shoot him? It's not like McClane has any handcuffs on him to neutralize Kristoff, so what is he going to do, if Kristoff surrenders?<br/>
# <br/>
# Kristoff refused to drop the gun, and any realistic person would know that a cop would just shoot you in this situation and not attempt to wrestle a machine gun out of your hand.<br/>
# <br/>
# Later on, McClane is trying to get the cop's attention from out the window and another goon comes to try stop him. McClane again tells the guy to put the gun down, but why? It's not like he can keep him held prisoner in situation like that.<br/>
# <br/>
# He does this with Hans later as well instead of just shooting Hans.<br/>
# <br/>
# I also feel that some of the dialogue is really dumb in this movie, like when the Deputy Chief cop says that the body that fell from the window that was full of bullet holes, must have been a depressed stockbroker. Really???<br/>
# <br/>
# And I also feel that the Thornberg character, was not necessary to the plot and didn't really add anything really. I first saw Die Hard on edited television way back, and back then, all of Thornberg's scenes were cut, accept for the video footage, on the news that Holly saw, which tipped Hans' off. Having seen the uncut version of the movie, I feel that Thornberg being turned into an actual subplot character, doesn't really add anything.<br/>
# <br/>
# We don't need to know the personal squabbles of the news guy, who's only role in the plot was to unintentionally tip the villain off. It made perfect sense on TV to cut all his scenes out accept the video footage one, that tipped Hans off.<br/>
# <br/>
# And a lot of people out there say that Hans Gruber is the greatest movie villain ever, if not the greatest, but I dunno... I mean he doesn't really go through any huge personal character changes, and he is really just a bankrobber, with no hugely personal stakes in his goal.<br/>
# <br/>
# McClane is good character, but I feel he is doesn't really do anything to be go through much of a change, and he is not pushed to his moral limits either in the end. But maybe this is not a bad thing, and maybe he doesn't have to.<br/>
# <br/>
# So I feel the movie, in spite of having really good action scenes, is just not as well written as it could be, and is more of an average, perhaps decent action movie in terms of story and script.<br/>
# <br/>
# What do you think?
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695062">
#       I dont really think there's any such thing as an overrated movie. Just because I may not enjoy a film so much does not mean critics and viewers dont get pumped for it. Die Hard I thought was great fun. Gone Girl is one I mentioned earlier where I dont get the hype, but I'm not going to label it overrated.
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695063">
#       ur talking abt the best action movie ever made along with the star of the stars, love every bit of this film, very rarely a movie gives u this feeling as if ur john mclane and shows u that much parts of a building and lets u get immersed into the surroundings and every bit and corner of that building, its such a greatly made film that i can watch it again and again and never get bored, it is that good
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695064">
# <div class="quotecontainer">
# <div class="quote">
# <div class="postedby">
# <a href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;p=1695063#post1695063" title="View Post">Originally Posted by <strong>rambond</strong></a>
# </div>
# <div class="italic">ur talking abt the best action movie ever made along with the star of the stars, love every bit of this film, very rarely a movie gives u this feeling as if ur john mclane and shows u that much parts of a building and lets u get immersed into the surroundings and every bit and corner of that building, its such a greatly made film that i can watch it again and again and never get bored, it is that good</div>
# </div>
# </div>I've loved all of them but that was my stand out because - Alan Rickman!!! RiP, my darling. Die Hard 3 lost a few points for me due to Jeremy's silly accent. 4 for Timothy who was so hot in this, and Justin's chemistry with Bruce.
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695107">
#       I think it's a pretty great film but yes it's overrated. So many people calling it the absolute best action movie ever made surely can only make it feel overrated, in the most literal way possible, to those of us who don't think it's a 10/10 absolute masterpiece...
#       </div>
# <div style="clear: both;">
#         __________________<br/>
# <b><a href="https://www.movieforums.com/community/showthread.php?p=1771126#post1771126" target="_blank"><font color="Red"><font size="3">NEW REVIEW OF <font size="3">IT</font> (2017)</font> </font></a></b> <b>//</b> <a href="https://www.movieforums.com/community/showthread.php?t=37926" target="_blank"><b><font color="Orange">MovieMeditation's Cinema Reviews</font></b></a> <b>//</b> <a href="https://www.movieforums.com/community/showthread.php?p=1234644#post1234644" target="_blank"><b><font color="RoyalBlue">#1 Film Diary 2015</font></b></a> <b>//</b> <a href="https://letterboxd.com/MovieMeditation/" target="_blank"><b><font color="DarkSlateBlue">Letterboxd Profile</font></b></a> <b>//</b> <a href="http://oc.mymovies.dk/ABjerg" target="_blank"><b><font color="SeaGreen">DVD &amp; Blu-ray Collection</font></b></a> <b>//</b> <a href="https://www.movieforums.com/community/showthread.php?t=40665" target="_blank"><b><font color="Red">MovieMeditation's Top 50 Horror</font></b></a>
# </div>
# </div>, <div class="posttext">
# <div id="post_message_1695109">
#       I regard it as the best action movie of all time, and I have since the day it came out. So I say no.
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695110">
# <div class="quotecontainer">
# <div class="quote">
# <div class="postedby">
# <a href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;p=1695109#post1695109" title="View Post">Originally Posted by <strong>cricket</strong></a>
# </div>
# <div class="italic">I regard it as the best action movie of all time, and I have since the day it came out. So I say no.</div>
# </div>
# </div>I think we should all call it the best action movie of all time just to irritate the Viking.<br/>
# <br/>
# Just joshin' MM. I dont think I've ever said Best movie of all time. I just love and dont like movies.
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695111">
#       Anything on as high of a pedestal as <i>Die Hard</i> can be considered "overrated". I've always preferred <i>Die Hard with a Vengeance</i> myself.
#       </div>
# <div style="clear: both;">
#         __________________<br/>
# <font face="Book Antiqua"><a href="https://letterboxd.com/Redwell/" target="_blank">Letterboxd</a> | <a href="https://squawkr.io/" target="_blank">Squakwr</a> | <a href="http://reverseshot.org/" target="_blank">ReverseShot</a> | <a href="http://slantmagazine.com/" target="_blank">SlantMagazine</a></font>
# </div>
# </div>, <div class="posttext">
# <div id="post_message_1695114">
#       It may be a run-of-the-mill action movie, with cardboard cutout characters, but for whatever reason, any stimulus at all (such as this thread) compels me to watch it again, and it pulls me in and I enjoy it just as much every time.  Plus it's a ready-made Christmas tradition.  And don't tell me there are no significant character changes; after all, <div style="box-shadow: 2px 2px 3px rgba(0, 0, 0, 0.4); margin: 0 16px 8px 16px; border: 1px solid #888;" title="Click anywhere to toggle spoilers on or off">
# <div onclick="spoiler(this);" onmouseout="this.style.cursor = 'default';" onmouseover="this.style.cursor = 'pointer';" style="border: 1px solid #FFF; background-color: #E9E9E9; padding: 8px;">
# <div class="smallfont" id="spoilerlink" style="float: right"><a href="" onclick="return false;">View Spoilers</a></div>
# <span class="med" style="color: red;"><b>WARNING: "Die Hard" spoilers below</b></span>
# <div id="idSpoiler" style="padding-top: 6px;">
# <span style="color: #E9E9E9;">McClane's very shirt changes color on its own halfway through the movie!</span>
# </div>
# <div id="idSpoiler2" style="display: none; padding-top: 6px;">
#     McClane's very shirt changes color on its own halfway through the movie!
#   </div>
# </div>
# </div><br/>
#   Damn, now I need to go watch <i>Die Hard</i>.  Excuse me.
#       </div>
# <div style="clear: both;">
#         __________________<br/>
#         "You seem a decent fellow.  I hate to kill you." <br/>
# "<i>You</i> seem a decent fellow.  I hate to die."
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695137">
#       The characters do feel kind of card board cut out.  One thing in Die Hard, a lot of people say that Alan Rickman was such a great villain, and some have said that he's the best movie villain of all time.  But the villain doesn't really go through much character development.  He doesn't learn any lessons, go through any moral changes, or explore any themes or anything much.<br/>
# <br/>
# He is incapabable of character change, yet he is considered to be a great villain, in a great movie, that doesn't have a lot of character development.  I know it's an action movie, but even other great ones, still make more time for it.
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695139">
# <div class="quotecontainer">
# <div class="quote">
# <div class="postedby">
# <a href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;p=1695137#post1695137" title="View Post">Originally Posted by <strong>ironpony</strong></a>
# </div>
# <div class="italic">The characters do feel kind of card board cut out.  One thing in Die Hard, a lot of people say that Alan Rickman was such a great villain, and some have said that he's the best movie villain of all time.  But the villain doesn't really go through much character development.  He doesn't learn any lessons, go through any moral changes, or explore any themes or anything much.<br/>
# <br/>
# He is incapabable of character change, yet he is considered to be a great villain, in a great movie, that doesn't have a lot of character development.  I know it's an action movie, but even other great ones, still make more time for it.</div>
# </div>
# </div>He's fun, which is all a movie like this requires.  (As he also was in <i>Robin Hood, Prince of Thieves</i>.)  Fun is really what the whole appeal of this movie boils down to, for me.  Switch-your-mind-off fun.
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695141">
#       No.
#       </div>
# <div style="clear: both;">
#         __________________<br/>
# <div align="center"><b>Top 100 <a href="https://www.movieforums.com/community/showthread.php?t=48685" target="_blank">here!</a></b><br/>
# </div><br/>
# <div align="center"><b>Reviews thread </b><a href="https://www.movieforums.com/community/showthread.php?anchor=1&amp;p=1276583#post1276583" target="_blank"><b>here</b></a>!<br/>
# </div>
# </div>
# </div>, <div class="posttext">
# <div id="post_message_1695142">
#       Nope.
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695145">
# <div class="quotecontainer">
# <div class="quote">
# <div class="postedby">
# <a href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;p=1695137#post1695137" title="View Post">Originally Posted by <strong>ironpony</strong></a>
# </div>
# <div class="italic">  One thing in Die Hard, a lot of people say that Alan Rickman was such a great villain, and some have said that he's the best movie villain of all time.  But the villain doesn't really go through much character development.  He doesn't learn any lessons, go through any moral changes, or explore any themes or anything much..</div>
# </div>
# </div>Because<br/>
# 1. Alan Rickman.<br/>
# and <br/>
# 2. I dont expect villains to have to go through character development, learn any lessons, go through moral changes, and realise how flawed they are. That's what makes them villains - they're sociopathic.
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695146">
# <font face="Comic Sans MS"><font size="3">It's an enjoyable movie showcasing vintage Bruce Willis as action hero.  My wife likes to watch it every year.  One of my favorite parts is at the end when Vaughn Monroe sings "Let It Snow".<br/>
# <br/>
# ~Cheers</font></font>
# </div>
# </div>, <div class="posttext">
# <div id="post_message_1695150">
#       It's not *that* overrated really. It's exceptionally directed, I love John McClane as a character and Alan Rickman's villain while one-dimensional is still a joy to watch.<br/>
# <br/>
# So overrated? I disagree. Now, if we were talking Mad Max: Fury Road...
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695162">
# <div class="quotecontainer">
# <div class="quote">
# <div class="postedby">
# <a href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;p=1695150#post1695150" title="View Post">Originally Posted by <strong>mattiasflgrtll6</strong></a>
# </div>
# <div class="italic">So overrated? I disagree. Now, if we were talking Mad Max: Fury Road...</div>
# </div>
# </div>Oh god yes
#       </div>
# </div>, <div class="posttext">
# <div id="post_message_1695184">
# <div class="quotecontainer"> <div class="quote"> <div class="postedby"> <a href="showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&amp;p=1695145#post1695145" title="View Post">Originally Posted by <strong>Dani8</strong></a> </div> <div class="italic">Because<br/>  1. Alan Rickman.<br/>  and <br/>  2. I dont expect villains to have to go through character development, learn any lessons, go through moral changes, and realise how flawed they are. That's what makes them villains - they're sociopathic.</div> </div> </div>Clarence Boddicker ... #1 with a bullet. :P<br/> <br/> <div class="video" data-pe-videoid="QdZqKVcI9m8"><iframe allowfullscreen="" frameborder="0" height="429" src="//www.youtube.com/embed/QdZqKVcI9m8?rel=0" width="700"></iframe></div>
# </div>
# </div>, <div class="posttext">
# <div id="post_message_1695195">
#       I think it deserves its place as a classic action picture. I certainly wouldn't call it the best action film. It's definitely an American macho rootin' tootin' shoot em up. Mindless fun, not much more. I watch it every few Christmases. Not overrated imo. I thought John McTiernan hit his stride with "Predator". Now <i>that's</i> a good action movie that may even suffer from being <i>under</i>rated. Just kidding. I think at the time a lot of people were impressed that Die Hard took a tv star and made him a household name. Bruce Willis was only semi popular from "Moonlighting" before "Die Hard".
#       </div>
# </div>]

# %% [markdown]
# <b>Awesome,</b> we now have all the posts. Now we need to figure out what information we actually want from the posts.
# For the sake of doing all of this to get something meaningful, I've decided that my goal is to get the following:
# <ul>
# <li>Username</li>
# <li>TimeStamp</li>
# <li>Post</li>
# </ul>

# %%
## Starting with the username. 
## After some sluething, we found out that usernames are in the a tag with class 'username'
## Let's make this a function!

def findUserName(postDiv):
    allPostLinks = postDiv.find_all('a')
    # iterate through all links
    for link in allPostLinks:
        try:
            if 'username' in link.get('class'): # if class type is username, get the name!
                return link.text
        except Exception:
            pass
    return None

## test...
for post in postDivs:
    print(findUserName(post))
# Out:
# ironpony
# Dani8
# rambond
# Dani8
# MovieMeditation
# cricket
# Dani8
# Redwell
# BoxOfficePoison
# ironpony
# BoxOfficePoison
# neiba
# Steve Freeling
# Dani8
# GulfportDoc
# mattiasflgrtll6
# Blix the Goblin
# Joel
# Joel

# %%
## now let's find the timestamp

def findTimeStamp(postDateDiv):
    try: # we know the time stamp is the title of date items
        return postDateDiv.a['title']
    except Exception:
        return None

for div in postDateDivs:
    print(findTimeStamp(div))
# Out:
# 4-29-17 at 6:53 PM
# 4-29-17 at 6:55 PM
# 4-29-17 at 6:56 PM
# 4-29-17 at 6:57 PM
# 4-29-17 at 7:04 PM
# 4-29-17 at 8:52 PM
# 4-29-17 at 8:54 PM
# 4-29-17 at 8:56 PM
# 4-29-17 at 8:56 PM
# 4-29-17 at 9:18 PM
# 4-29-17 at 9:41 PM
# 4-29-17 at 9:46 PM
# 4-29-17 at 9:49 PM
# 4-29-17 at 9:49 PM
# 4-29-17 at 9:52 PM
# 4-29-17 at 9:59 PM
# 4-29-17 at 10:15 PM
# 4-29-17 at 10:54 PM
# 4-29-17 at 11:30 PM
# 4-29-17 at 11:39 PM

# %%
## now for the actual text..

def findText(postTextDiv):
    """ This function finds all text, and all the text that was quoted from someplace else
        It finds the text, erases all quoted text, and then returns the remaining, original text."""
    allText = None 
    quotedText = None
    postDivs = postTextDiv.find_all('div')
    #find text
    for div in postDivs:
        try: 
            if "post_message" in div['id']:
                allText = div.get_text()
        except Exception:
            pass
        try: #if any text was quoted, we need to save it so we can remove it from all text
            if "quotecontainer" in div.get('class'):
                quotedText = div.get_text()
                #print(quotedText)
        except Exception:
            pass

    # print(allText, "\n", quotedText)
    # if the post isn't quoting anything, return the post text
    if quotedText == None: 
        allText = allText.replace(",", "")
        return allText
    else: #otherwise you need to remove the quoted text 
        allText = allText.replace(quotedText,"")
        allText = allText.replace(",", "")
        return allText
    
for div in postTextDivs:
    print(findText(div))
# Out:
#       After seeing it a few times over the years I still don't get all the hype. I mean the action scenes are good but I find the story to be an average action movie plot to be quite honest.
#
# There isn't a huge deal of character change the heroes and villains are very black and white and some parts of the plot I find unconvincing. I mean I know it's an action movie but this is rated so high by many people that I can't help to pick on illogics in the plot more so because of how highly praised it is.
#
#
# SPOILERS
#
#
# Basically when Kristoff is looking for McClane McClane sneaks up on Kristoff and points his gun at Christoff's head.
#
# He tells Kristoff to drop his gun and Kristoff says "You won't hurt me there are rules for policemen". McClane then says that's what my Captain keeps telling me. He then pistol whips Kristoff and then tries to wrestle Kristoff's Machine gun out of his hands.
#
# But why! Why would a cop try to fight someone who has a machine gun when the cop can just shoot him? It's not like McClane has any handcuffs on him to neutralize Kristoff so what is he going to do if Kristoff surrenders?
#
# Kristoff refused to drop the gun and any realistic person would know that a cop would just shoot you in this situation and not attempt to wrestle a machine gun out of your hand.
#
# Later on McClane is trying to get the cop's attention from out the window and another goon comes to try stop him. McClane again tells the guy to put the gun down but why? It's not like he can keep him held prisoner in situation like that.
#
# He does this with Hans later as well instead of just shooting Hans.
#
# I also feel that some of the dialogue is really dumb in this movie like when the Deputy Chief cop says that the body that fell from the window that was full of bullet holes must have been a depressed stockbroker. Really???
#
# And I also feel that the Thornberg character was not necessary to the plot and didn't really add anything really. I first saw Die Hard on edited television way back and back then all of Thornberg's scenes were cut accept for the video footage on the news that Holly saw which tipped Hans' off. Having seen the uncut version of the movie I feel that Thornberg being turned into an actual subplot character doesn't really add anything.
#
# We don't need to know the personal squabbles of the news guy who's only role in the plot was to unintentionally tip the villain off. It made perfect sense on TV to cut all his scenes out accept the video footage one that tipped Hans off.
#
# And a lot of people out there say that Hans Gruber is the greatest movie villain ever if not the greatest but I dunno... I mean he doesn't really go through any huge personal character changes and he is really just a bankrobber with no hugely personal stakes in his goal.
#
# McClane is good character but I feel he is doesn't really do anything to be go through much of a change and he is not pushed to his moral limits either in the end. But maybe this is not a bad thing and maybe he doesn't have to.
#
# So I feel the movie in spite of having really good action scenes is just not as well written as it could be and is more of an average perhaps decent action movie in terms of story and script.
#
# What do you think?
#
#
#       I dont really think there's any such thing as an overrated movie. Just because I may not enjoy a film so much does not mean critics and viewers dont get pumped for it. Die Hard I thought was great fun. Gone Girl is one I mentioned earlier where I dont get the hype but I'm not going to label it overrated.
#
#
#       ur talking abt the best action movie ever made along with the star of the stars love every bit of this film very rarely a movie gives u this feeling as if ur john mclane and shows u that much parts of a building and lets u get immersed into the surroundings and every bit and corner of that building its such a greatly made film that i can watch it again and again and never get bored it is that good
#
#
# I've loved all of them but that was my stand out because - Alan Rickman!!! RiP my darling. Die Hard 3 lost a few points for me due to Jeremy's silly accent. 4 for Timothy who was so hot in this and Justin's chemistry with Bruce.
#
#
#       I think it's a pretty great film but yes it's overrated. So many people calling it the absolute best action movie ever made surely can only make it feel overrated in the most literal way possible to those of us who don't think it's a 10/10 absolute masterpiece...
#
#
#       I regard it as the best action movie of all time and I have since the day it came out. So I say no.
#
#
# I think we should all call it the best action movie of all time just to irritate the Viking.
#
# Just joshin' MM. I dont think I've ever said Best movie of all time. I just love and dont like movies.
#
#
#       Anything on as high of a pedestal as Die Hard can be considered "overrated". I've always preferred Die Hard with a Vengeance myself.
#
#
#       It may be a run-of-the-mill action movie with cardboard cutout characters but for whatever reason any stimulus at all (such as this thread) compels me to watch it again and it pulls me in and I enjoy it just as much every time.  Plus it's a ready-made Christmas tradition.  And don't tell me there are no significant character changes; after all
#
# View Spoilers
# WARNING: "Die Hard" spoilers below
#
# McClane's very shirt changes color on its own halfway through the movie!
#
#
#     McClane's very shirt changes color on its own halfway through the movie!
#
#
#
#   Damn now I need to go watch Die Hard.  Excuse me.
#
#
#       The characters do feel kind of card board cut out.  One thing in Die Hard a lot of people say that Alan Rickman was such a great villain and some have said that he's the best movie villain of all time.  But the villain doesn't really go through much character development.  He doesn't learn any lessons go through any moral changes or explore any themes or anything much.
#
# He is incapabable of character change yet he is considered to be a great villain in a great movie that doesn't have a lot of character development.  I know it's an action movie but even other great ones still make more time for it.
#
#
# He's fun which is all a movie like this requires.  (As he also was in Robin Hood Prince of Thieves.)  Fun is really what the whole appeal of this movie boils down to for me.  Switch-your-mind-off fun.
#
#
#       No.
#
#
#       Nope.
#
#
# Because
# 1. Alan Rickman.
# and
# 2. I dont expect villains to have to go through character development learn any lessons go through moral changes and realise how flawed they are. That's what makes them villains - they're sociopathic.
#
#
# It's an enjoyable movie showcasing vintage Bruce Willis as action hero.  My wife likes to watch it every year.  One of my favorite parts is at the end when Vaughn Monroe sings "Let It Snow".
#
# ~Cheers
#
#
#       It's not *that* overrated really. It's exceptionally directed I love John McClane as a character and Alan Rickman's villain while one-dimensional is still a joy to watch.
#
# So overrated? I disagree. Now if we were talking Mad Max: Fury Road...
#
#
# Oh god yes
#
#
# Clarence Boddicker ... #1 with a bullet. :P
#
#
#       I think it deserves its place as a classic action picture. I certainly wouldn't call it the best action film. It's definitely an American macho rootin' tootin' shoot em up. Mindless fun not much more. I watch it every few Christmases. Not overrated imo. I thought John McTiernan hit his stride with "Predator". Now that's a good action movie that may even suffer from being underrated. Just kidding. I think at the time a lot of people were impressed that Die Hard took a tv star and made him a household name. Bruce Willis was only semi popular from "Moonlighting" before "Die Hard".

# %%
## okay! Now that we know how to find all the info we want, we can make a csv file! 
allUserNames  = [findUserName(div) for div in postDivs]
allTimeStamps = [findTimeStamp(div) for div in postDateDivs]
allText       = [findText(div) for div in postTextDivs]
print(len(allUserNames), len(allTimeStamps), len(allText))
# Out:
# 19 20 19

# %%
## now write to csv file..
import csv

allRows = []
for username, timestamp, text in zip(allUserNames, allTimeStamps, allText):
    allRows.append([username, timestamp, text.strip()])

#print(allRows)
with open("DieHardData2.csv", "a", encoding = "utf-8") as csvfile:
    writer = csv.writer(csvfile)
    writer.writerow(["UserName", "TimeStamp", "Text"])
    for row in allRows:
        writer.writerow(row)

# %% [markdown]
# Look in your directory to for the csv file.

# %%
# What about the next page? The link to the next page is indcated with a '>>'

def findNextPage(allLinks):
    for link in allLinks:
        if link.get_text() == "»":
            return "https://www.movieforums.com/community/"+ link['href']
    ## if we get all the way to end and didn't find it, assume it's the end of the forum
    return None

print(findNextPage(links))
# Out:
# https://www.movieforums.com/community/showthread.php?s=cdc988b455c2e529861d3d4f51f35e13&t=49209&page=2

# %% [markdown]
# #### Cool! We got all the pieces ~ now we should put them together into a nice, neat set of funcitons.

# %%
def scrapeForum(url, fileName):
    """ This takes a forum from movieforum.com and scrapes all entries. 
        It then creates a file with the Usernames, TimeStamp, and Text of each entry. """
    
    ## first, open the page:
    webpage = requests.get(url)
    webtext = webpage.text
    
    ## now let's make some soup
    soup = BeautifulSoup(webtext, "html.parser") 
    
    ## get links for future reference
    links = soup.find_all('a')
    
    ## now find all the right div sections:
    allDiv       = soup.find_all('div') #all div's
    postDivs     = [] #empty list
    postDateDivs = []
    postTextDivs = []

    for div in allDiv:
        try:
            if 'post' in div.get('class'):
                postDivs.append(div)
            elif 'postdate' in div.get('class'):
                postDateDivs.append(div)
            elif 'posttext' in div.get('class'):
                postTextDivs.append(div)
        except Exception:
            pass
    
    ## we already described the functions to find the username, timestamp, and text, so let's use them!!
    allUserNames = [findUserName(div) for div in postDivs]
    allTimeStamps = [findTimeStamp(div) for div in postDateDivs]
    allText = [findText(div) for div in postTextDivs]
    
    ## create the rows for the csv file
    allRows = []
    for username, timestamp, text in zip(allUserNames, allTimeStamps, allText):
        allRows.append([username, timestamp, text.strip()])
    
    ## print to file! 
    with open(fileName, "a", encoding = "utf-8") as csvfile:
        writer = csv.writer(csvfile)
        writer.writerow(["UserName", "TimeStamp", "Text"])
        for row in allRows:
            writer.writerow(row)
            
    ## almost done - now we should check for a next page. If there is, call this function again.
    ## If not, then we can just call it a day. 
    
    nextPage = findNextPage(links)
    if nextPage != None:
        scrapeForum(nextPage, fileName) ## since we open the fileName using 'a', it'll just append to the end
   
    return

# %%
scrapeForum("https://www.movieforums.com/community/showthread.php?t=49209", "DieHardForum2.csv")

# %%
scrapeForum("https://www.movieforums.com/community/showthread.php?t=45018", "pirate2.csv")

# %% [markdown]
# ### Results
# <p> We can successfully scrape a whole web forum! </p>
# <p> Some things to remember </p>
# <ul>
# <li> This will ONLY work for movieforums.com. We other website may not have the same tags </li>
# <li> It takes a bit of effort to make the script, but it's WORTH IT </li>
# <li> This script may have to be changed over time.  Websites get updated, and so do the HMTL tags in it </li>
# <li> Beautiful Soup does not work for websites written with javascript. </li>
# <li> Overall, it's pretty cool!</li>
# <ul>
#
#
#
# ## Thanks, Lena!
